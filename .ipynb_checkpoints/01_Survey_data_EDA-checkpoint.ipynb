# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Survey on Municipal Services of Barcelona's City
#
# Source of the data:
#
# https://opendata-ajuntament.barcelona.cat/data/en/dataset/esm-bcn-evo
#
# https://opendata-ajuntament.barcelona.cat/doc/BackOff_DescCompDefCamps/EnquestaServeisMunicipals_BCN/2019_Any/2019_r19006_ESM_Questionari_v1_0.pdf

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import contextily as cx
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# # 1.1. Reading the data

# %%
survey = pd.read_csv('data/survey/2019_r19006_esm_evolucio_bdd_v1_0/2019_r19006_esm_evolucio_bdd_v1_0.csv', low_memory=False)

# %%
survey.head()
# Out:
#    Unnamed: 0         ID   ANY NOM_DISTRICTE NOM_BARRI DATA_ENQ  \
# 0           1  198900001  1989  CIUTAT VELLA       NaN      NaN
# 1           2  198900002  1989  CIUTAT VELLA       NaN      NaN
# 2           3  198900003  1989  CIUTAT VELLA       NaN      NaN
# 3           4  198900004  1989  CIUTAT VELLA       NaN      NaN
# 4           5  198900005  1989  CIUTAT VELLA       NaN      NaN
#
#   TMP_RES_BCN_1A6 TMP_RES_BARRI_1A6 RES_HAB PADRO  ... DEM_BARRI_N1  \
# 0             NaN               NaN     NaN   NaN  ...          NaN
# 1             NaN               NaN     NaN   NaN  ...          NaN
# 2             NaN               NaN     NaN   NaN  ...          NaN
# 3             NaN               NaN     NaN   NaN  ...          NaN
# 4             NaN               NaN     NaN   NaN  ...          NaN
#
#   CONSULTA_DIARI_Q01_N1 CONSULTA_DIARI_Q02_N1 VEURE_TELE_Q01_N1  \
# 0                   NaN                   NaN               TV3
# 1                ALTRES                   NaN              LA 1
# 2                   NaN                   NaN              LA 1
# 3          EL PERIÓDICO                   NaN              LA 1
# 4                   NaN                   NaN               TV3
#
#   VEURE_TELE_Q02_N1 VEURE_TELE_Q03_N1 HAB_COTXE_PART_1A4 US30D_XARXES_Q06  \
# 0               NaN               NaN                CAP              NaN
# 1               NaN               NaN                CAP              NaN
# 2               NaN               NaN                CAP              NaN
# 3               NaN               NaN                CAP              NaN
# 4               NaN               NaN                CAP              NaN
#
#   US30D_XARXES_Q07 PMI_1A3_2017
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
#
# [5 rows x 286 columns]

# %%
survey.groupby(['ANY']).size().plot.bar()

# %%
survey = survey.query('ANY >= 2007')

# %% [markdown]
# # 1.2. Translating the data from Catalan to English and subsetting the DataFrame to only relevant columns (survey questions)

# %% [markdown]
# As the survey is conducted in Catalan, the data is also saved in this language. In this section the data is being translated into English. The translation was done by the author.

# %%
# Reading questions dataset with a flag indicating if the question is relevant for further analysis
questions = pd.read_excel('data/survey/survey_filtered/2019_r19006_ESM_Evolucio_BDD_Metainformacio_Preguntes_v1_0.xlsx')

# %%
# Filtering out unnecessary questions
questions = questions.query('Flag == 1')
questions.head()
# Out:
#     Nom_variable  Flag             Pregunta     Question Tipus_variable
# 1            ANY     1    ANY DE L'ENQUESTA  SURVEY YEAR        numeric
# 2  NOM_DISTRICTE     1  DISTRICTE MUNICIPAL     DISTRICT         factor
# 3      NOM_BARRI     1                BARRI        BARRI         factor
# 4      GRANBARRI     1           GRAN BARRI   GRAN BARRI         factor
# 6           SEXE     1                 SEXE          SEX         factor

# %%
# Dictionary with Catalan and Spanish names/descriptions of questions
df = questions[['Nom_variable', 'Question']]
questions_dict = {}
for i in range(len(df)):
    questions_dict[df.iloc[i].Nom_variable] = df.iloc[i].Question
questions_dict
# Out:
# {'ANY': 'SURVEY YEAR',
#  'NOM_DISTRICTE': 'DISTRICT',
#  'NOM_BARRI': 'BARRI',
#  'GRANBARRI': 'GRAN BARRI',
#  'SEXE': 'SEX',
#  'EDAT1899_1A6': 'AGE',
#  'NACIO_ACT_UE': 'WHAT IS YOUR NATIONALITY?',
#  'TMP_RES_BCN_1A6': 'HOW LONG HAVE YOU BEEN LIVING IN BARCELONA?',
#  'TMP_RES_BARRI_1A6': 'HOW LONG HAVE YOU BEEN LIVING IN THIS NEIGHBORHOOD?',
#  'EVO1A_BCN': 'DO YOU THINK THAT LAST YEAR BARCELONA HAS IMPROVED OR WORSENED?',
#  'FUTUR_BCN': 'FACING THE FUTURE, DO YOU THINK BARCELONA WILL IMPROVE OR GET WORSE?',
#  'SATISF_RES_BCN_1A4': 'ON A SCALE OF 0 TO 10, BEING 0 NOT SATISFIED AND 10 VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR SATISFACTION DEGREE OF LIVING IN THE CITY OF BARCELONA? - GROUPED',
#  'VAL_GESTMUNI_1A2': 'ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 BEING VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL? - GROUPED',
#  'VAL_ESCOMBRARIES_1A2': 'CITY SERVICES - RATE: GARBAGE COLLECTION - GROUPED',
#  'VAL_NETEJA_1A2': 'CITY SERVICES - RATE: STREETS CLEANING - GROUPED',
#  'VAL_SOROLL_1A2': 'CITY SERVICES - RATE: NOISE - GROUPED',
#  'VAL_VERD_1A2': 'CITY SERVICES - RATE: GREEN AREAS - GROUPED',
#  'VAL_ENLLUM_1A2': 'CITY SERVICES - RATE: PUBLIC LIGHTING - GROUPED',
#  'VAL_URBA_1A2': 'CITY SERVICES - RATE: URBANISM - GROUPED',
#  'VAL_ASFALT_1A2': 'CITY SERVICES - RATE: ASPHALT AND STREET CONSERVATION - GROUPED',
#  'VAL_FACANES_1A2': 'CITY SERVICES - RATE: FACADES AND BUILDING CONSERVATION - GROUPED',
#  'VAL_CIRCUL_1A2': 'CITY SERVICES - RATE: CIRCULATION - GROUPED',
#  'VAL_APARCA_1A2': 'CITY SERVICES - RATE: PARKING - GROUPED',
#  'VAL_BUS_1A2': 'CITY SERVICES - RATE: BUS - GROUPED',
#  'VAL_METRO_1A2': 'CITY SERVICES - RATE: SUBWAY - GROUPED',
#  'VAL_TRAM_1A2': 'CITY SERVICES - RATE: TRAM - GROUPED',
#  'VAL_BICING_1A2': 'CITY SERVICES - RATE: BICING - GROUPED',
#  'VAL_GUB_1A2': 'CITY SERVICES - RATE: MUNICIPAL POLICE - GROUPED',
#  'VAL_SPEIS_1A2': 'CITY SERVICES - RATE: FIREFIGHTERS - GROUPED',
#  'VAL_SEGUR_1A2': 'CITY SERVICES - RATE: CITIZEN SECURITY IN THE CITY AS A WHOLE - GROUPED',
#  'VAL_SEGUR_BARRI_1A2': 'CITY SERVICES - RATE: CITIZEN SECURITY IN THE NEIGHBORHOOD - GROUPED',
#  'VAL_ESPORT_1A2': 'CITY SERVICES - RATE: SPORTS FACILITIES - GROUPED',
#  'VAL_SIAC_1A2': 'CITY SERVICES - RATE: CITIZEN INFORMATION AND ATTENTION SERVICES - GROUPED',
#  'VAL_CSS_1A2': 'CITY SERVICES - RATE: SOCIAL SERVICES CENTERS - GROUPED',
#  'VAL_CULT_1A2': 'CITY SERVICES - RATE: CULTURAL ACTIVITIES - GROUPED',
#  'VAL_FESTESPOP_1A2': 'CITY SERVICES - RATE: POPULAR FESTIVALS - GROUPED',
#  'VAL_MERCAT_1A2': 'CITY SERVICES - RATE: MUNICIPAL MARKETS - GROUPED',
#  'VAL_BIBLIO_1A2': 'CITY SERVICES - RATE: PUBLIC LIBRARIES - GROUPED',
#  'VAL_CC_1A2': 'CITY SERVICES - RATE: CIVIC CENTERS - GROUPED',
#  'EVO1A_ESCOMBRARIES': 'CITY SERVICES - IMPROVED/WORSENED: GARBAGE COLLECTION',
#  'EVO1A_NETEJA': 'CITY SERVICES - IMPROVED/WORSENED: STREETS CLEANING',
#  'EVO1A_SOROLL': 'CITY SERVICES - IMPROVED/WORSENED: NOISE',
#  'EVO1A_VERD': 'CITY SERVICES - IMPROVED/WORSENED: GREEN AREAS',
#  'EVO1A_ENLLUM': 'CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIGHTING',
#  'EVO1A_URBA': 'CITY SERVICES - IMPROVED/WORSENED: URBANISM',
#  'EVO1A_ASFALT': 'CITY SERVICES - IMPROVED/WORSENED: ASPHALT AND STREET CONSERVATION',
#  'EVO1A_FACANES': 'CITY SERVICES - IMPROVED/WORSENED: FACADES AND BUILDING CONSERVATION',
#  'EVO1A_CIRCUL': 'CITY SERVICES - IMPROVED/WORSENED: CIRCULATION',
#  'EVO1A_APARCA': 'CITY SERVICES - IMPROVED/WORSENED: PARKING',
#  'EVO1A_BUS': 'CITY SERVICES - IMPROVED/WORSENED: BUS',
#  'EVO1A_METRO': 'CITY SERVICES - IMPROVED/WORSENED: SUBWAY',
#  'EVO1A_TRAM': 'CITY SERVICES - IMPROVED/WORSENED: TRAM',
#  'EVO1A_BICING': 'CITY SERVICES - IMPROVED/WORSENED: BICING',
#  'EVO1A_GUB': 'CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL POLICE',
#  'EVO1A_SPEIS': 'CITY SERVICES - IMPROVED/WORSENED: FIREFIGHTERS',
#  'EVO1A_SEGUR': 'CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'EVO1A_SEGUR_BARRI': 'CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'EVO1A_ESPORT': 'CITY SERVICES - IMPROVED/WORSENED: SPORTS FACILITIES',
#  'EVO1A_SIAC': 'CITY SERVICES - IMPROVED/WORSENED: CITIZEN INFORMATION AND SERVICE SERVICES',
#  'EVO1A_CSS': 'CITY SERVICES - IMPROVED/WORSENED: SOCIAL SERVICES CENTERS',
#  'EVO1A_CULT': 'CITY SERVICES - IMPROVED/WORSENED: CULTURAL ACTIVITIES',
#  'EVO1A_FESTESPOP': 'CITY SERVICES - IMPROVED/WORSENED: POPULAR FESTIVALS',
#  'EVO1A_MERCAT': 'CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL MARKETS',
#  'EVO1A_BIBLIO': 'CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIBRARIES',
#  'EVO1A_CC': 'CITY SERVICES - IMPROVED/WORSENED: CIVIC CENTERS',
#  'US_VERD': "CITY SERVICES - USE/DON'T USE: GREEN AREAS",
#  'US_APARCA': "CITY SERVICES - USE/DON'T USE: PARKING",
#  'US_BUS': "CITY SERVICES - USE/DON'T USE: BUS",
#  'US_METRO': "CITY SERVICES - USE/DON'T USE: SUBWAY",
#  'US_TRAM': "CITY SERVICES - USE/DON'T USE: TRAM",
#  'US_BICING': "CITY SERVICES - USE/DON'T USE: BICING",
#  'US_ESPORT': "CITY SERVICES - USE/DON'T USE: SPORTS FACILITIES",
#  'US_SIAC': "CITY SERVICES - USE/DON'T USE: CITIZEN INFORMATION AND SERVICE SERVICES",
#  'US_CSS': "CITY SERVICES - USE/DON'T USE: SOCIAL SERVICES CENTERS",
#  'US_CULT': "CITY SERVICES - USE/DON'T USE: CULTURAL ACTIVITIES",
#  'US_FESTESPOP': "CITY SERVICES - USE/DON'T USE: POPULAR FESTIVALS",
#  'US_MERCAT': "CITY SERVICES - USE/DON'T USE: MUNICIPAL MARKETS",
#  'US_BIBLIO': "CITY SERVICES - USE/DON'T USE: PUBLIC LIBRARIES",
#  'US_CC': "CITY SERVICES - USE/DON'T USE: CIVIC CENTERS",
#  'TRANSP_MOU': 'WHICH MEANS OF TRANSPORT DO YOU USE MOST FREQUENTLY ON A DAILY BASIS?',
#  'VAL_TRANSP_1A3': 'IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT BARCELONA IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED',
#  'VAL_TRANSP_BARRI_1A3': 'IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT YOUR NEIGHBORHOOD IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED',
#  'EVO1A_BARRI': 'IN GENERAL, DO YOU THINK YOUR NEIGHBORHOOD HAS IMPROVED OR WORSENED IN THE LAST YEAR?',
#  'FUTUR_BARRI': 'AND FACING THE FUTURE, DO YOU THINK YOUR NEIGHBORHOOD WILL IMPROVE OR GET WORSE?',
#  'SATISF_RES_BARRI_1A4': 'ON A SCALE OF 0 TO 10, 0 BEING NOT SATISFIED AND 10 BEING VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR DEGREE OF SATISFACTION OF LIVING IN YOUR NEIGHBORHOOD? - GROUPED',
#  'COMPARA_BARRI': 'DO YOU THINK YOUR NEIGHBORHOOD IS ONE OF THE BEST OR ONE OF THE WORST?',
#  'CANVI_LLOC_RES_1A3': 'IF YOU HAD THE POSSIBILITY AND THE RESOURCES TO CHANGE YOUR RESIDENCE, WHERE WOULD YOU LIVE?',
#  'VAL_GESTBARRI_1A2': 'ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL IN YOUR NEIGHBORHOOD? - GROUPED',
#  'HAB_COTXE_PART': 'DO YOU HAVE: PRIVATE CAR',
#  'HAB_TREBDOM': 'DO YOU HAVE: REMUNERATED PERSON TO HELP WITH HOMEWORK OR FAMILY CARE',
#  'HAB_REGIM_1A5': 'DO YOU OWN OR DO YOU RENT YOUR HOUSE/FLAT/ROOM?',
#  'HAB_M2_1A14': 'HOW MANY SQUARE METERS DOES YOUR FLAT OR HOUSE HAVE? - GROUPED',
#  'LLAR_INGRESSOS_1A10': 'WHAT IS THE NET MONTHLY INCOME OF ALL MEMBERS OF YOUR HOME? - GROUPED',
#  'CLASSESOC_ENT': 'COULD YOU TELL ME WHAT SOCIAL CLASS DO YOU THINK YOU BELONG TO?',
#  'SENTPERTI': 'BELONGING - SPANISH VS CATALAN',
#  'MUNI_VOTAR': 'HAVE YOU VOTED IN THE LAST MUNICIPAL ELECTIONS?',
#  'LLOC_NAIX_1A4': 'WHAT IS YOUR PLACE OF BIRTH?',
#  'LLENGUA_HAB': 'WHAT IS YOUR USUAL LANGUAGE?',
#  'ESTUDIS_1A6': 'WHAT IS YOUR LEVEL OF FINISHED STUDIES?',
#  'RESUM_PARENTIU': 'WHAT IS THE TYPE OF YOUR FAMILY?',
#  'HAB_RES_1A4': 'WHAT IS THE NUMBER OF PEOPLE LIVING IN THE HOUSE? - GROUPED',
#  'TE_CERT_DISCAP': 'DO YOU HAVE ANY RECOGNIZED DEGREE OF DISABILITY?',
#  'HAB_CERT_DISC': 'DO YOU LIVE WITH A PERSON WITH RECOGNIZED DEGREE OF DISABILITY?'}

# %%
# Filtering the table by choosing only those questions which are relevant for further analysis
survey = survey[list(questions.Nom_variable.unique())]

# %%
survey.head()
# Out:
#         ANY NOM_DISTRICTE NOM_BARRI GRANBARRI  SEXE      EDAT1899_1A6  \
# 57800  2007  CIUTAT VELLA  EL RAVAL  EL RAVAL  HOME   DE 25 A 34 ANYS
# 57801  2007  CIUTAT VELLA  EL RAVAL  EL RAVAL  HOME  DE 65 ANYS I MÉS
# 57802  2007  CIUTAT VELLA  EL RAVAL  EL RAVAL  HOME   DE 25 A 34 ANYS
# 57803  2007  CIUTAT VELLA  EL RAVAL  EL RAVAL  DONA   DE 45 A 54 ANYS
# 57804  2007  CIUTAT VELLA  EL RAVAL  EL RAVAL  HOME   DE 35 A 44 ANYS
#
#               NACIO_ACT_UE                 TMP_RES_BCN_1A6  \
# 57800            ESPANYOLA  MÉS DE 5 ANYS I FINS A 10 ANYS
# 57801            ESPANYOLA    SEMPRE HA VISCUT A LA CIUTAT
# 57802            ESPANYOLA    SEMPRE HA VISCUT A LA CIUTAT
# 57803            ESPANYOLA    SEMPRE HA VISCUT A LA CIUTAT
# 57804  ALTRES UNIÓ EUROPEA                  MÉS DE 10 ANYS
#
#                     TMP_RES_BARRI_1A6    EVO1A_BCN  ...  \
# 57800  MÉS DE 5 ANYS I FINS A 10 ANYS  HA MILLORAT  ...
# 57801       SEMPRE HA VISCUT AL BARRI  HA MILLORAT  ...
# 57802       SEMPRE HA VISCUT AL BARRI   ESTÀ IGUAL  ...
# 57803   MÉS DE 2 ANYS I FINS A 5 ANYS  HA MILLORAT  ...
# 57804                  MÉS DE 10 ANYS  HA MILLORAT  ...
#
#                 CLASSESOC_ENT                SENTPERTI MUNI_VOTAR  \
# 57800  CLASSE MITJANA-MITJANA  MÉS ESPANYOL QUE CATALÀ        NaN
# 57801    CLASSE MITJANA-BAIXA  TAN ESPANYOL COM CATALÀ        NaN
# 57802  CLASSE MITJANA-MITJANA  TAN ESPANYOL COM CATALÀ        NaN
# 57803    CLASSE MITJANA-BAIXA  TAN ESPANYOL COM CATALÀ        NaN
# 57804  CLASSE MITJANA-MITJANA  TAN ESPANYOL COM CATALÀ        NaN
#
#           LLOC_NAIX_1A4 LLENGUA_HAB               ESTUDIS_1A6  \
# 57800         ESTRANGER    CASTELLÀ  SECUNDARIS PROFESSIONALS
# 57801  BARCELONA CIUTAT      CATALÀ               OBLIGATORIS
# 57802  BARCELONA CIUTAT    CASTELLÀ             UNIVERSITARIS
# 57803  BARCELONA CIUTAT    CASTELLÀ  SECUNDARIS PROFESSIONALS
# 57804         ESTRANGER    CASTELLÀ       SECUNDARIS GENERALS
#
#           RESUM_PARENTIU   HAB_RES_1A4 TE_CERT_DISCAP HAB_CERT_DISC
# 57800  PARELLA AMB FILLS  QUATRE O MÉS            NaN           NaN
# 57801       PARELLA SOLA          DUES            NaN           NaN
# 57802  PARELLA AMB FILLS  QUATRE O MÉS            NaN           NaN
# 57803       PERSONA SOLA           UNA            NaN           NaN
# 57804       PARELLA SOLA          DUES            NaN           NaN
#
# [5 rows x 103 columns]

# %%
# Reading answers dataset with a flag indicating if the answer relates to the question
# which was tagged as relevant for further analysis or not
answers = pd.read_excel('data/survey/survey_filtered/2019_r19006_ESM_Evolucio_BDD_Metainformacio_Respostes_v1_0.xlsx')

# %%
answers = answers.query('Flag == 1')
answers.head()
# Out:
#     Nom_variable  Flag               Resposta                 Answer
# 0  NOM_DISTRICTE     1           CIUTAT VELLA           CIUTAT VELLA
# 1  NOM_DISTRICTE     1               EIXAMPLE               EIXAMPLE
# 2  NOM_DISTRICTE     1       SANTS - MONTJUÏC       SANTS - MONTJUÏC
# 3  NOM_DISTRICTE     1              LES CORTS              LES CORTS
# 4  NOM_DISTRICTE     1  SARRIÀ - SANT GERVASI  SARRIÀ - SANT GERVASI

# %% [markdown]
# As the survey was conducted in Catalan or Spanish and the answers are recorded in Catalan it needs to be translated into English for better understanding of the responses. The survey was initially translated on metadata tables with questions (Preguntas) and answers (Respostes). Below, I create a dictionary translating_answers with question name (Nom_variable) as a key and temp_dict as a value. Temp_dict is a nested dictionary, with Catalan answer as a key and English translation of this answer as a value.

# %%
translating_answers = {}
for i in answers.Nom_variable.unique():
    temp_dict = {}
    temp_dict[str(np.nan)] = np.nan
    df = answers.query('Nom_variable == @i')
    for j in range(len(df)):
        temp_dict[str(df.iloc[j].Resposta)] = df.iloc[j].Answer
    translating_answers[i] = temp_dict

# %%
survey['VAL_BUS_1A2'].unique()
# Out:
# array(['APROVAT (5 A 10)', 'SUSPÈS (0 A 4)', 'NS / NC'], dtype=object)

# %%
translating_answers['VAL_BUS_1A2']
# Out:
# {'nan': nan,
#  'SUSPÈS (0 A 4)': 'BAD (0 TO 4)',
#  'APROVAT (5 A 10)': 'GOOD (5 TO 10)',
#  'NS / NC': "I DON'T KNOW / NO ANSWER"}

# %%
# Using a for loop, the survey is being translated by replacing Catalan version of an answer
# with its English translation using translating_answers dictionary created above.
for column in [i for i in list(survey.columns) if i != "ANY"]:
    translate = translating_answers[column]
    for i in survey[column].unique():
        survey[column].replace(i, translate[str(i)], inplace=True)

# %%
survey['VAL_BUS_1A2'].unique()
# Out:
# array(['GOOD (5 TO 10)', 'BAD (0 TO 4)', "I DON'T KNOW / NO ANSWER"],
#       dtype=object)

# %% [markdown]
# # 1.3. Subsetting the data to 2008-2019 surveys with responses of people aged 65+
# For further analysis we will use the data from 2008-2019 Surveys with responses of people aged 65 years and more. Data from 2008-2018 will be used for training the models and data from 2019 - for testing.

# %%
survey_65 = survey.query('EDAT1899_1A6 == "65 YEARS AND OVER"')

# %%
survey_65.shape
# Out:
# (19582, 103)

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().values.any() == True:
        print(i, survey_65[i].isnull().values.any())
# Out:
# VAL_SOROLL_1A2 True
# VAL_TRAM_1A2 True
# VAL_BICING_1A2 True
# VAL_SPEIS_1A2 True
# VAL_CC_1A2 True
# EVO1A_TRAM True
# EVO1A_BICING True
# EVO1A_SPEIS True
# EVO1A_CC True
# US_APARCA True
# US_TRAM True
# US_BICING True
# US_CC True
# HAB_TREBDOM True
# HAB_REGIM_1A5 True
# MUNI_VOTAR True
# TE_CERT_DISCAP True
# HAB_CERT_DISC True

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().sum() > 1 :
        print(i, survey_65[i].isnull().sum())
# Out:
# VAL_SOROLL_1A2 1441
# VAL_TRAM_1A2 16602
# VAL_BICING_1A2 1441
# VAL_SPEIS_1A2 16602
# VAL_CC_1A2 10433
# EVO1A_TRAM 15102
# EVO1A_BICING 1441
# EVO1A_SPEIS 16602
# EVO1A_CC 10433
# US_APARCA 4371
# US_TRAM 15102
# US_BICING 1441
# US_CC 10433
# HAB_TREBDOM 16602
# HAB_REGIM_1A5 16602
# MUNI_VOTAR 5840
# TE_CERT_DISCAP 18100
# HAB_CERT_DISC 18100

# %% [markdown]
# Columns listed above have many NA values and as these are categorical variables. Those with the highest number of NAs are being removed.

# %%
del survey_65['VAL_TRAM_1A2']
del survey_65['EVO1A_TRAM']
del survey_65['US_TRAM'] 
del survey_65['VAL_BICING_1A2']
del survey_65['EVO1A_BICING']
del survey_65['US_BICING']
del survey_65['VAL_CC_1A2']
del survey_65['EVO1A_CC']
del survey_65['US_CC']
del survey_65['VAL_SPEIS_1A2']
del survey_65['EVO1A_SPEIS']
del survey_65['US_APARCA']
del survey_65['HAB_TREBDOM'] 
del survey_65['HAB_REGIM_1A5']
del survey_65['TE_CERT_DISCAP']
del survey_65['HAB_CERT_DISC']

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().values.any() == True:
        print(i, survey_65[i].isnull().values.any())
# Out:
# VAL_SOROLL_1A2 True
# MUNI_VOTAR True

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().sum() > 1 :
        print(i, survey_65[i].isnull().sum())
# Out:
# VAL_SOROLL_1A2 1441
# MUNI_VOTAR 5840

# %%
survey_65 = survey_65.query('ANY >= 2011').query('EDAT1899_1A6 == "65 YEARS AND OVER"')

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().values.any() == True:
        print(i, survey_65[i].isnull().values.any())

# %%
for i in survey_65.columns:
    if survey_65[i].isnull().sum() > 1 :
        print(i, survey_65[i].isnull().sum())

# %% [markdown]
# After limiting the dataset to surveys from 2011-2019 there are no NA values.

# %%
# Creating a copy of the data subset for further data preparation and features generation
data = survey_65.copy()

# %%
survey_65.shape, data.shape
# Out:
# ((13742, 87), (13742, 87))

# %% [markdown]
# # 1.4. Exploratory Data Analysis and data preparation

# %%
for i in survey_65.columns.tolist():
    print(i, ":", questions_dict[i])
# Out:
# ANY : SURVEY YEAR
# NOM_DISTRICTE : DISTRICT
# NOM_BARRI : BARRI
# GRANBARRI : GRAN BARRI
# SEXE : SEX
# EDAT1899_1A6 : AGE
# NACIO_ACT_UE : WHAT IS YOUR NATIONALITY?
# TMP_RES_BCN_1A6 : HOW LONG HAVE YOU BEEN LIVING IN BARCELONA?
# TMP_RES_BARRI_1A6 : HOW LONG HAVE YOU BEEN LIVING IN THIS NEIGHBORHOOD?
# EVO1A_BCN : DO YOU THINK THAT LAST YEAR BARCELONA HAS IMPROVED OR WORSENED?
# FUTUR_BCN : FACING THE FUTURE, DO YOU THINK BARCELONA WILL IMPROVE OR GET WORSE?
# SATISF_RES_BCN_1A4 : ON A SCALE OF 0 TO 10, BEING 0 NOT SATISFIED AND 10 VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR SATISFACTION DEGREE OF LIVING IN THE CITY OF BARCELONA? - GROUPED
# VAL_GESTMUNI_1A2 : ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 BEING VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL? - GROUPED
# VAL_ESCOMBRARIES_1A2 : CITY SERVICES - RATE: GARBAGE COLLECTION - GROUPED
# VAL_NETEJA_1A2 : CITY SERVICES - RATE: STREETS CLEANING - GROUPED
# VAL_SOROLL_1A2 : CITY SERVICES - RATE: NOISE - GROUPED
# VAL_VERD_1A2 : CITY SERVICES - RATE: GREEN AREAS - GROUPED
# VAL_ENLLUM_1A2 : CITY SERVICES - RATE: PUBLIC LIGHTING - GROUPED
# VAL_URBA_1A2 : CITY SERVICES - RATE: URBANISM - GROUPED
# VAL_ASFALT_1A2 : CITY SERVICES - RATE: ASPHALT AND STREET CONSERVATION - GROUPED
# VAL_FACANES_1A2 : CITY SERVICES - RATE: FACADES AND BUILDING CONSERVATION - GROUPED
# VAL_CIRCUL_1A2 : CITY SERVICES - RATE: CIRCULATION - GROUPED
# VAL_APARCA_1A2 : CITY SERVICES - RATE: PARKING - GROUPED
# VAL_BUS_1A2 : CITY SERVICES - RATE: BUS - GROUPED
# VAL_METRO_1A2 : CITY SERVICES - RATE: SUBWAY - GROUPED
# VAL_GUB_1A2 : CITY SERVICES - RATE: MUNICIPAL POLICE - GROUPED
# VAL_SEGUR_1A2 : CITY SERVICES - RATE: CITIZEN SECURITY IN THE CITY AS A WHOLE - GROUPED
# VAL_SEGUR_BARRI_1A2 : CITY SERVICES - RATE: CITIZEN SECURITY IN THE NEIGHBORHOOD - GROUPED
# VAL_ESPORT_1A2 : CITY SERVICES - RATE: SPORTS FACILITIES - GROUPED
# VAL_SIAC_1A2 : CITY SERVICES - RATE: CITIZEN INFORMATION AND ATTENTION SERVICES - GROUPED
# VAL_CSS_1A2 : CITY SERVICES - RATE: SOCIAL SERVICES CENTERS - GROUPED
# VAL_CULT_1A2 : CITY SERVICES - RATE: CULTURAL ACTIVITIES - GROUPED
# VAL_FESTESPOP_1A2 : CITY SERVICES - RATE: POPULAR FESTIVALS - GROUPED
# VAL_MERCAT_1A2 : CITY SERVICES - RATE: MUNICIPAL MARKETS - GROUPED
# VAL_BIBLIO_1A2 : CITY SERVICES - RATE: PUBLIC LIBRARIES - GROUPED
# EVO1A_ESCOMBRARIES : CITY SERVICES - IMPROVED/WORSENED: GARBAGE COLLECTION
# EVO1A_NETEJA : CITY SERVICES - IMPROVED/WORSENED: STREETS CLEANING
# EVO1A_SOROLL : CITY SERVICES - IMPROVED/WORSENED: NOISE
# EVO1A_VERD : CITY SERVICES - IMPROVED/WORSENED: GREEN AREAS
# EVO1A_ENLLUM : CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIGHTING
# EVO1A_URBA : CITY SERVICES - IMPROVED/WORSENED: URBANISM
# EVO1A_ASFALT : CITY SERVICES - IMPROVED/WORSENED: ASPHALT AND STREET CONSERVATION
# EVO1A_FACANES : CITY SERVICES - IMPROVED/WORSENED: FACADES AND BUILDING CONSERVATION
# EVO1A_CIRCUL : CITY SERVICES - IMPROVED/WORSENED: CIRCULATION
# EVO1A_APARCA : CITY SERVICES - IMPROVED/WORSENED: PARKING
# EVO1A_BUS : CITY SERVICES - IMPROVED/WORSENED: BUS
# EVO1A_METRO : CITY SERVICES - IMPROVED/WORSENED: SUBWAY
# EVO1A_GUB : CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL POLICE
# EVO1A_SEGUR : CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE CITY AS A WHOLE
# EVO1A_SEGUR_BARRI : CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE NEIGHBORHOOD
# EVO1A_ESPORT : CITY SERVICES - IMPROVED/WORSENED: SPORTS FACILITIES
# EVO1A_SIAC : CITY SERVICES - IMPROVED/WORSENED: CITIZEN INFORMATION AND SERVICE SERVICES
# EVO1A_CSS : CITY SERVICES - IMPROVED/WORSENED: SOCIAL SERVICES CENTERS
# EVO1A_CULT : CITY SERVICES - IMPROVED/WORSENED: CULTURAL ACTIVITIES
# EVO1A_FESTESPOP : CITY SERVICES - IMPROVED/WORSENED: POPULAR FESTIVALS
# EVO1A_MERCAT : CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL MARKETS
# EVO1A_BIBLIO : CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIBRARIES
# US_VERD : CITY SERVICES - USE/DON'T USE: GREEN AREAS
# US_BUS : CITY SERVICES - USE/DON'T USE: BUS
# US_METRO : CITY SERVICES - USE/DON'T USE: SUBWAY
# US_ESPORT : CITY SERVICES - USE/DON'T USE: SPORTS FACILITIES
# US_SIAC : CITY SERVICES - USE/DON'T USE: CITIZEN INFORMATION AND SERVICE SERVICES
# US_CSS : CITY SERVICES - USE/DON'T USE: SOCIAL SERVICES CENTERS
# US_CULT : CITY SERVICES - USE/DON'T USE: CULTURAL ACTIVITIES
# US_FESTESPOP : CITY SERVICES - USE/DON'T USE: POPULAR FESTIVALS
# US_MERCAT : CITY SERVICES - USE/DON'T USE: MUNICIPAL MARKETS
# US_BIBLIO : CITY SERVICES - USE/DON'T USE: PUBLIC LIBRARIES
# TRANSP_MOU : WHICH MEANS OF TRANSPORT DO YOU USE MOST FREQUENTLY ON A DAILY BASIS?
# VAL_TRANSP_1A3 : IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT BARCELONA IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED
# VAL_TRANSP_BARRI_1A3 : IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT YOUR NEIGHBORHOOD IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED
# EVO1A_BARRI : IN GENERAL, DO YOU THINK YOUR NEIGHBORHOOD HAS IMPROVED OR WORSENED IN THE LAST YEAR?
# FUTUR_BARRI : AND FACING THE FUTURE, DO YOU THINK YOUR NEIGHBORHOOD WILL IMPROVE OR GET WORSE?
# SATISF_RES_BARRI_1A4 : ON A SCALE OF 0 TO 10, 0 BEING NOT SATISFIED AND 10 BEING VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR DEGREE OF SATISFACTION OF LIVING IN YOUR NEIGHBORHOOD? - GROUPED
# COMPARA_BARRI : DO YOU THINK YOUR NEIGHBORHOOD IS ONE OF THE BEST OR ONE OF THE WORST?
# CANVI_LLOC_RES_1A3 : IF YOU HAD THE POSSIBILITY AND THE RESOURCES TO CHANGE YOUR RESIDENCE, WHERE WOULD YOU LIVE?
# VAL_GESTBARRI_1A2 : ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL IN YOUR NEIGHBORHOOD? - GROUPED
# HAB_COTXE_PART : DO YOU HAVE: PRIVATE CAR
# HAB_M2_1A14 : HOW MANY SQUARE METERS DOES YOUR FLAT OR HOUSE HAVE? - GROUPED
# LLAR_INGRESSOS_1A10 : WHAT IS THE NET MONTHLY INCOME OF ALL MEMBERS OF YOUR HOME? - GROUPED
# CLASSESOC_ENT : COULD YOU TELL ME WHAT SOCIAL CLASS DO YOU THINK YOU BELONG TO?
# SENTPERTI : BELONGING - SPANISH VS CATALAN
# MUNI_VOTAR : HAVE YOU VOTED IN THE LAST MUNICIPAL ELECTIONS?
# LLOC_NAIX_1A4 : WHAT IS YOUR PLACE OF BIRTH?
# LLENGUA_HAB : WHAT IS YOUR USUAL LANGUAGE?
# ESTUDIS_1A6 : WHAT IS YOUR LEVEL OF FINISHED STUDIES?
# RESUM_PARENTIU : WHAT IS THE TYPE OF YOUR FAMILY?
# HAB_RES_1A4 : WHAT IS THE NUMBER OF PEOPLE LIVING IN THE HOUSE? - GROUPED

# %% [markdown]
# ## 1.4.1 Dependent variable

# %% [markdown]
# Survey question: IF YOU HAD THE POSSIBILITY AND THE RESOURCES TO CHANGE YOUR RESIDENCE, WHERE WOULD YOU LIVE?

# %%
survey_65.groupby(['CANVI_LLOC_RES_1A3']).size()
# Out:
# CANVI_LLOC_RES_1A3
# I DON'T KNOW                                           124
# I WOULD LIVE IN ANOTHER NEIGHBORHOOD IN BARCELONA     1321
# I WOULD LIVE OUTSIDE BARCELONA                        1798
# I WOULD STAY LIVING IN THE SAME NEIGHBORHOOD         10498
# NO ANSWER                                                1
# dtype: int64

# %%
survey_65.groupby(['CANVI_LLOC_RES_1A3']).size().plot.bar()

# %%
data_prep = {'I WOULD STAY LIVING IN THE SAME NEIGHBORHOOD': 1,
            'I WOULD LIVE IN ANOTHER NEIGHBORHOOD IN BARCELONA': 0,
             'I WOULD LIVE OUTSIDE BARCELONA': 0,
             "I DON'T KNOW": 0,
             'NO ANSWER': 0
            }
data['Stay_in_the_same_neighborhood'] = [data_prep[i] for i in data['CANVI_LLOC_RES_1A3']]

# %%
count_stay = len(data[data['Stay_in_the_same_neighborhood']==1])
count_move = len(data[data['Stay_in_the_same_neighborhood']==0])
pct_of_stay = count_stay/len(data)
print("Number of elderly who would stay in their neighborhood:", count_stay)
print("Percentage of elderly who would stay in their neighborhood:", round(pct_of_stay*100,2), '%')
pct_of_move = count_move/len(data)
print("Number of elderly who would hange their neighborhood or move out from the city:", count_move)
print("Percentage of elderly who would change their neighborhood or move out from the city:", round(pct_of_move*100,2), '%')
# Out:
# Number of elderly who would stay in their neighborhood: 10498
# Percentage of elderly who would stay in their neighborhood: 76.39 %
# Number of elderly who would hange their neighborhood or move out from the city: 3244
# Percentage of elderly who would change their neighborhood or move out from the city: 23.61 %

# %% [markdown]
# The dataset is highly inbalances - there are more responses of people who would like to stay in their neighborhood than of those who would like to change it or move outside Barcelona. To be able to find the predictors of willigness to stay, I will have to oversample the minority class.

# %% [markdown]
# ## 1.4.2 Independent variables

# %% [markdown]
# First insight into the dataset using cross tablation of dependent variable and different features:

# %%
for i in data.columns.tolist():
    display(pd.crosstab(data[i], data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood    0     1
# ANY
# 2011                           387  1131
# 2012                           378  1149
# 2013                           344  1204
# 2014                           348  1195
# 2015                           341  1225
# 2016                           315  1245
# 2017                           275  1225
# 2018                           439  1059
# 2019                           417  1065
# Stay_in_the_same_neighborhood    0     1
# NOM_DISTRICTE
# CIUTAT VELLA                   313   679
# EIXAMPLE                       403  1769
# GRÀCIA                         218   868
# HORTA - GUINARDÓ               385  1200
# LES CORTS                      139   969
# NOU BARRIS                     492  1051
# SANT ANDREU                    287   867
# SANT MARTÍ                     411  1239
# SANTS - MONTJUÏC               420   898
# SARRIÀ - SANT GERVASI          176   958
# Stay_in_the_same_neighborhood           0    1
# NOM_BARRI
# BARÓ DE VIVER                          13   17
# CAN BARÓ                               29   57
# CAN PEGUERA                             5   15
# CANYELLES                              29   78
# CIUTAT MERIDIANA                       98   50
# ...                                    ..  ...
# VALLBONA                               13    7
# VALLCARCA I ELS PENITENTS              31  133
# VALLVIDRERA, EL TIBIDABO I LES PLANES   5   24
# VERDUN                                 28   74
# VILAPICINA I LA TORRE LLOBETA          50  131
#
# [73 rows x 2 columns]
# Stay_in_the_same_neighborhood                         0    1
# GRANBARRI
# CANYELLES, LES ROQUETES I LA TRINITAT NOVA          132  239
# EL BARRI GÒTIC                                       53  163
# EL BESÒS, EL MARESME I PROVENÇALS                   101  209
# EL CAMP D'EN GRASSOT I GRÀCIA NOVA                   71  314
# EL CARMEL I CAN BARÓ                                131  249
# EL CLOT I EL CAMP DE L'ARPA                          91  258
# EL FORT PIENC                                        79  270
# EL GUINARDÓ                                          89  288
# EL PARC, LA LLACUNA I LA VILA OLÍMPICA               63  212
# EL POBLE SEC                                        111  181
# EL POBLENOU I DIAGONAL MAR                           40  243
# EL RAVAL                                            115  122
# ELS BARRIS DE LA VALL D'HEBRON                      107  303
# HORTA I LA FONT D'EN FARGUES                         58  360
# L'ANTIGA ESQUERRA DE L'EIXAMPLE                      69  293
# LA BARCELONETA                                       61  217
# LA DRETA DE L'EIXAMPLE                               53  305
# LA FONT DE LA GUATLLA, HOSTAFRANCS I LA BORDETA     107  229
# LA GUINEUETA, VERDUN I LA PROSPERITAT               114  373
# LA MARINA                                           119  220
# LA MATERNITAT I SANT RAMON                           63  394
# LA NOVA ESQUERRA DE L'EIXAMPLE                       74  294
# LA SAGRADA FAMÍLIA                                   71  291
# LA SAGRERA, EL CONGRÉS I NAVAS                       97  346
# LA TRINITAT VELLA, BARÓ DE VIVER I EL BON PASTOR    137  178
# LA VILA DE GRÀCIA                                    63  259
# LES CORTS                                            46  415
# PEDRALBES                                            30  160
# SANT ANDREU                                          53  343
# SANT ANTONI                                          57  316
# SANT GERVASI-GALVANY                                 63  335
# SANT GERVASI-LA BONANOVA I EL PUTXET                 66  304
# SANT MARTÍ, LA VERNEDA I LA PAU                     116  317
# SANT PERE, SANTA CATERINA I LA RIBERA                84  177
# SANTS I SANTS-BADAL                                  83  268
# SARRIÀ, LES TRES TORRES I VALLVIDRERA                47  319
# TORRE BARÓ, CIUTAT MERIDIANA I VALLBONA             117   81
# VALLCARCA, EL COLL I LA SALUT                        84  295
# VILAPICINA, PORTA, EL TURÓ DE LA PEIRA I CAN PE...  129  358
# Stay_in_the_same_neighborhood     0     1
# SEXE
# MAN                            1414  4099
# WOMAN                          1830  6399
# Stay_in_the_same_neighborhood     0      1
# EDAT1899_1A6
# 65 YEARS AND OVER              3244  10498
# Stay_in_the_same_neighborhood     0      1
# NACIO_ACT_UE
# OTHER EU                         16     88
# REMAINING COUNTRIES              33     88
# SPANISH                        3195  10322
# Stay_in_the_same_neighborhood            0     1
# TMP_RES_BCN_1A6
# FROM 6 MONTHS TO 2 YEARS                21    37
# I HAVE ALWAYS LIVED IN THE CITY       1322  4402
# MORE THAN 10 YEARS                    1850  5931
# MORE THAN 2 YEARS AND UP TO 5 YEARS     24    60
# MORE THAN 5 YEARS AND UP TO 10 YEARS    27    68
# Stay_in_the_same_neighborhood            0     1
# TMP_RES_BARRI_1A6
# FROM 6 MONTHS TO 2 YEARS                61   118
# I HAVE ALWAYS LIVED IN THE BARRI       311  1449
# LESS THAN SIX MONTHS                    16    33
# MORE THAN 10 YEARS                    2649  8525
# MORE THAN 2 YEARS AND UP TO 5 YEARS     93   143
# MORE THAN 5 YEARS AND UP TO 10 YEARS   114   230
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BCN
# I DON'T KNOW                     91   288
# IT HAS IMPROVED                 772  3355
# IT'S THE SAME                   747  2858
# IT'S WORSE                     1628  3992
# NO ANSWER                         6     5
# Stay_in_the_same_neighborhood     0     1
# FUTUR_BCN
# I DON'T KNOW                    502  1609
# IT WILL IMPROVE                1382  5385
# IT WILL STAY THE SAME           325  1024
# IT WILL WORSE                  1029  2471
# NO ANSWER                         6     9
# Stay_in_the_same_neighborhood       0     1
# SATISF_RES_BCN_1A4
# FAIRLY SATISFIED (5 to 6)         584   883
# I DON'T KNOW / NO ANSWER           13    42
# LITTLE / NOT SATISFIED (0 TO 4)   258   190
# SATISFIED (7 TO 8)               1362  4328
# VERY SATISFIED (9 TO 10)         1027  5055
# Stay_in_the_same_neighborhood     0     1
# VAL_GESTMUNI_1A2
# BAD (0 TO 4)                    756  1584
# GOOD (5 TO 10)                 2338  8413
# I DON'T KNOW / NO ANSWER        150   501
# Stay_in_the_same_neighborhood     0     1
# VAL_ESCOMBRARIES_1A2
# BAD (0 TO 4)                    270   504
# GOOD (5 TO 10)                 2958  9954
# I DON'T KNOW / NO ANSWER         16    40
# Stay_in_the_same_neighborhood     0     1
# VAL_NETEJA_1A2
# BAD (0 TO 4)                    739  1568
# GOOD (5 TO 10)                 2500  8903
# I DON'T KNOW / NO ANSWER          5    27
# Stay_in_the_same_neighborhood     0     1
# VAL_SOROLL_1A2
# BAD (0 TO 4)                   1341  2940
# GOOD (5 TO 10)                 1827  7223
# I DON'T KNOW / NO ANSWER         76   335
# Stay_in_the_same_neighborhood     0     1
# VAL_VERD_1A2
# BAD (0 TO 4)                    763  1591
# GOOD (5 TO 10)                 2365  8396
# I DON'T KNOW / NO ANSWER        116   511
# Stay_in_the_same_neighborhood     0     1
# VAL_ENLLUM_1A2
# BAD (0 TO 4)                    390   882
# GOOD (5 TO 10)                 2797  9430
# I DON'T KNOW / NO ANSWER         57   186
# Stay_in_the_same_neighborhood     0     1
# VAL_URBA_1A2
# BAD (0 TO 4)                    564  1064
# GOOD (5 TO 10)                 2295  8176
# I DON'T KNOW / NO ANSWER        385  1258
# Stay_in_the_same_neighborhood     0     1
# VAL_ASFALT_1A2
# BAD (0 TO 4)                    943  2122
# GOOD (5 TO 10)                 2258  8246
# I DON'T KNOW / NO ANSWER         43   130
# Stay_in_the_same_neighborhood     0     1
# VAL_FACANES_1A2
# BAD (0 TO 4)                    528  1076
# GOOD (5 TO 10)                 2528  8748
# I DON'T KNOW / NO ANSWER        188   674
# Stay_in_the_same_neighborhood     0     1
# VAL_CIRCUL_1A2
# BAD (0 TO 4)                   1173  3066
# GOOD (5 TO 10)                 1917  6873
# I DON'T KNOW / NO ANSWER        154   559
# Stay_in_the_same_neighborhood     0     1
# VAL_APARCA_1A2
# BAD (0 TO 4)                   2009  5709
# GOOD (5 TO 10)                  800  3150
# I DON'T KNOW / NO ANSWER        435  1639
# Stay_in_the_same_neighborhood     0     1
# VAL_BUS_1A2
# BAD (0 TO 4)                    413   893
# GOOD (5 TO 10)                 2675  9023
# I DON'T KNOW / NO ANSWER        156   582
# Stay_in_the_same_neighborhood     0     1
# VAL_METRO_1A2
# BAD (0 TO 4)                    135   266
# GOOD (5 TO 10)                 2777  8891
# I DON'T KNOW / NO ANSWER        332  1341
# Stay_in_the_same_neighborhood     0     1
# VAL_GUB_1A2
# BAD (0 TO 4)                    800  1722
# GOOD (5 TO 10)                 2076  7494
# I DON'T KNOW / NO ANSWER        368  1282
# Stay_in_the_same_neighborhood     0     1
# VAL_SEGUR_1A2
# BAD (0 TO 4)                   1281  3167
# GOOD (5 TO 10)                 1804  6799
# I DON'T KNOW / NO ANSWER        159   532
# Stay_in_the_same_neighborhood     0     1
# VAL_SEGUR_BARRI_1A2
# BAD (0 TO 4)                   1246  2505
# GOOD (5 TO 10)                 1948  7862
# I DON'T KNOW / NO ANSWER         50   131
# Stay_in_the_same_neighborhood     0     1
# VAL_ESPORT_1A2
# BAD (0 TO 4)                    471   834
# GOOD (5 TO 10)                 1618  5379
# I DON'T KNOW / NO ANSWER       1155  4285
# Stay_in_the_same_neighborhood     0     1
# VAL_SIAC_1A2
# BAD (0 TO 4)                    293   555
# GOOD (5 TO 10)                 2094  6946
# I DON'T KNOW / NO ANSWER        857  2997
# Stay_in_the_same_neighborhood     0     1
# VAL_CSS_1A2
# BAD (0 TO 4)                    370   712
# GOOD (5 TO 10)                 1508  5350
# I DON'T KNOW / NO ANSWER       1366  4436
# Stay_in_the_same_neighborhood     0     1
# VAL_CULT_1A2
# BAD (0 TO 4)                    202   350
# GOOD (5 TO 10)                 1987  6915
# I DON'T KNOW / NO ANSWER       1055  3233
# Stay_in_the_same_neighborhood     0     1
# VAL_FESTESPOP_1A2
# BAD (0 TO 4)                    346   624
# GOOD (5 TO 10)                 2074  7482
# I DON'T KNOW / NO ANSWER        824  2392
# Stay_in_the_same_neighborhood     0     1
# VAL_MERCAT_1A2
# BAD (0 TO 4)                    297   628
# GOOD (5 TO 10)                 2664  8813
# I DON'T KNOW / NO ANSWER        283  1057
# Stay_in_the_same_neighborhood     0     1
# VAL_BIBLIO_1A2
# BAD (0 TO 4)                     71   164
# GOOD (5 TO 10)                 2036  6340
# I DON'T KNOW / NO ANSWER       1137  3994
# Stay_in_the_same_neighborhood     0     1
# EVO1A_ESCOMBRARIES
# I DON'T KNOW                     51   139
# IT HAS IMPROVED                1170  4037
# IT'S THE SAME                  1651  5501
# IT'S WORSE                      371   816
# NO ANSWER                         1     5
# Stay_in_the_same_neighborhood     0     1
# EVO1A_NETEJA
# I DON'T KNOW                     38    90
# IT HAS IMPROVED                 934  3534
# IT'S THE SAME                  1343  4563
# IT'S WORSE                      928  2308
# NO ANSWER                         1     3
# Stay_in_the_same_neighborhood     0     1
# EVO1A_SOROLL
# I DON'T KNOW                     80   316
# IT HAS IMPROVED                 376  1502
# IT'S THE SAME                  1494  5672
# IT'S WORSE                     1294  3006
# NO ANSWER                         0     2
# Stay_in_the_same_neighborhood     0     1
# EVO1A_VERD
# I DON'T KNOW                    183   645
# IT HAS IMPROVED                 894  3354
# IT'S THE SAME                  1399  4635
# IT'S WORSE                      766  1857
# NO ANSWER                         2     7
# Stay_in_the_same_neighborhood     0     1
# EVO1A_ENLLUM
# I DON'T KNOW                     86   258
# IT HAS IMPROVED                 834  3025
# IT'S THE SAME                  1887  6147
# IT'S WORSE                      435  1064
# NO ANSWER                         2     4
# Stay_in_the_same_neighborhood     0     1
# EVO1A_URBA
# I DON'T KNOW                    376  1225
# IT HAS IMPROVED                 882  3326
# IT'S THE SAME                  1365  4511
# IT'S WORSE                      619  1433
# NO ANSWER                         2     3
# Stay_in_the_same_neighborhood     0     1
# EVO1A_ASFALT
# I DON'T KNOW                     61   187
# IT HAS IMPROVED                 750  2973
# IT'S THE SAME                  1349  4541
# IT'S WORSE                     1084  2796
# NO ANSWER                         0     1
# Stay_in_the_same_neighborhood     0     1
# EVO1A_FACANES
# I DON'T KNOW                    217   683
# IT HAS IMPROVED                1055  4089
# IT'S THE SAME                  1376  4380
# IT'S WORSE                      593  1336
# NO ANSWER                         3    10
# Stay_in_the_same_neighborhood     0     1
# EVO1A_CIRCUL
# I DON'T KNOW                    176   614
# IT HAS IMPROVED                 405  1476
# IT'S THE SAME                  1280  4722
# IT'S WORSE                     1382  3682
# NO ANSWER                         1     4
# Stay_in_the_same_neighborhood     0     1
# EVO1A_APARCA
# I DON'T KNOW                    453  1705
# IT HAS IMPROVED                 134   662
# IT'S THE SAME                   757  2791
# IT'S WORSE                     1898  5333
# NO ANSWER                         2     7
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BUS
# I DON'T KNOW                    198   688
# IT HAS IMPROVED                1265  4418
# IT'S THE SAME                  1185  3883
# IT'S WORSE                      596  1506
# NO ANSWER                         0     3
# Stay_in_the_same_neighborhood     0     1
# EVO1A_METRO
# I DON'T KNOW                    373  1490
# IT HAS IMPROVED                1184  3821
# IT'S THE SAME                  1505  4732
# IT'S WORSE                      179   448
# NO ANSWER                         3     7
# Stay_in_the_same_neighborhood     0     1
# EVO1A_GUB
# I DON'T KNOW                    429  1466
# IT HAS IMPROVED                 489  1836
# IT'S THE SAME                  1611  5610
# IT'S WORSE                      709  1578
# NO ANSWER                         6     8
# Stay_in_the_same_neighborhood     0     1
# EVO1A_SEGUR
# I DON'T KNOW                    205   648
# IT HAS IMPROVED                 346  1377
# IT'S THE SAME                  1185  4316
# IT'S WORSE                     1508  4151
# NO ANSWER                         0     6
# Stay_in_the_same_neighborhood     0     1
# EVO1A_SEGUR_BARRI
# I DON'T KNOW                     80   219
# IT HAS IMPROVED                 365  1763
# IT'S THE SAME                  1383  5278
# IT'S WORSE                     1416  3232
# NO ANSWER                         0     6
# Stay_in_the_same_neighborhood     0     1
# EVO1A_ESPORT
# I DON'T KNOW                   1215  4515
# IT HAS IMPROVED                 520  1752
# IT'S THE SAME                  1253  3673
# IT'S WORSE                      250   544
# NO ANSWER                         6    14
# Stay_in_the_same_neighborhood     0     1
# EVO1A_SIAC
# I DON'T KNOW                    936  3218
# IT HAS IMPROVED                 638  2325
# IT'S THE SAME                  1404  4414
# IT'S WORSE                      262   531
# NO ANSWER                         4    10
# Stay_in_the_same_neighborhood     0     1
# EVO1A_CSS
# I DON'T KNOW                   1468  4708
# IT HAS IMPROVED                 497  1876
# IT'S THE SAME                   814  2880
# IT'S WORSE                      458  1018
# NO ANSWER                         7    16
# Stay_in_the_same_neighborhood     0     1
# EVO1A_CULT
# I DON'T KNOW                   1132  3459
# IT HAS IMPROVED                 681  2408
# IT'S THE SAME                  1193  4149
# IT'S WORSE                      234   469
# NO ANSWER                         4    13
# Stay_in_the_same_neighborhood     0     1
# EVO1A_FESTESPOP
# I DON'T KNOW                    876  2616
# IT HAS IMPROVED                 542  2133
# IT'S THE SAME                  1328  4626
# IT'S WORSE                      494  1117
# NO ANSWER                         4     6
# Stay_in_the_same_neighborhood     0     1
# EVO1A_MERCAT
# I DON'T KNOW                    307  1170
# IT HAS IMPROVED                1314  4423
# IT'S THE SAME                  1138  3715
# IT'S WORSE                      483  1187
# NO ANSWER                         2     3
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BIBLIO
# I DON'T KNOW                   1231  4271
# IT HAS IMPROVED                 931  2811
# IT'S THE SAME                  1016  3248
# IT'S WORSE                       61   153
# NO ANSWER                         5    15
# Stay_in_the_same_neighborhood     0     1
# US_VERD
# DO NOT USE                     1175  3662
# NO ANSWER                         3     7
# USE                            2066  6829
# Stay_in_the_same_neighborhood     0     1
# US_BUS
# DO NOT USE                      517  1854
# NO ANSWER                         1     2
# USE                            2726  8642
# Stay_in_the_same_neighborhood     0     1
# US_METRO
# DO NOT USE                      925  3375
# NO ANSWER                         0     6
# USE                            2319  7117
# Stay_in_the_same_neighborhood     0     1
# US_ESPORT
# DO NOT USE                     2662  8850
# NO ANSWER                        14    40
# USE                             568  1608
# Stay_in_the_same_neighborhood     0     1
# US_SIAC
# DO NOT USE                     1847  6169
# NO ANSWER                         5    11
# USE                            1392  4318
# Stay_in_the_same_neighborhood     0     1
# US_CSS
# DO NOT USE                     2310  7394
# NO ANSWER                        12    23
# USE                             922  3081
# Stay_in_the_same_neighborhood     0     1
# US_CULT
# DO NOT USE                     2081  6582
# NO ANSWER                         5    13
# USE                            1158  3903
# Stay_in_the_same_neighborhood     0     1
# US_FESTESPOP
# DO NOT USE                     1925  5959
# NO ANSWER                         5    11
# USE                            1314  4528
# Stay_in_the_same_neighborhood     0     1
# US_MERCAT
# DO NOT USE                      836  3067
# NO ANSWER                         0     2
# USE                            2408  7429
# Stay_in_the_same_neighborhood     0     1
# US_BIBLIO
# DO NOT USE                     2030  7072
# NO ANSWER                         9    13
# USE                            1205  3413
# Stay_in_the_same_neighborhood            0     1
# TRANSP_MOU
# BICYCLE                                 10    31
# BICYCLE (BICING)                         5    10
# BUS                                   1429  4586
# CAR                                    175   534
# METRO / CATALAN RAILWAYS (FGC) URBAN  1040  3170
# MOTORCYCLE                              44    91
# NO ANSWER                                1     1
# OTHERS                                  12    29
# TAXI                                    59   376
# TRAIN (RENFE / FGC INTERURBAN)           9    30
# TRAM (TRAM, TRAMBAIX, TRAMBESÒS)        15    41
# WALKING                                445  1599
# Stay_in_the_same_neighborhood     0     1
# VAL_TRANSP_1A3
# I DON'T KNOW / NO ANSWER         66   208
# LITTLE / NOTHING EQUIPPED       357   779
# NORMAL                          314   866
# VERY / FAIRLY GIFTED           2507  8645
# Stay_in_the_same_neighborhood     0     1
# VAL_TRANSP_BARRI_1A3
# I DON'T KNOW / NO ANSWER         22    70
# LITTLE / NOTHING EQUIPPED       488  1162
# NORMAL                          331   809
# VERY / FAIRLY GIFTED           2403  8457
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BARRI
# I DON'T KNOW                     43    86
# IT HAS IMPROVED                1242  5384
# IT'S THE SAME                   852  3135
# IT'S WORSE                     1107  1891
# NO ANSWER                         0     2
# Stay_in_the_same_neighborhood     0     1
# FUTUR_BARRI
# I DON'T KNOW                    493  1392
# IT WILL GET WORSE               876  1395
# IT WILL IMPROVE                1319  5720
# IT WILL STAY THE SAME           556  1988
# NO ANSWER                         0     3
# Stay_in_the_same_neighborhood       0     1
# SATISF_RES_BARRI_1A4
# FAIRLY SATISFIED (5 to 6)         661   616
# I DON'T KNOW / NO ANSWER           15    26
# LITTLE / NOT SATISFIED (0 TO 4)   336    87
# SATISFIED (7 TO 8)               1496  4652
# VERY SATISFIED (9 TO 10)          736  5117
# Stay_in_the_same_neighborhood       0     1
# COMPARA_BARRI
# I DON'T KNOW                       89   225
# NEITHER THE BEST, NOR THE WORST  1773  3673
# NO ANSWER                           4     4
# ONE OF THE BEST                   954  6357
# ONE OF THE WORST                  424   239
# Stay_in_the_same_neighborhood                         0      1
# CANVI_LLOC_RES_1A3
# I DON'T KNOW                                        124      0
# I WOULD LIVE IN ANOTHER NEIGHBORHOOD IN BARCELONA  1321      0
# I WOULD LIVE OUTSIDE BARCELONA                     1798      0
# I WOULD STAY LIVING IN THE SAME NEIGHBORHOOD          0  10498
# NO ANSWER                                             1      0
# Stay_in_the_same_neighborhood     0     1
# VAL_GESTBARRI_1A2
# BAD (0 TO 4)                    654   926
# GOOD (5 TO 10)                 2270  8670
# I DON'T KNOW / NO ANSWER        320   902
# Stay_in_the_same_neighborhood     0     1
# HAB_COTXE_PART
# I DON'T KNOW                      2     2
# I DON'T WANT / I DON'T NEED     284   848
# IT'S NOT POSSIBLE                72   151
# NO                             1131  4352
# NO ANSWER                        20    72
# YES                            1735  5073
# Stay_in_the_same_neighborhood    0     1
# HAB_M2_1A14
# FROM 101 TO 110 M2              28    79
# FROM 101 TO 120 M2             128   616
# FROM 111 TO 120 M2              25    70
# FROM 121 TO 130 M2              15    42
# FROM 121 TO 150 M2              70   376
# FROM 131 TO 140 M2              12    38
# FROM 141 TO 150 M2               9    28
# FROM 151 TO 160 M2               2    14
# FROM 161 TO 170 M2               5    18
# FROM 51 TO 60 M2               435  1147
# FROM 61 TO 70 M2               723  1959
# FROM 71 TO 80 M2               551  1687
# FROM 81 TO 90 M2               392  1298
# FROM 91 TO 100 M2              279  1021
# I DON'T KNOW                   164   759
# MORE THAN 150 M2                72   360
# MORE THAN 170 M2                15    60
# NO ANSWER                       61   219
# UP TO 50 M2                    258   707
# Stay_in_the_same_neighborhood    0     1
# LLAR_INGRESSOS_1A10
# FROM 1,001 TO 1,500 EUROS      648  2018
# FROM 1,501 TO 2,000 EUROS      447  1253
# FROM 2,001 TO 2,500 EUROS      214   724
# FROM 2,501 TO 3,000 EUROS      138   414
# FROM 3,001 TO 5,000 EUROS      138   507
# FROM 5,001 TO 7,000 EUROS        4    26
# FROM 500 TO 1,000 EUROS        750  2340
# FROM 7,001 TO 9,000 EUROS        1     5
# I DON'T KNOW                   137   616
# LESS THAN 500 EUROS             72   214
# MORE THAN 5,000 EUROS           12    57
# MORE THAN 9,000 EUROS            5     8
# NO ANSWER                      678  2316
# Stay_in_the_same_neighborhood     0     1
# CLASSESOC_ENT
# HIGH CLASS                        3    41
# I DON'T KNOW                     74   252
# LOW CLASS                       435  1042
# MIDDLE-HIGH CLASS               101   480
# MIDDLE-LOW CLASS               1168  3278
# MIDDLE-MIDDLE CLASS            1418  5268
# NO ANSWER                        45   137
# Stay_in_the_same_neighborhood     0     1
# SENTPERTI
# HALF SPANISH, HALF CATALAN     1168  3892
# I DON'T KNOW                     26    65
# MORE CATALAN THAN SPANISH       742  2633
# MORE SPANISH THAN CATALAN       242   604
# NO ANSWER                        46   126
# ONLY CATALAN                    637  2202
# ONLY SPANISH                    303   785
# OTHER                            80   191
# Stay_in_the_same_neighborhood                         0     1
# MUNI_VOTAR
# I CANNOT VOTE (NATIONALITY, AGE, CENSUS PROBLEMS)    36   130
# I DID NOT VOTE                                      448  1302
# I DON'T REMEMBER IF I VOTED                          54   199
# IT WASN'T CENSUSED IN THE CITY                       40    77
# NO ANSWER                                            19    93
# VOTED                                              2647  8697
# Stay_in_the_same_neighborhood     0     1
# LLOC_NAIX_1A4
# BARCELONA CITY                 1440  4710
# FOREIGN                         135   449
# NO ANSWER                         1     9
# REST OF CATALONIA               361  1290
# REST OF SPAIN                  1307  4040
# Stay_in_the_same_neighborhood     0     1
# LLENGUA_HAB
# CATALAN                        1551  5578
# NO ANSWER                         3     6
# OTHER                            28    54
# SPANISH                        1662  4860
# Stay_in_the_same_neighborhood            0     1
# ESTUDIS_1A6
# COMPULSORY STUDIES HAVE NOT FINISHED   357  1152
# GENERAL SECONDARY                      466  1425
# MANDATORY                             1301  4403
# NO ANSWER                               10    39
# POST UNIVERSITY                         36    96
# PROFESSIONAL SECONDARY                 493  1521
# UNIVERSITY                             581  1862
# Stay_in_the_same_neighborhood     0     1
# RESUM_PARENTIU
# COUPLE WITH CHILDREN            422  1092
# COUPLE WITH NO CHILDREN        1430  4599
# NO ANSWER                         0     1
# OTHER FAMILY                    141   412
# OTHER SITUATIONS                 26   154
# SINGLE                          886  3172
# SINGLE-PARENT WITH CHILDREN     339  1068
# Stay_in_the_same_neighborhood     0     1
# HAB_RES_1A4
# FOUR OR MORE                    184   508
# ONE                             886  3172
# THREE                           425  1226
# TWO                            1749  5592
# Stay_in_the_same_neighborhood     0      1
# Stay_in_the_same_neighborhood
# 0                              3244      0
# 1                                 0  10498

# %% [markdown]
# Some of the features will be used only for statistical description of the sample. Some will be used as independent variables in further modeling. Others will be ignored/dropped.

# %% [markdown]
# * ANY : SURVEY YEAR - statistical description
#
#
# * NOM_DISTRICTE : DISTRICT - statistical description
# * NOM_BARRI : BARRI - statistical description
# * GRANBARRI : GRAN BARRI - statistical description
#
#
# * SEXE : SEX - statistical description + modeling
# * EDAT1899_1A6 : AGE - dropped (there is only one age group as the dataset was limited to responses of people aged 65 years and more)
# * NACIO_ACT_UE : WHAT IS YOUR NATIONALITY? - statistical description
#
#
# * TMP_RES_BCN_1A6 : HOW LONG HAVE YOU BEEN LIVING IN BARCELONA? - statistical description
# * TMP_RES_BARRI_1A6 : HOW LONG HAVE YOU BEEN LIVING IN THIS NEIGHBORHOOD? - statistical description + modeling
#
#
# * EVO1A_BCN : DO YOU THINK THAT LAST YEAR BARCELONA HAS IMPROVED OR WORSENED? - statistical description + modeling
# * FUTUR_BCN : FACING THE FUTURE, DO YOU THINK BARCELONA WILL IMPROVE OR GET WORSE? - statistical description + modeling
# * SATISF_RES_BCN_1A4 : ON A SCALE OF 0 TO 10, BEING 0 NOT SATISFIED AND 10 VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR SATISFACTION DEGREE OF LIVING IN THE CITY OF BARCELONA? - GROUPED - statistical description + modeling
# * VAL_GESTMUNI_1A2 : ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 BEING VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL? - GROUPED - statistical description + modeling
#
#
# * VAL_ESCOMBRARIES_1A2 : CITY SERVICES - RATE: GARBAGE COLLECTION - GROUPED - modeling
# * VAL_NETEJA_1A2 : CITY SERVICES - RATE: STREETS CLEANING - GROUPED - modeling
# * VAL_SOROLL_1A2 : CITY SERVICES - RATE: NOISE - GROUPED - modeling
# * VAL_VERD_1A2 : CITY SERVICES - RATE: GREEN AREAS - GROUPED - modeling
# * VAL_ENLLUM_1A2 : CITY SERVICES - RATE: PUBLIC LIGHTING - GROUPED - modeling
# * VAL_URBA_1A2 : CITY SERVICES - RATE: URBANISM - GROUPED - modeling
# * VAL_ASFALT_1A2 : CITY SERVICES - RATE: ASPHALT AND STREET CONSERVATION - GROUPED - modeling
# * VAL_FACANES_1A2 : CITY SERVICES - RATE: FACADES AND BUILDING CONSERVATION - GROUPED - modeling
# * VAL_CIRCUL_1A2 : CITY SERVICES - RATE: CIRCULATION - GROUPED - modeling
# * VAL_APARCA_1A2 : CITY SERVICES - RATE: PARKING - GROUPED - modeling
# * VAL_BUS_1A2 : CITY SERVICES - RATE: BUS - GROUPED - dropped (other variable will be used to evaluate public transport)
# * VAL_METRO_1A2 : CITY SERVICES - RATE: SUBWAY - GROUPED - dropped (other variable will be used to evaluate public transport)
# * VAL_GUB_1A2 : CITY SERVICES - RATE: MUNICIPAL POLICE - GROUPED - modeling
# * VAL_SEGUR_1A2 : CITY SERVICES - RATE: CITIZEN SECURITY IN THE CITY AS A WHOLE - GROUPED - modeling
# * VAL_SEGUR_BARRI_1A2 : CITY SERVICES - RATE: CITIZEN SECURITY IN THE NEIGHBORHOOD - GROUPED - modeling
# * VAL_ESPORT_1A2 : CITY SERVICES - RATE: SPORTS FACILITIES - GROUPED - modeling
# * VAL_SIAC_1A2 : CITY SERVICES - RATE: CITIZEN INFORMATION AND ATTENTION SERVICES - GROUPED - modeling
# * VAL_CSS_1A2 : CITY SERVICES - RATE: SOCIAL SERVICES CENTERS - GROUPED - modeling
# * VAL_CULT_1A2 : CITY SERVICES - RATE: CULTURAL ACTIVITIES - GROUPED - modeling
# * VAL_FESTESPOP_1A2 : CITY SERVICES - RATE: POPULAR FESTIVALS - GROUPED - modeling
# * VAL_MERCAT_1A2 : CITY SERVICES - RATE: MUNICIPAL MARKETS - GROUPED - modeling
# * VAL_BIBLIO_1A2 : CITY SERVICES - RATE: PUBLIC LIBRARIES - GROUPED - modeling
#
#
# * EVO1A_ESCOMBRARIES : CITY SERVICES - IMPROVED/WORSENED: GARBAGE COLLECTION  - modeling
# * EVO1A_NETEJA : CITY SERVICES - IMPROVED/WORSENED: STREETS CLEANING - modeling
# * EVO1A_SOROLL : CITY SERVICES - IMPROVED/WORSENED: NOISE - modeling
# * EVO1A_VERD : CITY SERVICES - IMPROVED/WORSENED: GREEN AREAS - modeling
# * EVO1A_ENLLUM : CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIGHTING - modeling
# * EVO1A_URBA : CITY SERVICES - IMPROVED/WORSENED: URBANISM - modeling
# * EVO1A_ASFALT : CITY SERVICES - IMPROVED/WORSENED: ASPHALT AND STREET CONSERVATION - modeling
# * EVO1A_FACANES : CITY SERVICES - IMPROVED/WORSENED: FACADES AND BUILDING CONSERVATION - modeling
# * EVO1A_CIRCUL : CITY SERVICES - IMPROVED/WORSENED: CIRCULATION - modeling
# * EVO1A_APARCA : CITY SERVICES - IMPROVED/WORSENED: PARKING - modeling
# * EVO1A_BUS : CITY SERVICES - IMPROVED/WORSENED: BUS - dropped (other variable will be used to evaluate public transport)
# * EVO1A_METRO : CITY SERVICES - IMPROVED/WORSENED: SUBWAY - dropped (other variable will be used to evaluate public transport)
# * EVO1A_GUB : CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL POLICE - modeling
# * EVO1A_SEGUR : CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE CITY AS A WHOLE - modeling
# * EVO1A_SEGUR_BARRI : CITY SERVICES - IMPROVED/WORSENED: CITIZEN SECURITY IN THE NEIGHBORHOOD - modeling
# * EVO1A_ESPORT : CITY SERVICES - IMPROVED/WORSENED: SPORTS FACILITIES - modeling
# * EVO1A_SIAC : CITY SERVICES - IMPROVED/WORSENED: CITIZEN INFORMATION AND SERVICE SERVICES - modeling
# * EVO1A_CSS : CITY SERVICES - IMPROVED/WORSENED: SOCIAL SERVICES CENTERS - modeling
# * EVO1A_CULT : CITY SERVICES - IMPROVED/WORSENED: CULTURAL ACTIVITIES - modeling
# * EVO1A_FESTESPOP : CITY SERVICES - IMPROVED/WORSENED: POPULAR FESTIVALS - modeling
# * EVO1A_MERCAT : CITY SERVICES - IMPROVED/WORSENED: MUNICIPAL MARKETS - modeling
# * EVO1A_BIBLIO : CITY SERVICES - IMPROVED/WORSENED: PUBLIC LIBRARIES - modeling
#
#
# * US_VERD : CITY SERVICES - USE/DON'T USE: GREEN AREAS, US_BUS : CITY SERVICES - USE/DON'T USE: BUS, US_METRO : CITY SERVICES - USE/DON'T USE: SUBWAY, US_ESPORT : CITY SERVICES - USE/DON'T USE: SPORTS FACILITIES, US_SIAC : CITY SERVICES - USE/DON'T USE: CITIZEN INFORMATION AND SERVICE SERVICES, US_CSS : CITY SERVICES - USE/DON'T USE: SOCIAL SERVICES CENTERS, US_CULT : CITY SERVICES - USE/DON'T USE: CULTURAL ACTIVITIES, US_FESTESPOP : CITY SERVICES - USE/DON'T USE: POPULAR FESTIVALS, US_MERCAT : CITY SERVICES - USE/DON'T USE: MUNICIPAL MARKETS, US_BIBLIO : CITY SERVICES - USE/DON'T USE: PUBLIC LIBRARIES - dropped
#
#
# * TRANSP_MOU : WHICH MEANS OF TRANSPORT DO YOU USE MOST FREQUENTLY ON A DAILY BASIS? - statistical description + modeling
# * VAL_TRANSP_1A3 : IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT BARCELONA IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED - statistical description + modeling
# * VAL_TRANSP_BARRI_1A3 : IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT YOUR NEIGHBORHOOD IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED - statistical description + modeling
#
#
# * EVO1A_BARRI : IN GENERAL, DO YOU THINK YOUR NEIGHBORHOOD HAS IMPROVED OR WORSENED IN THE LAST YEAR? - statistical description + modeling
# * FUTUR_BARRI : AND FACING THE FUTURE, DO YOU THINK YOUR NEIGHBORHOOD WILL IMPROVE OR GET WORSE? statistical description + modeling
# * SATISF_RES_BARRI_1A4 : ON A SCALE OF 0 TO 10, 0 BEING NOT SATISFIED AND 10 BEING VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR DEGREE OF SATISFACTION OF LIVING IN YOUR NEIGHBORHOOD? - GROUPED - statistical description + modeling
# * COMPARA_BARRI : DO YOU THINK YOUR NEIGHBORHOOD IS ONE OF THE BEST OR ONE OF THE WORST? - statistical description + modeling
# * VAL_GESTBARRI_1A2 : ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL IN YOUR NEIGHBORHOOD? - GROUPED - statistical description + modeling
#
#
# * HAB_COTXE_PART : DO YOU HAVE: PRIVATE CAR - statistical description + modeling
# * HAB_M2_1A14 : HOW MANY SQUARE METERS DOES YOUR FLAT OR HOUSE HAVE? - GROUPED - statistical description + modeling (grouped)
# * LLAR_INGRESSOS_1A10 : WHAT IS THE NET MONTHLY INCOME OF ALL MEMBERS OF YOUR HOME? - GROUPED - dropped (too many "NO ANSWER" responses)
# * CLASSESOC_ENT : COULD YOU TELL ME WHAT SOCIAL CLASS DO YOU THINK YOU BELONG TO? - statistical description + modeling
#
#
# * SENTPERTI : BELONGING - SPANISH VS CATALAN - statistical description
# * MUNI_VOTAR : HAVE YOU VOTED IN THE LAST MUNICIPAL ELECTIONS? - statistical description + modeling
# * LLOC_NAIX_1A4 : WHAT IS YOUR PLACE OF BIRTH? - statistical description + modeling
# * LLENGUA_HAB : WHAT IS YOUR USUAL LANGUAGE? - statistical description
# * ESTUDIS_1A6 : WHAT IS YOUR LEVEL OF FINISHED STUDIES? - statistical description
# * RESUM_PARENTIU : WHAT IS THE TYPE OF YOUR FAMILY? - statistical description + modeling
# * HAB_RES_1A4 : WHAT IS THE NUMBER OF PEOPLE LIVING IN THE HOUSE? - GROUPED - statistical description + modeling

# %%
del survey_65['VAL_BUS_1A2']
del survey_65['VAL_METRO_1A2']
del survey_65['EVO1A_BUS']
del survey_65['EVO1A_METRO']
del survey_65['LLAR_INGRESSOS_1A10']

# %%
# GENDER
survey_65.groupby(['SEXE']).size().plot.bar()

# %%
display(pd.crosstab(data.SEXE, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# SEXE
# MAN                            1414  4099
# WOMAN                          1830  6399

# %%
data_prep = {'WOMAN': 1,
            'MAN': 0}
data['Gender'] = [data_prep[i] for i in data['SEXE']]

# %%
table = pd.crosstab(data.Gender, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# NATIONALITY
survey_65.groupby(['NACIO_ACT_UE']).size().plot.bar()

# %%
display(pd.crosstab(data.NACIO_ACT_UE, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0      1
# NACIO_ACT_UE
# OTHER EU                         16     88
# REMAINING COUNTRIES              33     88
# SPANISH                        3195  10322

# %%
# HOW LONG HAVE YOU BEEN LIVING IN BARCELONA?
survey_65.groupby(['TMP_RES_BCN_1A6']).size().plot.bar()

# %%
display(pd.crosstab(data.TMP_RES_BCN_1A6, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood            0     1
# TMP_RES_BCN_1A6
# FROM 6 MONTHS TO 2 YEARS                21    37
# I HAVE ALWAYS LIVED IN THE CITY       1322  4402
# MORE THAN 10 YEARS                    1850  5931
# MORE THAN 2 YEARS AND UP TO 5 YEARS     24    60
# MORE THAN 5 YEARS AND UP TO 10 YEARS    27    68

# %%
data.TMP_RES_BCN_1A6.unique()
# Out:
# array(['MORE THAN 10 YEARS', 'I HAVE ALWAYS LIVED IN THE CITY',
#        'MORE THAN 5 YEARS AND UP TO 10 YEARS',
#        'MORE THAN 2 YEARS AND UP TO 5 YEARS', 'FROM 6 MONTHS TO 2 YEARS'],
#       dtype=object)

# %%
data_prep = {'I HAVE ALWAYS LIVED IN THE CITY': 'I HAVE ALWAYS LIVED IN THE CITY',
             'MORE THAN 10 YEARS': 'MORE THAN 10 YEARS', 
             'MORE THAN 5 YEARS AND UP TO 10 YEARS': 'LESS THAN 10 YEARS',
             'MORE THAN 2 YEARS AND UP TO 5 YEARS': 'LESS THAN 10 YEARS', 
             'FROM 6 MONTHS TO 2 YEARS': 'LESS THAN 10 YEARS'}
data['Time_living_in_BCN'] = [data_prep[i] for i in data['TMP_RES_BCN_1A6']]

# %%
table = pd.crosstab(data.Time_living_in_BCN, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# HOW LONG HAVE YOU BEEN LIVING IN THIS NEIGHBORHOOD?
survey_65.groupby(['TMP_RES_BARRI_1A6']).size().plot.bar()

# %%
display(pd.crosstab(data.TMP_RES_BARRI_1A6, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood            0     1
# TMP_RES_BARRI_1A6
# FROM 6 MONTHS TO 2 YEARS                61   118
# I HAVE ALWAYS LIVED IN THE BARRI       311  1449
# LESS THAN SIX MONTHS                    16    33
# MORE THAN 10 YEARS                    2649  8525
# MORE THAN 2 YEARS AND UP TO 5 YEARS     93   143
# MORE THAN 5 YEARS AND UP TO 10 YEARS   114   230

# %%
data.TMP_RES_BARRI_1A6.unique()
# Out:
# array(['MORE THAN 10 YEARS', 'MORE THAN 5 YEARS AND UP TO 10 YEARS',
#        'I HAVE ALWAYS LIVED IN THE BARRI', 'FROM 6 MONTHS TO 2 YEARS',
#        'MORE THAN 2 YEARS AND UP TO 5 YEARS', 'LESS THAN SIX MONTHS'],
#       dtype=object)

# %%
data_prep = {'I HAVE ALWAYS LIVED IN THE BARRI': 'I HAVE ALWAYS LIVED IN THE CITY',
             'MORE THAN 10 YEARS': 'MORE THAN 10 YEARS', 
             'MORE THAN 5 YEARS AND UP TO 10 YEARS': 'LESS THAN 10 YEARS',
             'MORE THAN 2 YEARS AND UP TO 5 YEARS': 'LESS THAN 10 YEARS', 
             'FROM 6 MONTHS TO 2 YEARS': 'LESS THAN 10 YEARS',
             'LESS THAN SIX MONTHS': 'LESS THAN 10 YEARS'}
data['Time_living_in_barri'] = [data_prep[i] for i in data['TMP_RES_BARRI_1A6']]

# %%
table = pd.crosstab(data.Time_living_in_barri, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# DO YOU THINK THAT LAST YEAR BARCELONA HAS IMPROVED OR WORSENED?
survey_65.groupby(['EVO1A_BCN']).size().plot.bar()

# %%
display(pd.crosstab(data.EVO1A_BCN, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BCN
# I DON'T KNOW                     91   288
# IT HAS IMPROVED                 772  3355
# IT'S THE SAME                   747  2858
# IT'S WORSE                     1628  3992
# NO ANSWER                         6     5

# %%
data.EVO1A_BCN.unique()
# Out:
# array(["IT'S WORSE", "IT'S THE SAME", 'IT HAS IMPROVED', "I DON'T KNOW",
#        'NO ANSWER'], dtype=object)

# %%
data_prep = {"IT'S WORSE": -1, 
             "IT'S THE SAME": 0, 
             'IT HAS IMPROVED': 1, 
             "I DON'T KNOW": 0,
             'NO ANSWER': 0}
data['BCN_if_has_improved'] = [data_prep[i] for i in data['EVO1A_BCN']]

# %%
table = pd.crosstab(data.BCN_if_has_improved, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# FACING THE FUTURE, DO YOU THINK BARCELONA WILL IMPROVE OR GET WORSE?
survey_65.groupby(['FUTUR_BCN']).size().plot.bar()

# %%
display(pd.crosstab(data.FUTUR_BCN, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# FUTUR_BCN
# I DON'T KNOW                    502  1609
# IT WILL IMPROVE                1382  5385
# IT WILL STAY THE SAME           325  1024
# IT WILL WORSE                  1029  2471
# NO ANSWER                         6     9

# %%
data.FUTUR_BCN.unique()
# Out:
# array(['IT WILL WORSE', 'IT WILL IMPROVE', 'IT WILL STAY THE SAME',
#        "I DON'T KNOW", 'NO ANSWER'], dtype=object)

# %%
data_prep = {'IT WILL WORSE': -1, 
             'IT WILL IMPROVE': 1, 
             'IT WILL STAY THE SAME': 0,
             "I DON'T KNOW": 0, 
             'NO ANSWER': 0}
data['BCN_if_will_improve'] = [data_prep[i] for i in data['FUTUR_BCN']]

# %%
table = pd.crosstab(data.BCN_if_will_improve, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# ON A SCALE OF 0 TO 10, BEING 0 NOT SATISFIED AND 10 VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR SATISFACTION DEGREE OF LIVING IN THE CITY OF BARCELONA? - GROUPED
survey_65.groupby(['SATISF_RES_BCN_1A4']).size().plot.bar()

# %%
display(pd.crosstab(data.SATISF_RES_BCN_1A4, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood       0     1
# SATISF_RES_BCN_1A4
# FAIRLY SATISFIED (5 to 6)         584   883
# I DON'T KNOW / NO ANSWER           13    42
# LITTLE / NOT SATISFIED (0 TO 4)   258   190
# SATISFIED (7 TO 8)               1362  4328
# VERY SATISFIED (9 TO 10)         1027  5055

# %%
data.SATISF_RES_BCN_1A4.unique()
# Out:
# array(['SATISFIED (7 TO 8)', 'VERY SATISFIED (9 TO 10)',
#        'FAIRLY SATISFIED (5 to 6)', 'LITTLE / NOT SATISFIED (0 TO 4)',
#        "I DON'T KNOW / NO ANSWER"], dtype=object)

# %%
data_prep = {'SATISFIED (7 TO 8)': 3, 
             'VERY SATISFIED (9 TO 10)': 4,
             'FAIRLY SATISFIED (5 to 6)': 2, 
             'LITTLE / NOT SATISFIED (0 TO 4)': 1,
             "I DON'T KNOW / NO ANSWER": 0}
data['BCN_satisfaction_of_living'] = [data_prep[i] for i in data['SATISF_RES_BCN_1A4']]

# %%
table = pd.crosstab(data.BCN_satisfaction_of_living, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 BEING VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL? - GROUPED
survey_65.groupby(['VAL_GESTMUNI_1A2']).size().plot.bar()

# %%
display(pd.crosstab(data.VAL_GESTMUNI_1A2, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# VAL_GESTMUNI_1A2
# BAD (0 TO 4)                    756  1584
# GOOD (5 TO 10)                 2338  8413
# I DON'T KNOW / NO ANSWER        150   501

# %%
data.VAL_GESTMUNI_1A2.unique()
# Out:
# array(['GOOD (5 TO 10)', 'BAD (0 TO 4)', "I DON'T KNOW / NO ANSWER"],
#       dtype=object)

# %%
data_prep = {'GOOD (5 TO 10)': 1, 
             'BAD (0 TO 4)': -1,
             "I DON'T KNOW / NO ANSWER": 0}
data['BCN_city_management'] = [data_prep[i] for i in data['VAL_GESTMUNI_1A2']]

# %%
table = pd.crosstab(data.BCN_city_management, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
survey_65.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'NOM_BARRI',
#  'GRANBARRI',
#  'SEXE',
#  'EDAT1899_1A6',
#  'NACIO_ACT_UE',
#  'TMP_RES_BCN_1A6',
#  'TMP_RES_BARRI_1A6',
#  'EVO1A_BCN',
#  'FUTUR_BCN',
#  'SATISF_RES_BCN_1A4',
#  'VAL_GESTMUNI_1A2',
#  'VAL_ESCOMBRARIES_1A2',
#  'VAL_NETEJA_1A2',
#  'VAL_SOROLL_1A2',
#  'VAL_VERD_1A2',
#  'VAL_ENLLUM_1A2',
#  'VAL_URBA_1A2',
#  'VAL_ASFALT_1A2',
#  'VAL_FACANES_1A2',
#  'VAL_CIRCUL_1A2',
#  'VAL_APARCA_1A2',
#  'VAL_GUB_1A2',
#  'VAL_SEGUR_1A2',
#  'VAL_SEGUR_BARRI_1A2',
#  'VAL_ESPORT_1A2',
#  'VAL_SIAC_1A2',
#  'VAL_CSS_1A2',
#  'VAL_CULT_1A2',
#  'VAL_FESTESPOP_1A2',
#  'VAL_MERCAT_1A2',
#  'VAL_BIBLIO_1A2',
#  'EVO1A_ESCOMBRARIES',
#  'EVO1A_NETEJA',
#  'EVO1A_SOROLL',
#  'EVO1A_VERD',
#  'EVO1A_ENLLUM',
#  'EVO1A_URBA',
#  'EVO1A_ASFALT',
#  'EVO1A_FACANES',
#  'EVO1A_CIRCUL',
#  'EVO1A_APARCA',
#  'EVO1A_GUB',
#  'EVO1A_SEGUR',
#  'EVO1A_SEGUR_BARRI',
#  'EVO1A_ESPORT',
#  'EVO1A_SIAC',
#  'EVO1A_CSS',
#  'EVO1A_CULT',
#  'EVO1A_FESTESPOP',
#  'EVO1A_MERCAT',
#  'EVO1A_BIBLIO',
#  'US_VERD',
#  'US_BUS',
#  'US_METRO',
#  'US_ESPORT',
#  'US_SIAC',
#  'US_CSS',
#  'US_CULT',
#  'US_FESTESPOP',
#  'US_MERCAT',
#  'US_BIBLIO',
#  'TRANSP_MOU',
#  'VAL_TRANSP_1A3',
#  'VAL_TRANSP_BARRI_1A3',
#  'EVO1A_BARRI',
#  'FUTUR_BARRI',
#  'SATISF_RES_BARRI_1A4',
#  'COMPARA_BARRI',
#  'CANVI_LLOC_RES_1A3',
#  'VAL_GESTBARRI_1A2',
#  'HAB_COTXE_PART',
#  'HAB_M2_1A14',
#  'CLASSESOC_ENT',
#  'SENTPERTI',
#  'MUNI_VOTAR',
#  'LLOC_NAIX_1A4',
#  'LLENGUA_HAB',
#  'ESTUDIS_1A6',
#  'RESUM_PARENTIU',
#  'HAB_RES_1A4']

# %%
for x in ['VAL_ESCOMBRARIES_1A2', 'VAL_NETEJA_1A2', 'VAL_SOROLL_1A2', 'VAL_VERD_1A2',
          'VAL_ENLLUM_1A2', 'VAL_URBA_1A2', 'VAL_ASFALT_1A2', 'VAL_FACANES_1A2', 'VAL_CIRCUL_1A2', 'VAL_APARCA_1A2',
          'VAL_GUB_1A2', 'VAL_SEGUR_1A2', 'VAL_SEGUR_BARRI_1A2', 'VAL_ESPORT_1A2', 'VAL_SIAC_1A2', 'VAL_CSS_1A2',
          'VAL_CULT_1A2', 'VAL_FESTESPOP_1A2', 'VAL_MERCAT_1A2', 'VAL_BIBLIO_1A2']:
    display(pd.crosstab(data[x], data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# VAL_ESCOMBRARIES_1A2
# BAD (0 TO 4)                    270   504
# GOOD (5 TO 10)                 2958  9954
# I DON'T KNOW / NO ANSWER         16    40
# Stay_in_the_same_neighborhood     0     1
# VAL_NETEJA_1A2
# BAD (0 TO 4)                    739  1568
# GOOD (5 TO 10)                 2500  8903
# I DON'T KNOW / NO ANSWER          5    27
# Stay_in_the_same_neighborhood     0     1
# VAL_SOROLL_1A2
# BAD (0 TO 4)                   1341  2940
# GOOD (5 TO 10)                 1827  7223
# I DON'T KNOW / NO ANSWER         76   335
# Stay_in_the_same_neighborhood     0     1
# VAL_VERD_1A2
# BAD (0 TO 4)                    763  1591
# GOOD (5 TO 10)                 2365  8396
# I DON'T KNOW / NO ANSWER        116   511
# Stay_in_the_same_neighborhood     0     1
# VAL_ENLLUM_1A2
# BAD (0 TO 4)                    390   882
# GOOD (5 TO 10)                 2797  9430
# I DON'T KNOW / NO ANSWER         57   186
# Stay_in_the_same_neighborhood     0     1
# VAL_URBA_1A2
# BAD (0 TO 4)                    564  1064
# GOOD (5 TO 10)                 2295  8176
# I DON'T KNOW / NO ANSWER        385  1258
# Stay_in_the_same_neighborhood     0     1
# VAL_ASFALT_1A2
# BAD (0 TO 4)                    943  2122
# GOOD (5 TO 10)                 2258  8246
# I DON'T KNOW / NO ANSWER         43   130
# Stay_in_the_same_neighborhood     0     1
# VAL_FACANES_1A2
# BAD (0 TO 4)                    528  1076
# GOOD (5 TO 10)                 2528  8748
# I DON'T KNOW / NO ANSWER        188   674
# Stay_in_the_same_neighborhood     0     1
# VAL_CIRCUL_1A2
# BAD (0 TO 4)                   1173  3066
# GOOD (5 TO 10)                 1917  6873
# I DON'T KNOW / NO ANSWER        154   559
# Stay_in_the_same_neighborhood     0     1
# VAL_APARCA_1A2
# BAD (0 TO 4)                   2009  5709
# GOOD (5 TO 10)                  800  3150
# I DON'T KNOW / NO ANSWER        435  1639
# Stay_in_the_same_neighborhood     0     1
# VAL_GUB_1A2
# BAD (0 TO 4)                    800  1722
# GOOD (5 TO 10)                 2076  7494
# I DON'T KNOW / NO ANSWER        368  1282
# Stay_in_the_same_neighborhood     0     1
# VAL_SEGUR_1A2
# BAD (0 TO 4)                   1281  3167
# GOOD (5 TO 10)                 1804  6799
# I DON'T KNOW / NO ANSWER        159   532
# Stay_in_the_same_neighborhood     0     1
# VAL_SEGUR_BARRI_1A2
# BAD (0 TO 4)                   1246  2505
# GOOD (5 TO 10)                 1948  7862
# I DON'T KNOW / NO ANSWER         50   131
# Stay_in_the_same_neighborhood     0     1
# VAL_ESPORT_1A2
# BAD (0 TO 4)                    471   834
# GOOD (5 TO 10)                 1618  5379
# I DON'T KNOW / NO ANSWER       1155  4285
# Stay_in_the_same_neighborhood     0     1
# VAL_SIAC_1A2
# BAD (0 TO 4)                    293   555
# GOOD (5 TO 10)                 2094  6946
# I DON'T KNOW / NO ANSWER        857  2997
# Stay_in_the_same_neighborhood     0     1
# VAL_CSS_1A2
# BAD (0 TO 4)                    370   712
# GOOD (5 TO 10)                 1508  5350
# I DON'T KNOW / NO ANSWER       1366  4436
# Stay_in_the_same_neighborhood     0     1
# VAL_CULT_1A2
# BAD (0 TO 4)                    202   350
# GOOD (5 TO 10)                 1987  6915
# I DON'T KNOW / NO ANSWER       1055  3233
# Stay_in_the_same_neighborhood     0     1
# VAL_FESTESPOP_1A2
# BAD (0 TO 4)                    346   624
# GOOD (5 TO 10)                 2074  7482
# I DON'T KNOW / NO ANSWER        824  2392
# Stay_in_the_same_neighborhood     0     1
# VAL_MERCAT_1A2
# BAD (0 TO 4)                    297   628
# GOOD (5 TO 10)                 2664  8813
# I DON'T KNOW / NO ANSWER        283  1057
# Stay_in_the_same_neighborhood     0     1
# VAL_BIBLIO_1A2
# BAD (0 TO 4)                     71   164
# GOOD (5 TO 10)                 2036  6340
# I DON'T KNOW / NO ANSWER       1137  3994

# %%
data_prep = {'GOOD (5 TO 10)': 1, 
             'BAD (0 TO 4)': -1,
            "I DON'T KNOW / NO ANSWER": 0}
for x in ['VAL_ESCOMBRARIES_1A2', 'VAL_NETEJA_1A2', 'VAL_SOROLL_1A2', 'VAL_VERD_1A2',
          'VAL_ENLLUM_1A2', 'VAL_URBA_1A2', 'VAL_ASFALT_1A2', 'VAL_FACANES_1A2', 'VAL_CIRCUL_1A2', 'VAL_APARCA_1A2',
          'VAL_GUB_1A2', 'VAL_SEGUR_1A2', 'VAL_SEGUR_BARRI_1A2', 'VAL_ESPORT_1A2', 'VAL_SIAC_1A2', 'VAL_CSS_1A2',
          'VAL_CULT_1A2', 'VAL_FESTESPOP_1A2', 'VAL_MERCAT_1A2', 'VAL_BIBLIO_1A2']:
    data[questions_dict[x][22:][:-10]] = [data_prep[i] for i in data[x]]

# %%
for x in ['VAL_ESCOMBRARIES_1A2', 'VAL_NETEJA_1A2', 'VAL_SOROLL_1A2', 'VAL_VERD_1A2',
          'VAL_ENLLUM_1A2', 'VAL_URBA_1A2', 'VAL_ASFALT_1A2', 'VAL_FACANES_1A2', 'VAL_CIRCUL_1A2', 'VAL_APARCA_1A2',
          'VAL_GUB_1A2', 'VAL_SEGUR_1A2', 'VAL_SEGUR_BARRI_1A2', 'VAL_ESPORT_1A2', 'VAL_SIAC_1A2', 'VAL_CSS_1A2',
          'VAL_CULT_1A2', 'VAL_FESTESPOP_1A2', 'VAL_MERCAT_1A2', 'VAL_BIBLIO_1A2']:
    table = pd.crosstab(data[questions_dict[x][22:][:-10]], data.Stay_in_the_same_neighborhood)
    table.plot(kind='bar')
    table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
# Out:
# C:\Users\THINK\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
# WHICH MEANS OF TRANSPORT DO YOU USE MOST FREQUENTLY ON A DAILY BASIS?
survey_65.groupby(['TRANSP_MOU']).size().plot.bar()

# %%
display(pd.crosstab(data.TRANSP_MOU, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood            0     1
# TRANSP_MOU
# BICYCLE                                 10    31
# BICYCLE (BICING)                         5    10
# BUS                                   1429  4586
# CAR                                    175   534
# METRO / CATALAN RAILWAYS (FGC) URBAN  1040  3170
# MOTORCYCLE                              44    91
# NO ANSWER                                1     1
# OTHERS                                  12    29
# TAXI                                    59   376
# TRAIN (RENFE / FGC INTERURBAN)           9    30
# TRAM (TRAM, TRAMBAIX, TRAMBESÒS)        15    41
# WALKING                                445  1599

# %%
data.TRANSP_MOU.unique()
# Out:
# array(['BUS', 'METRO / CATALAN RAILWAYS (FGC) URBAN', 'CAR', 'TAXI',
#        'WALKING', 'MOTORCYCLE', 'OTHERS', 'BICYCLE (BICING)',
#        'TRAIN (RENFE / FGC INTERURBAN)',
#        'TRAM (TRAM, TRAMBAIX, TRAMBESÒS)', 'BICYCLE', 'NO ANSWER'],
#       dtype=object)

# %%
data_prep = {'BUS': 'PUBLIC TRANSPORT', 
             'METRO / CATALAN RAILWAYS (FGC) URBAN': 'PUBLIC TRANSPORT', 
             'CAR': 'CAR', 
             'TAXI': 'TAXI',
             'WALKING': 'WALKING', 
             'MOTORCYCLE': 'MOTORCYCLE', 
             'OTHERS': 'OTHERS', 
             'BICYCLE (BICING)': 'BICYCLE',
             'TRAIN (RENFE / FGC INTERURBAN)': 'PUBLIC TRANSPORT',
             'TRAM (TRAM, TRAMBAIX, TRAMBESÒS)': 'PUBLIC TRANSPORT', 
             'BICYCLE': 'BICYCLE', 
             'NO ANSWER': np.nan}
data['Means_of_transport'] = [data_prep[i] for i in data['TRANSP_MOU']]

# %%
table = pd.crosstab(data.Means_of_transport, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT BARCELONA IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED
survey_65.groupby(['VAL_TRANSP_1A3']).size().plot.bar()

# %%
display(pd.crosstab(data.VAL_TRANSP_1A3, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# VAL_TRANSP_1A3
# I DON'T KNOW / NO ANSWER         66   208
# LITTLE / NOTHING EQUIPPED       357   779
# NORMAL                          314   866
# VERY / FAIRLY GIFTED           2507  8645

# %%
data.VAL_TRANSP_1A3.unique()
# Out:
# array(['VERY / FAIRLY GIFTED', 'NORMAL', 'LITTLE / NOTHING EQUIPPED',
#        "I DON'T KNOW / NO ANSWER"], dtype=object)

# %%
data_prep = {'VERY / FAIRLY GIFTED': 1, 
             'NORMAL': 0, 
             'LITTLE / NOTHING EQUIPPED': -1,
             "I DON'T KNOW / NO ANSWER": 0}
data['BCN_transport'] = [data_prep[i] for i in data['VAL_TRANSP_1A3']]

# %%
table = pd.crosstab(data.BCN_transport, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# IN RELATION TO PUBLIC TRANSPORT, WOULD YOU SAY THAT YOUR NEIGHBORHOOD IS A VERY, ENOUGH, LITTLE OR NOTHING EQUIPPED CITY? - GROUPED
survey_65.groupby(['VAL_TRANSP_BARRI_1A3']).size().plot.bar()

# %%
display(pd.crosstab(data.VAL_TRANSP_BARRI_1A3, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# VAL_TRANSP_BARRI_1A3
# I DON'T KNOW / NO ANSWER         22    70
# LITTLE / NOTHING EQUIPPED       488  1162
# NORMAL                          331   809
# VERY / FAIRLY GIFTED           2403  8457

# %%
data.VAL_TRANSP_BARRI_1A3.unique()
# Out:
# array(['VERY / FAIRLY GIFTED', 'NORMAL', "I DON'T KNOW / NO ANSWER",
#        'LITTLE / NOTHING EQUIPPED'], dtype=object)

# %%
data_prep = {'VERY / FAIRLY GIFTED': 1, 
             'NORMAL': 0, 
             'LITTLE / NOTHING EQUIPPED': -1,
             "I DON'T KNOW / NO ANSWER": 0}
data['Barri_transport'] = [data_prep[i] for i in data['VAL_TRANSP_BARRI_1A3']]

# %%
table = pd.crosstab(data.Barri_transport, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# IN GENERAL, DO YOU THINK YOUR NEIGHBORHOOD HAS IMPROVED OR WORSENED IN THE LAST YEAR?
survey_65.groupby(['EVO1A_BARRI']).size().plot.bar()

# %%
display(pd.crosstab(data.EVO1A_BARRI, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# EVO1A_BARRI
# I DON'T KNOW                     43    86
# IT HAS IMPROVED                1242  5384
# IT'S THE SAME                   852  3135
# IT'S WORSE                     1107  1891
# NO ANSWER                         0     2

# %%
data.EVO1A_BARRI.unique()
# Out:
# array(["IT'S WORSE", "IT'S THE SAME", 'IT HAS IMPROVED', "I DON'T KNOW",
#        'NO ANSWER'], dtype=object)

# %%
data_prep = {"IT'S WORSE": -1, 
             "IT'S THE SAME": 0, 
             'IT HAS IMPROVED': 1, 
             "I DON'T KNOW": 0,
             'NO ANSWER': 0}
data['Barri_if_has_improved'] = [data_prep[i] for i in data['EVO1A_BARRI']]

# %%
table = pd.crosstab(data.Barri_if_has_improved, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# AND FACING THE FUTURE, DO YOU THINK YOUR NEIGHBORHOOD WILL IMPROVE OR GET WORSE?
survey_65.groupby(['FUTUR_BARRI']).size().plot.bar()

# %%
display(pd.crosstab(data.FUTUR_BARRI, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# FUTUR_BARRI
# I DON'T KNOW                    493  1392
# IT WILL GET WORSE               876  1395
# IT WILL IMPROVE                1319  5720
# IT WILL STAY THE SAME           556  1988
# NO ANSWER                         0     3

# %%
data.FUTUR_BARRI.unique()
# Out:
# array(['IT WILL GET WORSE', 'IT WILL STAY THE SAME', 'IT WILL IMPROVE',
#        "I DON'T KNOW", 'NO ANSWER'], dtype=object)

# %%
data_prep = {'IT WILL GET WORSE': -1, 
             'IT WILL IMPROVE': 1, 
             'IT WILL STAY THE SAME': 0,
             "I DON'T KNOW": 0, 
             'NO ANSWER': 0}
data['Barri_if_will_improve'] = [data_prep[i] for i in data['FUTUR_BARRI']]

# %%
table = pd.crosstab(data.Barri_if_will_improve, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# ON A SCALE OF 0 TO 10, 0 BEING NOT SATISFIED AND 10 BEING VERY SATISFIED, COULD YOU TELL ME WHAT IS YOUR DEGREE OF SATISFACTION OF LIVING IN YOUR NEIGHBORHOOD? - GROUPED
survey_65.groupby(['SATISF_RES_BARRI_1A4']).size().plot.bar()

# %%
display(pd.crosstab(data.SATISF_RES_BARRI_1A4, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood       0     1
# SATISF_RES_BARRI_1A4
# FAIRLY SATISFIED (5 to 6)         661   616
# I DON'T KNOW / NO ANSWER           15    26
# LITTLE / NOT SATISFIED (0 TO 4)   336    87
# SATISFIED (7 TO 8)               1496  4652
# VERY SATISFIED (9 TO 10)          736  5117

# %%
data.SATISF_RES_BARRI_1A4.unique()
# Out:
# array(['FAIRLY SATISFIED (5 to 6)', 'VERY SATISFIED (9 TO 10)',
#        'SATISFIED (7 TO 8)', 'LITTLE / NOT SATISFIED (0 TO 4)',
#        "I DON'T KNOW / NO ANSWER"], dtype=object)

# %%
data_prep = {'SATISFIED (7 TO 8)': 3, 
             'VERY SATISFIED (9 TO 10)': 4,
             'FAIRLY SATISFIED (5 to 6)': 2, 
             'LITTLE / NOT SATISFIED (0 TO 4)': 1,
             "I DON'T KNOW / NO ANSWER": 0}
data['Barri_satisfaction_of_living'] = [data_prep[i] for i in data['SATISF_RES_BARRI_1A4']]

# %%
table = pd.crosstab(data.Barri_satisfaction_of_living, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# DO YOU THINK YOUR NEIGHBORHOOD IS ONE OF THE BEST OR ONE OF THE WORST?
survey_65.groupby(['COMPARA_BARRI']).size().plot.bar()

# %%
display(pd.crosstab(data.COMPARA_BARRI, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood       0     1
# COMPARA_BARRI
# I DON'T KNOW                       89   225
# NEITHER THE BEST, NOR THE WORST  1773  3673
# NO ANSWER                           4     4
# ONE OF THE BEST                   954  6357
# ONE OF THE WORST                  424   239

# %%
data.COMPARA_BARRI.unique()
# Out:
# array(['NEITHER THE BEST, NOR THE WORST', 'ONE OF THE BEST',
#        'ONE OF THE WORST', "I DON'T KNOW", 'NO ANSWER'], dtype=object)

# %%
data_prep = {'NEITHER THE BEST, NOR THE WORST': 0, 
             'ONE OF THE BEST': 1,
             'ONE OF THE WORST': -1, 
             "I DON'T KNOW": 0, 
             'NO ANSWER': 0}
data['Barri_comparison'] = [data_prep[i] for i in data['COMPARA_BARRI']]

# %%
table = pd.crosstab(data.Barri_comparison, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# ON A SCALE FROM 0 TO 10, 0 BEING VERY BAD AND 10 VERY GOOD, HOW DO YOU RATE THE MANAGEMENT OF THE CITY COUNCIL IN YOUR NEIGHBORHOOD? - GROUPED
survey_65.groupby(['VAL_GESTBARRI_1A2']).size().plot.bar()

# %%
display(pd.crosstab(data.VAL_GESTBARRI_1A2, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# VAL_GESTBARRI_1A2
# BAD (0 TO 4)                    654   926
# GOOD (5 TO 10)                 2270  8670
# I DON'T KNOW / NO ANSWER        320   902

# %%
data.VAL_GESTBARRI_1A2.unique()
# Out:
# array(['GOOD (5 TO 10)', "I DON'T KNOW / NO ANSWER", 'BAD (0 TO 4)'],
#       dtype=object)

# %%
data_prep = {'GOOD (5 TO 10)': 1, 
             'BAD (0 TO 4)': -1,
             "I DON'T KNOW / NO ANSWER": 0}
data['Barri_city_management'] = [data_prep[i] for i in data['VAL_GESTBARRI_1A2']]

# %%
table = pd.crosstab(data.Barri_city_management, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# DO YOU HAVE: PRIVATE CAR
survey_65.groupby(['HAB_COTXE_PART']).size().plot.bar()

# %%
display(pd.crosstab(data.HAB_COTXE_PART, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# HAB_COTXE_PART
# I DON'T KNOW                      2     2
# I DON'T WANT / I DON'T NEED     284   848
# IT'S NOT POSSIBLE                72   151
# NO                             1131  4352
# NO ANSWER                        20    72
# YES                            1735  5073

# %%
data.HAB_COTXE_PART.unique()
# Out:
# array(['NO', 'YES', 'NO ANSWER', "I DON'T KNOW",
#        "I DON'T WANT / I DON'T NEED", "IT'S NOT POSSIBLE"], dtype=object)

# %%
data_prep = {'NO': 0, 
             'YES': 1, 
             'NO ANSWER': 0, 
             "I DON'T KNOW": 0,
             "I DON'T WANT / I DON'T NEED": 0, 
             "IT'S NOT POSSIBLE": 0}
data['Owns_a_car'] = [data_prep[i] for i in data['HAB_COTXE_PART']]

# %%
table = pd.crosstab(data.Owns_a_car, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# HOW MANY SQUARE METERS DOES YOUR FLAT OR HOUSE HAVE? - GROUPED
survey_65.groupby(['HAB_M2_1A14']).size().plot.bar()

# %%
display(pd.crosstab(data.HAB_M2_1A14, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood    0     1
# HAB_M2_1A14
# FROM 101 TO 110 M2              28    79
# FROM 101 TO 120 M2             128   616
# FROM 111 TO 120 M2              25    70
# FROM 121 TO 130 M2              15    42
# FROM 121 TO 150 M2              70   376
# FROM 131 TO 140 M2              12    38
# FROM 141 TO 150 M2               9    28
# FROM 151 TO 160 M2               2    14
# FROM 161 TO 170 M2               5    18
# FROM 51 TO 60 M2               435  1147
# FROM 61 TO 70 M2               723  1959
# FROM 71 TO 80 M2               551  1687
# FROM 81 TO 90 M2               392  1298
# FROM 91 TO 100 M2              279  1021
# I DON'T KNOW                   164   759
# MORE THAN 150 M2                72   360
# MORE THAN 170 M2                15    60
# NO ANSWER                       61   219
# UP TO 50 M2                    258   707

# %%
data.HAB_M2_1A14.unique()
# Out:
# array(['FROM 61 TO 70 M2', 'FROM 51 TO 60 M2', 'UP TO 50 M2',
#        'FROM 81 TO 90 M2', 'FROM 91 TO 100 M2', 'MORE THAN 150 M2',
#        'FROM 71 TO 80 M2', 'NO ANSWER', "I DON'T KNOW",
#        'FROM 101 TO 120 M2', 'FROM 121 TO 150 M2', 'FROM 101 TO 110 M2',
#        'MORE THAN 170 M2', 'FROM 111 TO 120 M2', 'FROM 121 TO 130 M2',
#        'FROM 141 TO 150 M2', 'FROM 131 TO 140 M2', 'FROM 161 TO 170 M2',
#        'FROM 151 TO 160 M2'], dtype=object)

# %%
data_prep = {'UP TO 50 M2': '< 50 M2', 
             'FROM 51 TO 60 M2': '51-100 M2', 
             'FROM 61 TO 70 M2': '51-100 M2', 
             'FROM 71 TO 80 M2': '51-100 M2', 
             'FROM 81 TO 90 M2': '51-100 M2', 
             'FROM 91 TO 100 M2': '51-100 M2', 
             'FROM 101 TO 120 M2': '101-150 M2', 
             'FROM 101 TO 110 M2': '101-150 M2',
             'FROM 111 TO 120 M2': '101-150 M2', 
             'FROM 121 TO 150 M2': '101-150 M2', 
             'FROM 121 TO 130 M2': '101-150 M2',
             'FROM 131 TO 140 M2': '101-150 M2', 
             'FROM 141 TO 150 M2': '101-150 M2', 
             'FROM 151 TO 160 M2': '> 150 M2',
             'FROM 161 TO 170 M2': '> 150 M2',
             'MORE THAN 150 M2': '> 150 M2',
             'MORE THAN 170 M2': '> 150 M2',
             'NO ANSWER': '51-100 M2', # inserting most common value
             "I DON'T KNOW": '51-100 M2'} # inserting most common value
data['House_M2'] = [data_prep[i] for i in data['HAB_M2_1A14']]

# %%
table = pd.crosstab(data.House_M2, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# COULD YOU TELL ME WHAT SOCIAL CLASS DO YOU THINK YOU BELONG TO?
survey_65.groupby(['CLASSESOC_ENT']).size().plot.bar()

# %%
display(pd.crosstab(data.CLASSESOC_ENT, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# CLASSESOC_ENT
# HIGH CLASS                        3    41
# I DON'T KNOW                     74   252
# LOW CLASS                       435  1042
# MIDDLE-HIGH CLASS               101   480
# MIDDLE-LOW CLASS               1168  3278
# MIDDLE-MIDDLE CLASS            1418  5268
# NO ANSWER                        45   137

# %%
data.CLASSESOC_ENT.unique()
# Out:
# array(['MIDDLE-HIGH CLASS', 'MIDDLE-MIDDLE CLASS', 'MIDDLE-LOW CLASS',
#        "I DON'T KNOW", 'LOW CLASS', 'NO ANSWER', 'HIGH CLASS'],
#       dtype=object)

# %%
data_prep = {'MIDDLE-HIGH CLASS': 'MIDDLE-HIGH', 
             'MIDDLE-MIDDLE CLASS': 'MIDDLE-MIDDLE', 
             'MIDDLE-LOW CLASS': 'MIDDLE-LOW',
             "I DON'T KNOW": 'MIDDLE-MIDDLE', # inserting most common value
             'LOW CLASS': 'LOW', 
             'NO ANSWER': 'MIDDLE-MIDDLE', # inserting most common value
             'HIGH CLASS': 'HIGH'} 
data['Social_class'] = [data_prep[i] for i in data['CLASSESOC_ENT']]

# %%
table = pd.crosstab(data.Social_class, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# BELONGING - SPANISH VS CATALAN
survey_65.groupby(['SENTPERTI']).size().plot.bar()

# %%
display(pd.crosstab(data.SENTPERTI, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# SENTPERTI
# HALF SPANISH, HALF CATALAN     1168  3892
# I DON'T KNOW                     26    65
# MORE CATALAN THAN SPANISH       742  2633
# MORE SPANISH THAN CATALAN       242   604
# NO ANSWER                        46   126
# ONLY CATALAN                    637  2202
# ONLY SPANISH                    303   785
# OTHER                            80   191

# %%
# HAVE YOU VOTED IN THE LAST MUNICIPAL ELECTIONS?
survey_65.groupby(['MUNI_VOTAR']).size().plot.bar()

# %%
display(pd.crosstab(data.MUNI_VOTAR, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood                         0     1
# MUNI_VOTAR
# I CANNOT VOTE (NATIONALITY, AGE, CENSUS PROBLEMS)    36   130
# I DID NOT VOTE                                      448  1302
# I DON'T REMEMBER IF I VOTED                          54   199
# IT WASN'T CENSUSED IN THE CITY                       40    77
# NO ANSWER                                            19    93
# VOTED                                              2647  8697

# %%
data.MUNI_VOTAR.unique()
# Out:
# array(['VOTED', 'I DID NOT VOTE', 'NO ANSWER',
#        'I CANNOT VOTE (NATIONALITY, AGE, CENSUS PROBLEMS)',
#        "IT WASN'T CENSUSED IN THE CITY", "I DON'T REMEMBER IF I VOTED"],
#       dtype=object)

# %%
data_prep = {'VOTED': 1, 
             'I DID NOT VOTE': 0, 
             'NO ANSWER': 0,
             'I CANNOT VOTE (NATIONALITY, AGE, CENSUS PROBLEMS)': 0,
             "IT WASN'T CENSUSED IN THE CITY": 0, 
             "I DON'T REMEMBER IF I VOTED": 0} 
data['Voted'] = [data_prep[i] for i in data['MUNI_VOTAR']]

# %%
table = pd.crosstab(data.Voted, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# WHAT IS YOUR PLACE OF BIRTH?
survey_65.groupby(['LLOC_NAIX_1A4']).size().plot.bar()

# %%
display(pd.crosstab(data.LLOC_NAIX_1A4, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# LLOC_NAIX_1A4
# BARCELONA CITY                 1440  4710
# FOREIGN                         135   449
# NO ANSWER                         1     9
# REST OF CATALONIA               361  1290
# REST OF SPAIN                  1307  4040

# %%
data.LLOC_NAIX_1A4.unique()
# Out:
# array(['REST OF SPAIN', 'BARCELONA CITY', 'REST OF CATALONIA', 'FOREIGN',
#        'NO ANSWER'], dtype=object)

# %%
data_prep = {'REST OF SPAIN': 0, 
             'BARCELONA CITY': 1, 
             'REST OF CATALONIA': 0, 
             'FOREIGN': 0,
             'NO ANSWER': 0} 
data['Born_in_BCN'] = [data_prep[i] for i in data['LLOC_NAIX_1A4']]

# %%
table = pd.crosstab(data.Born_in_BCN, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# LLENGUA_HAB : WHAT IS YOUR USUAL LANGUAGE?
survey_65.groupby(['LLENGUA_HAB']).size().plot.bar()

# %%
display(pd.crosstab(data.LLENGUA_HAB, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# LLENGUA_HAB
# CATALAN                        1551  5578
# NO ANSWER                         3     6
# OTHER                            28    54
# SPANISH                        1662  4860

# %%
# WHAT IS YOUR LEVEL OF FINISHED STUDIES?
survey_65.groupby(['ESTUDIS_1A6']).size().plot.bar()

# %%
display(pd.crosstab(data.ESTUDIS_1A6, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood            0     1
# ESTUDIS_1A6
# COMPULSORY STUDIES HAVE NOT FINISHED   357  1152
# GENERAL SECONDARY                      466  1425
# MANDATORY                             1301  4403
# NO ANSWER                               10    39
# POST UNIVERSITY                         36    96
# PROFESSIONAL SECONDARY                 493  1521
# UNIVERSITY                             581  1862

# %%
# WHAT IS THE NUMBER OF PEOPLE LIVING IN THE HOUSE? - GROUPED
survey_65.groupby(['HAB_RES_1A4']).size().plot.bar()

# %%
display(pd.crosstab(data.HAB_RES_1A4, data.Stay_in_the_same_neighborhood))
# Out:
# Stay_in_the_same_neighborhood     0     1
# HAB_RES_1A4
# FOUR OR MORE                    184   508
# ONE                             886  3172
# THREE                           425  1226
# TWO                            1749  5592

# %%
data.HAB_RES_1A4.unique()
# Out:
# array(['ONE', 'TWO', 'THREE', 'FOUR OR MORE'], dtype=object)

# %%
data_prep = {'ONE': 1, 
             'TWO': 0, 
             'THREE': 0, 
             'FOUR OR MORE': 0} 
data['Living_alone'] = [data_prep[i] for i in data['HAB_RES_1A4']]

# %%
table = pd.crosstab(data.Living_alone, data.Stay_in_the_same_neighborhood)
table.plot(kind='bar')

# %%
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %% [markdown]
# ## 1.4.3 Feature engineering

# %%
data.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'NOM_BARRI',
#  'GRANBARRI',
#  'SEXE',
#  'EDAT1899_1A6',
#  'NACIO_ACT_UE',
#  'TMP_RES_BCN_1A6',
#  'TMP_RES_BARRI_1A6',
#  'EVO1A_BCN',
#  'FUTUR_BCN',
#  'SATISF_RES_BCN_1A4',
#  'VAL_GESTMUNI_1A2',
#  'VAL_ESCOMBRARIES_1A2',
#  'VAL_NETEJA_1A2',
#  'VAL_SOROLL_1A2',
#  'VAL_VERD_1A2',
#  'VAL_ENLLUM_1A2',
#  'VAL_URBA_1A2',
#  'VAL_ASFALT_1A2',
#  'VAL_FACANES_1A2',
#  'VAL_CIRCUL_1A2',
#  'VAL_APARCA_1A2',
#  'VAL_BUS_1A2',
#  'VAL_METRO_1A2',
#  'VAL_GUB_1A2',
#  'VAL_SEGUR_1A2',
#  'VAL_SEGUR_BARRI_1A2',
#  'VAL_ESPORT_1A2',
#  'VAL_SIAC_1A2',
#  'VAL_CSS_1A2',
#  'VAL_CULT_1A2',
#  'VAL_FESTESPOP_1A2',
#  'VAL_MERCAT_1A2',
#  'VAL_BIBLIO_1A2',
#  'EVO1A_ESCOMBRARIES',
#  'EVO1A_NETEJA',
#  'EVO1A_SOROLL',
#  'EVO1A_VERD',
#  'EVO1A_ENLLUM',
#  'EVO1A_URBA',
#  'EVO1A_ASFALT',
#  'EVO1A_FACANES',
#  'EVO1A_CIRCUL',
#  'EVO1A_APARCA',
#  'EVO1A_BUS',
#  'EVO1A_METRO',
#  'EVO1A_GUB',
#  'EVO1A_SEGUR',
#  'EVO1A_SEGUR_BARRI',
#  'EVO1A_ESPORT',
#  'EVO1A_SIAC',
#  'EVO1A_CSS',
#  'EVO1A_CULT',
#  'EVO1A_FESTESPOP',
#  'EVO1A_MERCAT',
#  'EVO1A_BIBLIO',
#  'US_VERD',
#  'US_BUS',
#  'US_METRO',
#  'US_ESPORT',
#  'US_SIAC',
#  'US_CSS',
#  'US_CULT',
#  'US_FESTESPOP',
#  'US_MERCAT',
#  'US_BIBLIO',
#  'TRANSP_MOU',
#  'VAL_TRANSP_1A3',
#  'VAL_TRANSP_BARRI_1A3',
#  'EVO1A_BARRI',
#  'FUTUR_BARRI',
#  'SATISF_RES_BARRI_1A4',
#  'COMPARA_BARRI',
#  'CANVI_LLOC_RES_1A3',
#  'VAL_GESTBARRI_1A2',
#  'HAB_COTXE_PART',
#  'HAB_M2_1A14',
#  'LLAR_INGRESSOS_1A10',
#  'CLASSESOC_ENT',
#  'SENTPERTI',
#  'MUNI_VOTAR',
#  'LLOC_NAIX_1A4',
#  'LLENGUA_HAB',
#  'ESTUDIS_1A6',
#  'RESUM_PARENTIU',
#  'HAB_RES_1A4',
#  'Stay_in_the_same_neighborhood',
#  'Gender',
#  'Time_living_in_BCN',
#  'Time_living_in_barri',
#  'BCN_if_has_improved',
#  'BCN_if_will_improve',
#  'BCN_satisfaction_of_living',
#  'BCN_city_management',
#  'GARBAGE COLLECTION',
#  'STREETS CLEANING',
#  'NOISE',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'URBANISM',
#  'ASPHALT AND STREET CONSERVATION',
#  'FACADES AND BUILDING CONSERVATION',
#  'CIRCULATION',
#  'PARKING',
#  'MUNICIPAL POLICE',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'SPORTS FACILITIES',
#  'CITIZEN INFORMATION AND ATTENTION SERVICES',
#  'SOCIAL SERVICES CENTERS',
#  'CULTURAL ACTIVITIES',
#  'POPULAR FESTIVALS',
#  'MUNICIPAL MARKETS',
#  'PUBLIC LIBRARIES',
#  'Means_of_transport',
#  'BCN_transport',
#  'Barri_transport',
#  'Barri_if_has_improved',
#  'Barri_if_will_improve',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'Barri_city_management',
#  'Owns_a_car',
#  'House_M2',
#  'Social_class',
#  'Voted',
#  'Born_in_BCN',
#  'Living_alone']

# %% [markdown]
# Creating comparable variables - if respondends rate the city higher than the neighbourhood:
# 'BCN_if_has_improved' & 'Barri_if_has_improved', 'BCN_if_will_improve' & 'Barri_if_will_improve', 'BCN_satisfaction_of_living' & 'Barri_satisfaction_of_living', 'BCN_city_management' & 'Barri_city_management', 'BCN_transport' & 'Barri_transport'.

# %%
for i in [('BCN_if_has_improved', 'Barri_if_has_improved'), 
          ('BCN_if_will_improve', 'Barri_if_will_improve'), 
          ('BCN_satisfaction_of_living', 'Barri_satisfaction_of_living'), 
          ('BCN_city_management', 'Barri_city_management'), 
          ('BCN_transport', 'Barri_transport')]:
    print(i)
    new_column = []
    for j in range(len(data)):
        if data.iloc[j][i[0]] == data.iloc[j][i[1]]:
            new_column.append('Equal')
        elif data.iloc[j][i[0]] > data.iloc[j][i[1]]:
            new_column.append('BCN over Barri')
        elif data.iloc[j][i[0]] < data.iloc[j][i[1]]:
            new_column.append('Barri over BCN')
    data['Compare_'+str(i[0][4:])] = new_column
# Out:
# ('BCN_if_has_improved', 'Barri_if_has_improved')
# ('BCN_if_will_improve', 'Barri_if_will_improve')
# ('BCN_satisfaction_of_living', 'Barri_satisfaction_of_living')
# ('BCN_city_management', 'Barri_city_management')
# ('BCN_transport', 'Barri_transport')

# %%
data.head()
# Out:
#         ANY NOM_DISTRICTE           NOM_BARRI           GRANBARRI   SEXE  \
# 81817  2011      EIXAMPLE  LA SAGRADA FAMÍLIA  LA SAGRADA FAMÍLIA  WOMAN
# 81819  2011      EIXAMPLE  LA SAGRADA FAMÍLIA  LA SAGRADA FAMÍLIA  WOMAN
# 81821  2011      EIXAMPLE  LA SAGRADA FAMÍLIA  LA SAGRADA FAMÍLIA  WOMAN
# 81823  2011      EIXAMPLE  LA SAGRADA FAMÍLIA  LA SAGRADA FAMÍLIA  WOMAN
# 81824  2011      EIXAMPLE  LA SAGRADA FAMÍLIA  LA SAGRADA FAMÍLIA    MAN
#
#             EDAT1899_1A6 NACIO_ACT_UE                  TMP_RES_BCN_1A6  \
# 81817  65 YEARS AND OVER      SPANISH               MORE THAN 10 YEARS
# 81819  65 YEARS AND OVER      SPANISH  I HAVE ALWAYS LIVED IN THE CITY
# 81821  65 YEARS AND OVER      SPANISH  I HAVE ALWAYS LIVED IN THE CITY
# 81823  65 YEARS AND OVER      SPANISH               MORE THAN 10 YEARS
# 81824  65 YEARS AND OVER      SPANISH  I HAVE ALWAYS LIVED IN THE CITY
#
#                           TMP_RES_BARRI_1A6      EVO1A_BCN  ...   House_M2  \
# 81817                    MORE THAN 10 YEARS     IT'S WORSE  ...  51-100 M2
# 81819                    MORE THAN 10 YEARS     IT'S WORSE  ...  51-100 M2
# 81821                    MORE THAN 10 YEARS  IT'S THE SAME  ...  51-100 M2
# 81823  MORE THAN 5 YEARS AND UP TO 10 YEARS     IT'S WORSE  ...  51-100 M2
# 81824                    MORE THAN 10 YEARS  IT'S THE SAME  ...    < 50 M2
#
#         Social_class Voted Born_in_BCN Living_alone Compare_if_has_improved  \
# 81817    MIDDLE-HIGH     1           0            1                   Equal
# 81819  MIDDLE-MIDDLE     1           1            0          Barri over BCN
# 81821  MIDDLE-MIDDLE     1           1            1          BCN over Barri
# 81823  MIDDLE-MIDDLE     1           1            1                   Equal
# 81824     MIDDLE-LOW     1           1            0                   Equal
#
#       Compare_if_will_improve Compare_satisfaction_of_living  \
# 81817                   Equal                 BCN over Barri
# 81819          Barri over BCN                          Equal
# 81821          BCN over Barri                          Equal
# 81823          BCN over Barri                          Equal
# 81824                   Equal                 BCN over Barri
#
#       Compare_city_management Compare_transport
# 81817                   Equal             Equal
# 81819                   Equal    Barri over BCN
# 81821          Barri over BCN             Equal
# 81823                   Equal             Equal
# 81824          Barri over BCN    Barri over BCN
#
# [5 rows x 134 columns]

# %% [markdown]
# # 1.5 Final dataset

# %%
data.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'NOM_BARRI',
#  'GRANBARRI',
#  'SEXE',
#  'EDAT1899_1A6',
#  'NACIO_ACT_UE',
#  'TMP_RES_BCN_1A6',
#  'TMP_RES_BARRI_1A6',
#  'EVO1A_BCN',
#  'FUTUR_BCN',
#  'SATISF_RES_BCN_1A4',
#  'VAL_GESTMUNI_1A2',
#  'VAL_ESCOMBRARIES_1A2',
#  'VAL_NETEJA_1A2',
#  'VAL_SOROLL_1A2',
#  'VAL_VERD_1A2',
#  'VAL_ENLLUM_1A2',
#  'VAL_URBA_1A2',
#  'VAL_ASFALT_1A2',
#  'VAL_FACANES_1A2',
#  'VAL_CIRCUL_1A2',
#  'VAL_APARCA_1A2',
#  'VAL_BUS_1A2',
#  'VAL_METRO_1A2',
#  'VAL_GUB_1A2',
#  'VAL_SEGUR_1A2',
#  'VAL_SEGUR_BARRI_1A2',
#  'VAL_ESPORT_1A2',
#  'VAL_SIAC_1A2',
#  'VAL_CSS_1A2',
#  'VAL_CULT_1A2',
#  'VAL_FESTESPOP_1A2',
#  'VAL_MERCAT_1A2',
#  'VAL_BIBLIO_1A2',
#  'EVO1A_ESCOMBRARIES',
#  'EVO1A_NETEJA',
#  'EVO1A_SOROLL',
#  'EVO1A_VERD',
#  'EVO1A_ENLLUM',
#  'EVO1A_URBA',
#  'EVO1A_ASFALT',
#  'EVO1A_FACANES',
#  'EVO1A_CIRCUL',
#  'EVO1A_APARCA',
#  'EVO1A_BUS',
#  'EVO1A_METRO',
#  'EVO1A_GUB',
#  'EVO1A_SEGUR',
#  'EVO1A_SEGUR_BARRI',
#  'EVO1A_ESPORT',
#  'EVO1A_SIAC',
#  'EVO1A_CSS',
#  'EVO1A_CULT',
#  'EVO1A_FESTESPOP',
#  'EVO1A_MERCAT',
#  'EVO1A_BIBLIO',
#  'US_VERD',
#  'US_BUS',
#  'US_METRO',
#  'US_ESPORT',
#  'US_SIAC',
#  'US_CSS',
#  'US_CULT',
#  'US_FESTESPOP',
#  'US_MERCAT',
#  'US_BIBLIO',
#  'TRANSP_MOU',
#  'VAL_TRANSP_1A3',
#  'VAL_TRANSP_BARRI_1A3',
#  'EVO1A_BARRI',
#  'FUTUR_BARRI',
#  'SATISF_RES_BARRI_1A4',
#  'COMPARA_BARRI',
#  'CANVI_LLOC_RES_1A3',
#  'VAL_GESTBARRI_1A2',
#  'HAB_COTXE_PART',
#  'HAB_M2_1A14',
#  'LLAR_INGRESSOS_1A10',
#  'CLASSESOC_ENT',
#  'SENTPERTI',
#  'MUNI_VOTAR',
#  'LLOC_NAIX_1A4',
#  'LLENGUA_HAB',
#  'ESTUDIS_1A6',
#  'RESUM_PARENTIU',
#  'HAB_RES_1A4',
#  'Stay_in_the_same_neighborhood',
#  'Gender',
#  'Time_living_in_BCN',
#  'Time_living_in_barri',
#  'BCN_if_has_improved',
#  'BCN_if_will_improve',
#  'BCN_satisfaction_of_living',
#  'BCN_city_management',
#  'GARBAGE COLLECTION',
#  'STREETS CLEANING',
#  'NOISE',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'URBANISM',
#  'ASPHALT AND STREET CONSERVATION',
#  'FACADES AND BUILDING CONSERVATION',
#  'CIRCULATION',
#  'PARKING',
#  'MUNICIPAL POLICE',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'SPORTS FACILITIES',
#  'CITIZEN INFORMATION AND ATTENTION SERVICES',
#  'SOCIAL SERVICES CENTERS',
#  'CULTURAL ACTIVITIES',
#  'POPULAR FESTIVALS',
#  'MUNICIPAL MARKETS',
#  'PUBLIC LIBRARIES',
#  'Means_of_transport',
#  'BCN_transport',
#  'Barri_transport',
#  'Barri_if_has_improved',
#  'Barri_if_will_improve',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'Barri_city_management',
#  'Owns_a_car',
#  'House_M2',
#  'Social_class',
#  'Voted',
#  'Born_in_BCN',
#  'Living_alone',
#  'Compare_if_has_improved',
#  'Compare_if_will_improve',
#  'Compare_satisfaction_of_living',
#  'Compare_city_management',
#  'Compare_transport']

# %%
survey_transformed = data[['ANY', 
                    'Stay_in_the_same_neighborhood', 
                    'Gender', 'Time_living_in_BCN', 'Time_living_in_barri', 
                    'BCN_if_has_improved', 'BCN_if_will_improve', 'BCN_satisfaction_of_living', 'BCN_city_management',
                    'GARBAGE COLLECTION', 'STREETS CLEANING', 'NOISE', 'GREEN AREAS', 'PUBLIC LIGHTING', 'URBANISM',
                    'ASPHALT AND STREET CONSERVATION', 'FACADES AND BUILDING CONSERVATION', 'CIRCULATION',
                    'PARKING', 'MUNICIPAL POLICE', 'CITIZEN SECURITY IN THE CITY AS A WHOLE',
                    'CITIZEN SECURITY IN THE NEIGHBORHOOD', 'SPORTS FACILITIES',
                    'CITIZEN INFORMATION AND ATTENTION SERVICES', 'SOCIAL SERVICES CENTERS', 'CULTURAL ACTIVITIES',
                    'POPULAR FESTIVALS', 'MUNICIPAL MARKETS', 'PUBLIC LIBRARIES',
                    'Means_of_transport', 'BCN_transport', 'Barri_transport', 
                    'Barri_if_has_improved', 'Barri_if_will_improve', 'Barri_satisfaction_of_living',
                    'Barri_comparison', 'Barri_city_management', 
                    'Owns_a_car', 'House_M2', 'Social_class', 'Voted', 
                    'Born_in_BCN', 'Living_alone', 'Compare_if_has_improved', 'Compare_if_will_improve',
                    'Compare_satisfaction_of_living', 'Compare_city_management', 'Compare_transport']]

# %%
survey_transformed.reset_index(drop=True, inplace=True)

# %%
survey_transformed.to_pickle("survey_transformed.pkl")
