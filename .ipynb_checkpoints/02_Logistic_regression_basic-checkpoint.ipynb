# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Predictors of elderly citizens willingness to stay in the neighbourhood
# # Logistic regression

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import r2_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from scipy import stats

# %%
data = pd.read_pickle("survey_transformed.pkl")

# %%
data.head()
# Out:
#     ANY  Stay_in_the_same_neighborhood  Gender  \
# 0  2011                              1       1
# 1  2011                              1       1
# 2  2011                              1       1
# 3  2011                              1       1
# 4  2011                              0       0
#
#                 Time_living_in_BCN Time_living_in_barri  BCN_if_has_improved  \
# 0               MORE THAN 10 YEARS   MORE THAN 10 YEARS                   -1
# 1  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                   -1
# 2  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                    0
# 3               MORE THAN 10 YEARS   LESS THAN 10 YEARS                   -1
# 4  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                    0
#
#    BCN_if_will_improve  BCN_satisfaction_of_living  BCN_city_management  \
# 0                   -1                           3                    1
# 1                   -1                           4                    1
# 2                    1                           4                   -1
# 3                    0                           4                    1
# 4                    0                           4                   -1
#
#    GARBAGE COLLECTION  ...   House_M2   Social_class  Voted  Born_in_BCN  \
# 0                   1  ...  51-100 M2    MIDDLE-HIGH      1            0
# 1                  -1  ...  51-100 M2  MIDDLE-MIDDLE      1            1
# 2                   1  ...  51-100 M2  MIDDLE-MIDDLE      1            1
# 3                   1  ...  51-100 M2  MIDDLE-MIDDLE      1            1
# 4                  -1  ...    < 50 M2     MIDDLE-LOW      1            1
#
#    Living_alone  Compare_if_has_improved  Compare_if_will_improve  \
# 0             1                    Equal                    Equal
# 1             0           Barri over BCN           Barri over BCN
# 2             1           BCN over Barri           BCN over Barri
# 3             1                    Equal           BCN over Barri
# 4             0                    Equal                    Equal
#
#    Compare_satisfaction_of_living  Compare_city_management  Compare_transport
# 0                  BCN over Barri                    Equal              Equal
# 1                           Equal                    Equal     Barri over BCN
# 2                           Equal           Barri over BCN              Equal
# 3                           Equal                    Equal              Equal
# 4                  BCN over Barri           Barri over BCN     Barri over BCN
#
# [5 rows x 48 columns]

# %%
data.shape
# Out:
# (13742, 48)

# %%
for i in data.columns:
    if data[i].isnull().sum() > 1 :
        print(i, data[i].isnull().sum())
# Out:
# Means_of_transport 2

# %%
data = data.dropna()

# %%
data_train = data.query('ANY < 2019')
data_test = data.query('ANY == 2019')

# %%
print("Train dataset shape:", data_train.shape, " Test dataset shape:", data_test.shape)
# Out:
# Train dataset shape: (12258, 48)  Test dataset shape: (1482, 48)

# %%
independent = data.columns.tolist()
for i in ['ANY', 'Stay_in_the_same_neighborhood']:
    independent.remove(i)

# %%
dependent = 'Stay_in_the_same_neighborhood'

# %%
x = data_train[independent]
y = data_train[dependent]

# %%
x = pd.get_dummies(x, drop_first = True)

# %%
# Training dataset is highly unbalanced
data_train.groupby(['Stay_in_the_same_neighborhood']).size()
# Out:
# Stay_in_the_same_neighborhood
# 0    2826
# 1    9432
# dtype: int64

# %%
os = SMOTE(random_state=0)
columns = x.columns
os_data_x, os_data_y=os.fit_sample(x, y)
os_data_x = pd.DataFrame(data=os_data_x, columns=columns )
os_data_y= pd.DataFrame(data=os_data_y, columns=['Stay_in_the_same_neighborhood'])

# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_x))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==0]))
print("Number of subscription",len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==1]))
print("Proportion of no subscription data in oversampled data is ",
      len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==0])/len(os_data_x))
print("Proportion of subscription data in oversampled data is ",
      len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==1])/len(os_data_x))
# Out:
# length of oversampled data is  18864
# Number of no subscription in oversampled data 9432
# Number of subscription 9432
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
logit_model = sm.Logit(os_data_y,os_data_x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.528405
#          Iterations 6
#                                         Results: Logit
# ==============================================================================================
# Model:                    Logit                              Pseudo R-squared:      0.238
# Dependent Variable:       Stay_in_the_same_neighborhood      AIC:                   20061.6508
# Date:                     2021-03-23 22:45                   BIC:                   20555.8864
# No. Observations:         18864                              Log-Likelihood:        -9967.8
# Df Model:                 62                                 LL-Null:               -13076.
# Df Residuals:             18801                              LLR p-value:           0.0000
# Converged:                1.0000                             Scale:                 1.0000
# No. Iterations:           6.0000
# ----------------------------------------------------------------------------------------------
#                                                Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ----------------------------------------------------------------------------------------------
# Gender                                         0.3772   0.0374  10.0926 0.0000  0.3039  0.4504
# BCN_if_has_improved                            0.1380   0.0387   3.5627 0.0004  0.0621  0.2140
# BCN_if_will_improve                            0.1391   0.0410   3.3914 0.0007  0.0587  0.2195
# BCN_satisfaction_of_living                    -0.1577   0.0359  -4.3889 0.0000 -0.2281 -0.0873
# BCN_city_management                           -0.2265   0.0467  -4.8463 0.0000 -0.3181 -0.1349
# GARBAGE COLLECTION                            -0.5744   0.0441 -13.0195 0.0000 -0.6608 -0.4879
# STREETS CLEANING                              -0.0556   0.0275  -2.0221 0.0432 -0.1095 -0.0017
# NOISE                                          0.2154   0.0206  10.4426 0.0000  0.1750  0.2559
# GREEN AREAS                                   -0.0676   0.0263  -2.5706 0.0102 -0.1191 -0.0161
# PUBLIC LIGHTING                               -0.2620   0.0331  -7.9130 0.0000 -0.3269 -0.1971
# URBANISM                                       0.0515   0.0295   1.7463 0.0808 -0.0063  0.1093
# ASPHALT AND STREET CONSERVATION                0.0559   0.0245   2.2779 0.0227  0.0078  0.1039
# FACADES AND BUILDING CONSERVATION             -0.1381   0.0289  -4.7771 0.0000 -0.1947 -0.0814
# CIRCULATION                                    0.0358   0.0217   1.6488 0.0992 -0.0068  0.0783
# PARKING                                        0.0825   0.0225   3.6714 0.0002  0.0385  0.1265
# MUNICIPAL POLICE                               0.0243   0.0250   0.9704 0.3319 -0.0247  0.0732
# CITIZEN SECURITY IN THE CITY AS A WHOLE       -0.0713   0.0254  -2.8096 0.0050 -0.1211 -0.0216
# CITIZEN SECURITY IN THE NEIGHBORHOOD           0.0669   0.0262   2.5539 0.0107  0.0156  0.1182
# SPORTS FACILITIES                              0.0386   0.0304   1.2693 0.2044 -0.0210  0.0981
# CITIZEN INFORMATION AND ATTENTION SERVICES    -0.1014   0.0324  -3.1267 0.0018 -0.1650 -0.0378
# SOCIAL SERVICES CENTERS                        0.1678   0.0308   5.4404 0.0000  0.1074  0.2283
# CULTURAL ACTIVITIES                            0.0528   0.0363   1.4540 0.1459 -0.0184  0.1241
# POPULAR FESTIVALS                              0.0841   0.0326   2.5833 0.0098  0.0203  0.1479
# MUNICIPAL MARKETS                             -0.3270   0.0341  -9.5850 0.0000 -0.3938 -0.2601
# PUBLIC LIBRARIES                              -0.1262   0.0369  -3.4222 0.0006 -0.1984 -0.0539
# BCN_transport                                 -0.2219   0.0489  -4.5410 0.0000 -0.3176 -0.1261
# Barri_transport                                0.0816   0.0465   1.7536 0.0795 -0.0096  0.1728
# Barri_if_has_improved                          0.1389   0.0397   3.5037 0.0005  0.0612  0.2166
# Barri_if_will_improve                          0.0789   0.0425   1.8558 0.0635 -0.0044  0.1622
# Barri_satisfaction_of_living                   0.0608   0.0393   1.5465 0.1220 -0.0162  0.1378
# Barri_comparison                               1.3624   0.0355  38.3421 0.0000  1.2927  1.4320
# Barri_city_management                          0.4588   0.0460   9.9763 0.0000  0.3687  0.5489
# Owns_a_car                                     0.1209   0.0391   3.0878 0.0020  0.0442  0.1976
# Voted                                         -0.3086   0.0442  -6.9799 0.0000 -0.3952 -0.2219
# Born_in_BCN                                    0.3515   0.0618   5.6884 0.0000  0.2304  0.4726
# Living_alone                                   0.3305   0.0453   7.2993 0.0000  0.2417  0.4192
# Time_living_in_BCN_LESS THAN 10 YEARS          0.6178   0.1891   3.2672 0.0011  0.2472  0.9884
# Time_living_in_BCN_MORE THAN 10 YEARS          0.5905   0.0626   9.4363 0.0000  0.4678  0.7131
# Time_living_in_barri_LESS THAN 10 YEARS       -0.8639   0.1056  -8.1811 0.0000 -1.0709 -0.6570
# Time_living_in_barri_MORE THAN 10 YEARS       -0.7007   0.0523 -13.4085 0.0000 -0.8032 -0.5983
# Means_of_transport_CAR                         0.9321   0.1176   7.9249 0.0000  0.7015  1.1626
# Means_of_transport_MOTORCYCLE                  0.5096   0.2240   2.2748 0.0229  0.0705  0.9487
# Means_of_transport_OTHERS                      1.0182   0.4437   2.2944 0.0218  0.1484  1.8879
# Means_of_transport_PUBLIC TRANSPORT            0.2773   0.0641   4.3253 0.0000  0.1516  0.4029
# Means_of_transport_TAXI                        1.7276   0.1737   9.9480 0.0000  1.3872  2.0680
# Means_of_transport_WALKING                     0.8507   0.0817  10.4151 0.0000  0.6906  1.0108
# House_M2_51-100 M2                            -0.1471   0.0475  -3.0956 0.0020 -0.2402 -0.0540
# House_M2_< 50 M2                               0.2578   0.0923   2.7934 0.0052  0.0769  0.4387
# House_M2_> 150 M2                              0.6649   0.1343   4.9498 0.0000  0.4016  0.9282
# Social_class_LOW                               1.5721   0.0851  18.4832 0.0000  1.4054  1.7388
# Social_class_MIDDLE-HIGH                       1.8695   0.1360  13.7441 0.0000  1.6029  2.1361
# Social_class_MIDDLE-LOW                        1.2796   0.0655  19.5426 0.0000  1.1513  1.4079
# Social_class_MIDDLE-MIDDLE                     1.2804   0.0626  20.4514 0.0000  1.1577  1.4031
# Compare_if_has_improved_Barri over BCN        -0.0661   0.0833  -0.7938 0.4273 -0.2294  0.0971
# Compare_if_has_improved_Equal                  0.0197   0.0526   0.3735 0.7088 -0.0835  0.1229
# Compare_if_will_improve_Barri over BCN         0.3605   0.0907   3.9750 0.0001  0.1827  0.5382
# Compare_if_will_improve_Equal                  0.1789   0.0522   3.4242 0.0006  0.0765  0.2813
# Compare_satisfaction_of_living_Barri over BCN  0.2868   0.0893   3.2138 0.0013  0.1119  0.4618
# Compare_satisfaction_of_living_Equal           0.5002   0.0520   9.6257 0.0000  0.3984  0.6021
# Compare_city_management_Barri over BCN        -0.9660   0.1249  -7.7315 0.0000 -1.2109 -0.7211
# Compare_city_management_Equal                 -0.8001   0.0633 -12.6319 0.0000 -0.9242 -0.6760
# Compare_transport_Barri over BCN              -0.4708   0.1230  -3.8263 0.0001 -0.7119 -0.2296
# Compare_transport_Equal                       -0.3665   0.0639  -5.7340 0.0000 -0.4918 -0.2412
# ==============================================================================================

# %%
pd.DataFrame(result.pvalues.sort_values(ascending=False))
# Out:
#                                                    0
# Compare_if_has_improved_Equal           7.087771e-01
# Compare_if_has_improved_Barri over BCN  4.273007e-01
# MUNICIPAL POLICE                        3.318717e-01
# SPORTS FACILITIES                       2.043505e-01
# CULTURAL ACTIVITIES                     1.459410e-01
# ...                                              ...
# Social_class_MIDDLE-HIGH                5.527069e-43
# Social_class_LOW                        2.820806e-76
# Social_class_MIDDLE-LOW                 4.769244e-85
# Social_class_MIDDLE-MIDDLE              5.839716e-93
# Barri_comparison                        0.000000e+00
#
# [63 rows x 1 columns]

# %%
features = os_data_x.columns.tolist()
for i in ['Compare_if_has_improved_Equal', 'Compare_if_has_improved_Barri over BCN', 'MUNICIPAL POLICE',
         'SPORTS FACILITIES', 'CULTURAL ACTIVITIES', 'Barri_satisfaction_of_living']:
    features.remove(i)

# %%
os_data_x = os_data_x[features]

# %%
logit_model = sm.Logit(os_data_y,os_data_x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.528669
#          Iterations 6
#                                         Results: Logit
# ==============================================================================================
# Model:                    Logit                              Pseudo R-squared:      0.237
# Dependent Variable:       Stay_in_the_same_neighborhood      AIC:                   20059.6349
# Date:                     2021-03-23 22:45                   BIC:                   20506.8005
# No. Observations:         18864                              Log-Likelihood:        -9972.8
# Df Model:                 56                                 LL-Null:               -13076.
# Df Residuals:             18807                              LLR p-value:           0.0000
# Converged:                1.0000                             Scale:                 1.0000
# No. Iterations:           6.0000
# ----------------------------------------------------------------------------------------------
#                                                Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ----------------------------------------------------------------------------------------------
# Gender                                         0.3763   0.0373  10.0834 0.0000  0.3032  0.4494
# BCN_if_has_improved                            0.1703   0.0247   6.8966 0.0000  0.1219  0.2187
# BCN_if_will_improve                            0.1392   0.0409   3.4080 0.0007  0.0592  0.2193
# BCN_satisfaction_of_living                    -0.1173   0.0239  -4.9147 0.0000 -0.1641 -0.0705
# BCN_city_management                           -0.2260   0.0467  -4.8401 0.0000 -0.3175 -0.1345
# GARBAGE COLLECTION                            -0.5695   0.0440 -12.9455 0.0000 -0.6557 -0.4833
# STREETS CLEANING                              -0.0557   0.0275  -2.0279 0.0426 -0.1095 -0.0019
# NOISE                                          0.2139   0.0206  10.3961 0.0000  0.1736  0.2543
# GREEN AREAS                                   -0.0621   0.0261  -2.3772 0.0174 -0.1134 -0.0109
# PUBLIC LIGHTING                               -0.2606   0.0330  -7.8870 0.0000 -0.3253 -0.1958
# URBANISM                                       0.0554   0.0294   1.8850 0.0594 -0.0022  0.1131
# ASPHALT AND STREET CONSERVATION                0.0564   0.0245   2.3020 0.0213  0.0084  0.1044
# FACADES AND BUILDING CONSERVATION             -0.1340   0.0288  -4.6526 0.0000 -0.1905 -0.0776
# CIRCULATION                                    0.0369   0.0217   1.7004 0.0891 -0.0056  0.0794
# PARKING                                        0.0843   0.0224   3.7595 0.0002  0.0404  0.1283
# CITIZEN SECURITY IN THE CITY AS A WHOLE       -0.0691   0.0253  -2.7317 0.0063 -0.1187 -0.0195
# CITIZEN SECURITY IN THE NEIGHBORHOOD           0.0711   0.0261   2.7295 0.0063  0.0200  0.1222
# CITIZEN INFORMATION AND ATTENTION SERVICES    -0.0891   0.0321  -2.7782 0.0055 -0.1519 -0.0262
# SOCIAL SERVICES CENTERS                        0.1764   0.0306   5.7566 0.0000  0.1163  0.2365
# POPULAR FESTIVALS                              0.0993   0.0317   3.1274 0.0018  0.0371  0.1615
# MUNICIPAL MARKETS                             -0.3183   0.0339  -9.3849 0.0000 -0.3847 -0.2518
# PUBLIC LIBRARIES                              -0.1048   0.0354  -2.9561 0.0031 -0.1742 -0.0353
# BCN_transport                                 -0.2226   0.0488  -4.5607 0.0000 -0.3182 -0.1269
# Barri_transport                                0.0872   0.0465   1.8763 0.0606 -0.0039  0.1782
# Barri_if_has_improved                          0.1130   0.0281   4.0227 0.0001  0.0579  0.1680
# Barri_if_will_improve                          0.0831   0.0423   1.9629 0.0497  0.0001  0.1661
# Barri_comparison                               1.3669   0.0353  38.7102 0.0000  1.2977  1.4361
# Barri_city_management                          0.4653   0.0459  10.1422 0.0000  0.3754  0.5553
# Owns_a_car                                     0.1199   0.0391   3.0685 0.0022  0.0433  0.1964
# Voted                                         -0.3064   0.0442  -6.9397 0.0000 -0.3930 -0.2199
# Born_in_BCN                                    0.3506   0.0616   5.6922 0.0000  0.2299  0.4714
# Living_alone                                   0.3313   0.0452   7.3253 0.0000  0.2426  0.4199
# Time_living_in_BCN_LESS THAN 10 YEARS          0.6257   0.1888   3.3144 0.0009  0.2557  0.9957
# Time_living_in_BCN_MORE THAN 10 YEARS          0.5895   0.0624   9.4511 0.0000  0.4672  0.7117
# Time_living_in_barri_LESS THAN 10 YEARS       -0.8767   0.1053  -8.3229 0.0000 -1.0831 -0.6702
# Time_living_in_barri_MORE THAN 10 YEARS       -0.7036   0.0522 -13.4746 0.0000 -0.8059 -0.6013
# Means_of_transport_CAR                         0.9299   0.1174   7.9230 0.0000  0.6999  1.1599
# Means_of_transport_MOTORCYCLE                  0.5035   0.2236   2.2517 0.0243  0.0652  0.9419
# Means_of_transport_OTHERS                      0.9964   0.4418   2.2550 0.0241  0.1304  1.8624
# Means_of_transport_PUBLIC TRANSPORT            0.2773   0.0639   4.3420 0.0000  0.1521  0.4024
# Means_of_transport_TAXI                        1.7247   0.1734   9.9481 0.0000  1.3849  2.0645
# Means_of_transport_WALKING                     0.8542   0.0814  10.4895 0.0000  0.6946  1.0138
# House_M2_51-100 M2                            -0.1477   0.0474  -3.1122 0.0019 -0.2406 -0.0547
# House_M2_< 50 M2                               0.2597   0.0923   2.8138 0.0049  0.0788  0.4406
# House_M2_> 150 M2                              0.6653   0.1342   4.9577 0.0000  0.4023  0.9283
# Social_class_LOW                               1.5643   0.0848  18.4444 0.0000  1.3981  1.7305
# Social_class_MIDDLE-HIGH                       1.8626   0.1358  13.7153 0.0000  1.5964  2.1287
# Social_class_MIDDLE-LOW                        1.2753   0.0653  19.5328 0.0000  1.1473  1.4033
# Social_class_MIDDLE-MIDDLE                     1.2763   0.0625  20.4320 0.0000  1.1539  1.3987
# Compare_if_will_improve_Barri over BCN         0.3618   0.0902   4.0113 0.0001  0.1850  0.5386
# Compare_if_will_improve_Equal                  0.1858   0.0517   3.5964 0.0003  0.0846  0.2871
# Compare_satisfaction_of_living_Barri over BCN  0.3876   0.0587   6.5983 0.0000  0.2724  0.5027
# Compare_satisfaction_of_living_Equal           0.5480   0.0409  13.3826 0.0000  0.4677  0.6282
# Compare_city_management_Barri over BCN        -0.9627   0.1247  -7.7213 0.0000 -1.2071 -0.7183
# Compare_city_management_Equal                 -0.7936   0.0631 -12.5759 0.0000 -0.9172 -0.6699
# Compare_transport_Barri over BCN              -0.4721   0.1229  -3.8401 0.0001 -0.7130 -0.2311
# Compare_transport_Equal                       -0.3641   0.0638  -5.7072 0.0000 -0.4891 -0.2390
# ==============================================================================================

# %%
margeff = result.get_margeff()
print(margeff.summary())
# Out:
#              Logit Marginal Effects
# ================================================
# Dep. Variable:     Stay_in_the_same_neighborhood
# Method:                                     dydx
# At:                                      overall
# =================================================================================================================
#                                                    dy/dx    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Gender                                            0.0666      0.007     10.177      0.000       0.054       0.079
# BCN_if_has_improved                               0.0301      0.004      6.926      0.000       0.022       0.039
# BCN_if_will_improve                               0.0246      0.007      3.412      0.001       0.010       0.039
# BCN_satisfaction_of_living                       -0.0208      0.004     -4.926      0.000      -0.029      -0.012
# BCN_city_management                              -0.0400      0.008     -4.850      0.000      -0.056      -0.024
# GARBAGE COLLECTION                               -0.1007      0.008    -13.144      0.000      -0.116      -0.086
# STREETS CLEANING                                 -0.0099      0.005     -2.029      0.042      -0.019      -0.000
# NOISE                                             0.0378      0.004     10.499      0.000       0.031       0.045
# GREEN AREAS                                      -0.0110      0.005     -2.378      0.017      -0.020      -0.002
# PUBLIC LIGHTING                                  -0.0461      0.006     -7.932      0.000      -0.057      -0.035
# URBANISM                                          0.0098      0.005      1.886      0.059      -0.000       0.020
# ASPHALT AND STREET CONSERVATION                   0.0100      0.004      2.303      0.021       0.001       0.018
# FACADES AND BUILDING CONSERVATION                -0.0237      0.005     -4.662      0.000      -0.034      -0.014
# CIRCULATION                                       0.0065      0.004      1.701      0.089      -0.001       0.014
# PARKING                                           0.0149      0.004      3.764      0.000       0.007       0.023
# CITIZEN SECURITY IN THE CITY AS A WHOLE          -0.0122      0.004     -2.734      0.006      -0.021      -0.003
# CITIZEN SECURITY IN THE NEIGHBORHOOD              0.0126      0.005      2.731      0.006       0.004       0.022
# CITIZEN INFORMATION AND ATTENTION SERVICES       -0.0158      0.006     -2.780      0.005      -0.027      -0.005
# SOCIAL SERVICES CENTERS                           0.0312      0.005      5.774      0.000       0.021       0.042
# POPULAR FESTIVALS                                 0.0176      0.006      3.130      0.002       0.007       0.029
# MUNICIPAL MARKETS                                -0.0563      0.006     -9.460      0.000      -0.068      -0.045
# PUBLIC LIBRARIES                                 -0.0185      0.006     -2.958      0.003      -0.031      -0.006
# BCN_transport                                    -0.0394      0.009     -4.569      0.000      -0.056      -0.022
# Barri_transport                                   0.0154      0.008      1.877      0.061      -0.001       0.032
# Barri_if_has_improved                             0.0200      0.005      4.028      0.000       0.010       0.030
# Barri_if_will_improve                             0.0147      0.007      1.964      0.050    2.72e-05       0.029
# Barri_comparison                                  0.2418      0.005     45.667      0.000       0.231       0.252
# Barri_city_management                             0.0823      0.008     10.236      0.000       0.067       0.098
# Owns_a_car                                        0.0212      0.007      3.071      0.002       0.008       0.035
# Voted                                            -0.0542      0.008     -6.970      0.000      -0.069      -0.039
# Born_in_BCN                                       0.0620      0.011      5.709      0.000       0.041       0.083
# Living_alone                                      0.0586      0.008      7.361      0.000       0.043       0.074
# Time_living_in_BCN_LESS THAN 10 YEARS             0.1107      0.033      3.318      0.001       0.045       0.176
# Time_living_in_BCN_MORE THAN 10 YEARS             0.1043      0.011      9.528      0.000       0.083       0.126
# Time_living_in_barri_LESS THAN 10 YEARS          -0.1551      0.019     -8.375      0.000      -0.191      -0.119
# Time_living_in_barri_MORE THAN 10 YEARS          -0.1245      0.009    -13.699      0.000      -0.142      -0.107
# Means_of_transport_CAR                            0.1645      0.021      7.968      0.000       0.124       0.205
# Means_of_transport_MOTORCYCLE                     0.0891      0.040      2.253      0.024       0.012       0.167
# Means_of_transport_OTHERS                         0.1763      0.078      2.256      0.024       0.023       0.329
# Means_of_transport_PUBLIC TRANSPORT               0.0490      0.011      4.350      0.000       0.027       0.071
# Means_of_transport_TAXI                           0.3051      0.030     10.031      0.000       0.245       0.365
# Means_of_transport_WALKING                        0.1511      0.014     10.597      0.000       0.123       0.179
# House_M2_51-100 M2                               -0.0261      0.008     -3.115      0.002      -0.043      -0.010
# House_M2_< 50 M2                                  0.0459      0.016      2.816      0.005       0.014       0.078
# House_M2_> 150 M2                                 0.1177      0.024      4.968      0.000       0.071       0.164
# Social_class_LOW                                  0.2767      0.015     19.024      0.000       0.248       0.305
# Social_class_MIDDLE-HIGH                          0.3295      0.024     13.942      0.000       0.283       0.376
# Social_class_MIDDLE-LOW                           0.2256      0.011     20.213      0.000       0.204       0.247
# Social_class_MIDDLE-MIDDLE                        0.2258      0.011     21.222      0.000       0.205       0.247
# Compare_if_will_improve_Barri over BCN            0.0640      0.016      4.017      0.000       0.033       0.095
# Compare_if_will_improve_Equal                     0.0329      0.009      3.601      0.000       0.015       0.051
# Compare_satisfaction_of_living_Barri over BCN     0.0686      0.010      6.625      0.000       0.048       0.089
# Compare_satisfaction_of_living_Equal              0.0969      0.007     13.610      0.000       0.083       0.111
# Compare_city_management_Barri over BCN           -0.1703      0.022     -7.763      0.000      -0.213      -0.127
# Compare_city_management_Equal                    -0.1404      0.011    -12.757      0.000      -0.162      -0.119
# Compare_transport_Barri over BCN                 -0.0835      0.022     -3.845      0.000      -0.126      -0.041
# Compare_transport_Equal                          -0.0644      0.011     -5.724      0.000      -0.086      -0.042
# =================================================================================================================

# %%
for i in ['Compare_if_has_improved', 'MUNICIPAL POLICE','SPORTS FACILITIES', 'CULTURAL ACTIVITIES',
          'Barri_satisfaction_of_living']:
    independent.remove(i)

# %%
import seaborn as sns # just a conventional alias, don't know why
sns.set(style="white")

corr = data_train[independent].corr('spearman')

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, annot = corr.round(2), linewidths=.5, cbar_kws={"shrink": .5})

# %%
data_test = pd.get_dummies(data_test)

# %%
data_test.groupby(['Stay_in_the_same_neighborhood']).size()
# Out:
# Stay_in_the_same_neighborhood
# 0     417
# 1    1065
# dtype: int64

# %%
print("Rate if we predict 1 for whole dataset: ", data_test.groupby(['Stay_in_the_same_neighborhood']).size()[1]/(data_test.groupby(['Stay_in_the_same_neighborhood']).size()[0]+data_test.groupby(['Stay_in_the_same_neighborhood']).size()[1]))
# Out:
# 0.7186234817813765

# %%
x_test = data_test[features]
y_test = data_test[dependent]

# %%
x_test.shape, os_data_x.shape
# Out:
# ((1482, 57), (18864, 57))

# %%
# logit_model = sm.Logit(y_test,x_test)
# result=logit_model.fit()
# print(result.summary2())

# %%
# yhat = logit_model.predict(x_test)
# prediction = list(map(y_test, yhat))
logreg = LogisticRegression(penalty='none')
logreg.fit(os_data_x,os_data_y)
y_pred=logreg.predict(x_test)
# Out:
# C:\Users\THINK\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\THINK\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
# confusion matrix 
cm = confusion_matrix(y_test, y_pred)  
print ("Confusion Matrix : \n", cm)  
  
# accuracy score of the model 
print('Test accuracy = ', accuracy_score(y_test, y_pred))

# r2 of the model 
print('R2 = ', r2_score(y_test, y_pred))
# Out:
# Confusion Matrix :
#  [[137 280]
#  [145 920]]
# Test accuracy =  0.713225371120108
# R2 =  -0.4182456851420271

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.5961934677610025

# %%
print(classification_report(y_test, y_pred.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.33      0.39       417
#            1       0.77      0.86      0.81      1065
#
#     accuracy                           0.71      1482
#    macro avg       0.63      0.60      0.60      1482
# weighted avg       0.69      0.71      0.69      1482

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict(x_test))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
