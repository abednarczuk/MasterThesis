# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Predictors of elderly citizens willingness to stay in the neighbourhood
# # Logistic regression

# %% [markdown]
# Original dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import r2_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from scipy import stats

# %%
data = pd.read_pickle("survey_transformed.pkl")

# %%
data.head()
# Out:
#      ANY NOM_DISTRICTE  Would_not_stay_in_the_neighborhood  Gender  \
# 0   2007  CIUTAT VELLA                                 0.0       0
# 9   2007  CIUTAT VELLA                                 0.0       1
# 12  2007  CIUTAT VELLA                                 0.0       1
# 14  2007  CIUTAT VELLA                                 0.0       1
# 17  2007  CIUTAT VELLA                                 1.0       1
#
#                Time_living_in_barri  Barri_evolution           Barri_future  \
# 0   I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED        IT WILL IMPROVE
# 9                MORE THAN 10 YEARS      IT IS WORSE  IT WILL STAY THE SAME
# 12  I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED        IT WILL IMPROVE
# 14               MORE THAN 10 YEARS      IT IS WORSE      IT WILL GET WORSE
# 17               LESS THAN 10 YEARS      IT IS WORSE      IT WILL GET WORSE
#
#    Barri_satisfaction_of_living                 Barri_comparison  \
# 0                     SATISFIED  NEITHER THE BEST, NOR THE WORST
# 9                     SATISFIED  NEITHER THE BEST, NOR THE WORST
# 12                    SATISFIED                  ONE OF THE BEST
# 14                    SATISFIED                  ONE OF THE BEST
# 17                NOT SATISFIED                 ONE OF THE WORST
#
#    GARBAGE COLLECTION  ...   Social_class Living_alone    BCN_evolution  \
# 0                GOOD  ...     MIDDLE-LOW            0  IT HAS IMPROVED
# 9                GOOD  ...     MIDDLE-LOW            0  IT HAS IMPROVED
# 12               GOOD  ...     MIDDLE-LOW            1  IT HAS IMPROVED
# 14               GOOD  ...            LOW            1   IT IS THE SAME
# 17               GOOD  ...  MIDDLE-MIDDLE            1      IT IS WORSE
#
#            BCN_future BCN_satisfaction_of_living BCN_transport  \
# 0     IT WILL IMPROVE                  SATISFIED          GOOD
# 9     IT WILL IMPROVE                  SATISFIED          GOOD
# 12    IT WILL IMPROVE                  SATISFIED          GOOD
# 14    IT WILL IMPROVE                  SATISFIED          GOOD
# 17  IT WILL GET WORSE              NOT SATISFIED          GOOD
#
#    BCN_over_barri_evolution BCN_over_barri_future  \
# 0                         0                     0
# 9                         1                     1
# 12                        0                     0
# 14                        1                     1
# 17                        0                     0
#
#    BCN_over_barri_satisfaction_of_living BCN_over_barri_transport
# 0                                      0                        0
# 9                                      0                        1
# 12                                     0                        0
# 14                                     0                        0
# 17                                     0                        0
#
# [5 rows x 34 columns]

# %%
data.shape
# Out:
# (6914, 34)

# %%
# Dataset is imbalanced
data.groupby(['Would_not_stay_in_the_neighborhood']).size()
# Out:
# Would_not_stay_in_the_neighborhood
# 0.0    6137
# 1.0     777
# dtype: int64

# %%
data.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'Would_not_stay_in_the_neighborhood',
#  'Gender',
#  'Time_living_in_barri',
#  'Barri_evolution',
#  'Barri_future',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'GARBAGE COLLECTION',
#  'STREETS CLEANING',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'ASPHALT AND STREET CONSERVATION',
#  'FACADES AND BUILDING CONSERVATION',
#  'CIRCULATION',
#  'BUS',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'MUNICIPAL MARKETS',
#  'Barri_transport',
#  'Owns_a_car',
#  'House_size',
#  'Monthly_family_income',
#  'Social_class',
#  'Living_alone',
#  'BCN_evolution',
#  'BCN_future',
#  'BCN_satisfaction_of_living',
#  'BCN_transport',
#  'BCN_over_barri_evolution',
#  'BCN_over_barri_future',
#  'BCN_over_barri_satisfaction_of_living',
#  'BCN_over_barri_transport']

# %%
x_var = data.columns.tolist()

# %%
for i in ['ANY', 'Would_not_stay_in_the_neighborhood',
          'BCN_evolution', 'BCN_future', 'BCN_satisfaction_of_living', 'BCN_transport']:
    x_var.remove(i)

# %%
x = data[x_var]

# %%
y = data['Would_not_stay_in_the_neighborhood']

# %%
x = pd.get_dummies(x, drop_first = True)

# %%
x = sm.add_constant(x)

# %%
resampling = SMOTE(random_state=0)
columns = x.columns
x_resampled, y_resampled=resampling.fit_sample(x, y)
x_resampled = pd.DataFrame(data=x_resampled, columns=columns )
y_resampled = pd.DataFrame(data=y_resampled, columns=['Would_not_stay_in_the_neighborhood'])

print("length of oversampled data is ",len(x_resampled))
print("Number of people who would not stay in the neighborhood in resampled data",
      len(y_resampled[y_resampled['Would_not_stay_in_the_neighborhood']==1]))
print("Number of people who would stay in the neighborhood in resampled data",
      len(y_resampled[y_resampled['Would_not_stay_in_the_neighborhood']==0]))
print("Proportion of 'Would_not_stay_in_the_neighborhood' in resampled data is ",
      len(y_resampled[y_resampled['Would_not_stay_in_the_neighborhood']==1])/len(x_resampled))
print("Proportion of subscription data in resampled data is ",
      len(y_resampled[y_resampled['Would_not_stay_in_the_neighborhood']==0])/len(x_resampled))
# Out:
# length of oversampled data is  12274
# Number of people who would not stay in the neighborhood in resampled data 6137
# Number of people who would stay in the neighborhood in resampled data 6137
# Proportion of 'Would_not_stay_in_the_neighborhood' in resampled data is  0.5
# Proportion of subscription data in resampled data is  0.5

# %%
x_resampled
# Out:
#        const  Gender  Owns_a_car  Living_alone  BCN_over_barri_evolution  \
# 0        1.0       0    0.000000             0                         0
# 1        1.0       1    0.000000             0                         1
# 2        1.0       1    0.000000             1                         0
# 3        1.0       1    0.000000             1                         1
# 4        1.0       1    1.000000             1                         0
# ...      ...     ...         ...           ...                       ...
# 12269    1.0       1    0.616368             0                         0
# 12270    1.0       0    0.000000             1                         0
# 12271    1.0       0    0.000000             0                         0
# 12272    1.0       0    0.000000             0                         0
# 12273    1.0       1    0.000000             0                         0
#
#        BCN_over_barri_future  BCN_over_barri_satisfaction_of_living  \
# 0                          0                                      0
# 1                          1                                      0
# 2                          0                                      0
# 3                          1                                      0
# 4                          0                                      0
# ...                      ...                                    ...
# 12269                      0                                      0
# 12270                      0                                      1
# 12271                      0                                      1
# 12272                      1                                      0
# 12273                      0                                      0
#
#        BCN_over_barri_transport  NOM_DISTRICTE_EIXAMPLE  NOM_DISTRICTE_GRÀCIA  \
# 0                             0                       0                     0
# 1                             1                       0                     0
# 2                             0                       0                     0
# 3                             0                       0                     0
# 4                             0                       0                     0
# ...                         ...                     ...                   ...
# 12269                         0                       0                     0
# 12270                         0                       0                     0
# 12271                         0                       0                     0
# 12272                         0                       0                     0
# 12273                         0                       0                     0
#
#        ...  House_size_51-100 M2  House_size_< 50 M2  House_size_> 150 M2  \
# 0      ...                     1                   0                    0
# 1      ...                     0                   0                    0
# 2      ...                     1                   0                    0
# 3      ...                     1                   0                    0
# 4      ...                     1                   0                    0
# ...    ...                   ...                 ...                  ...
# 12269  ...                     1                   0                    0
# 12270  ...                     1                   0                    0
# 12271  ...                     0                   1                    0
# 12272  ...                     1                   0                    0
# 12273  ...                     1                   0                    0
#
#        Monthly_family_income_2001-3000 EUROS  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 12269                                      0
# 12270                                      0
# 12271                                      0
# 12272                                      0
# 12273                                      0
#
#        Monthly_family_income_< 1000 EUROS  Monthly_family_income_> 3000 EUROS  \
# 0                                       0                                   0
# 1                                       1                                   0
# 2                                       1                                   0
# 3                                       1                                   0
# 4                                       0                                   0
# ...                                   ...                                 ...
# 12269                                   0                                   0
# 12270                                   0                                   0
# 12271                                   0                                   0
# 12272                                   1                                   0
# 12273                                   0                                   0
#
#        Social_class_LOW  Social_class_MIDDLE-HIGH  Social_class_MIDDLE-LOW  \
# 0                     0                         0                        1
# 1                     0                         0                        1
# 2                     0                         0                        1
# 3                     1                         0                        0
# 4                     0                         0                        0
# ...                 ...                       ...                      ...
# 12269                 0                         0                        0
# 12270                 0                         0                        0
# 12271                 0                         0                        1
# 12272                 0                         0                        1
# 12273                 0                         0                        1
#
#        Social_class_MIDDLE-MIDDLE
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               1
# ...                           ...
# 12269                           1
# 12270                           1
# 12271                           0
# 12272                           0
# 12273                           0
#
# [12274 rows x 49 columns]

# %%
y_resampled['Would_not_stay_in_the_neighborhood'].unique()
# Out:
# array([0., 1.])

# %%
logit_model = sm.Logit(y_resampled,x_resampled)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.362039
#          Iterations 8
#                                        Results: Logit
# =============================================================================================
# Model:                   Logit                                 Pseudo R-squared:    0.478
# Dependent Variable:      Would_not_stay_in_the_neighborhood    AIC:                 8985.3395
# Date:                    2021-04-23 08:13                      BIC:                 9348.6862
# No. Observations:        12274                                 Log-Likelihood:      -4443.7
# Df Model:                48                                    LL-Null:             -8507.7
# Df Residuals:            12225                                 LLR p-value:         0.0000
# Converged:               1.0000                                Scale:               1.0000
# No. Iterations:          8.0000
# ---------------------------------------------------------------------------------------------
#                                               Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------------------------------
# const                                        11.8901   0.3564  33.3607 0.0000 11.1915 12.5886
# Gender                                       -0.3518   0.0579  -6.0799 0.0000 -0.4651 -0.2384
# Owns_a_car                                    0.1373   0.0647   2.1210 0.0339  0.0104  0.2642
# Living_alone                                 -0.1283   0.0721  -1.7796 0.0751 -0.2696  0.0130
# BCN_over_barri_evolution                     -0.4311   0.1109  -3.8868 0.0001 -0.6485 -0.2137
# BCN_over_barri_future                        -0.5339   0.0962  -5.5475 0.0000 -0.7225 -0.3453
# BCN_over_barri_satisfaction_of_living        -0.6311   0.1395  -4.5227 0.0000 -0.9046 -0.3576
# BCN_over_barri_transport                     -0.4846   0.1167  -4.1526 0.0000 -0.7133 -0.2559
# NOM_DISTRICTE_EIXAMPLE                       -2.7741   0.1022 -27.1420 0.0000 -2.9744 -2.5737
# NOM_DISTRICTE_GRÀCIA                         -2.5382   0.1330 -19.0883 0.0000 -2.7988 -2.2776
# NOM_DISTRICTE_HORTA - GUINARDÓ               -2.1507   0.1019 -21.1028 0.0000 -2.3504 -1.9509
# NOM_DISTRICTE_LES CORTS                      -3.6217   0.1898 -19.0839 0.0000 -3.9936 -3.2497
# NOM_DISTRICTE_NOU BARRIS                     -2.2531   0.0982 -22.9355 0.0000 -2.4456 -2.0606
# NOM_DISTRICTE_SANT ANDREU                    -2.4758   0.1160 -21.3433 0.0000 -2.7032 -2.2485
# NOM_DISTRICTE_SANT MARTÍ                     -2.7281   0.1051 -25.9564 0.0000 -2.9341 -2.5221
# NOM_DISTRICTE_SANTS - MONTJUÏC               -2.4305   0.1029 -23.6289 0.0000 -2.6321 -2.2289
# NOM_DISTRICTE_SARRIÀ - SANT GERVASI          -3.8424   0.2182 -17.6122 0.0000 -4.2700 -3.4148
# Time_living_in_barri_LESS THAN 10 YEARS       0.4179   0.1367   3.0576 0.0022  0.1500  0.6858
# Time_living_in_barri_MORE THAN 10 YEARS      -0.0979   0.0729  -1.3423 0.1795 -0.2408  0.0450
# Barri_evolution_IT IS THE SAME               -0.8674   0.0807 -10.7524 0.0000 -1.0255 -0.7093
# Barri_evolution_IT IS WORSE                  -1.5215   0.1015 -14.9969 0.0000 -1.7204 -1.3227
# Barri_future_IT WILL IMPROVE                 -1.5033   0.0901 -16.6840 0.0000 -1.6799 -1.3267
# Barri_future_IT WILL STAY THE SAME           -1.2717   0.1022 -12.4455 0.0000 -1.4720 -1.0715
# Barri_satisfaction_of_living_SATISFIED       -1.3909   0.1111 -12.5201 0.0000 -1.6086 -1.1731
# Barri_comparison_ONE OF THE BEST             -1.9777   0.0629 -31.4656 0.0000 -2.1009 -1.8545
# Barri_comparison_ONE OF THE WORST            -0.0178   0.1407  -0.1266 0.8993 -0.2935  0.2579
# GARBAGE COLLECTION_GOOD                       0.2197   0.1181   1.8595 0.0630 -0.0119  0.4512
# STREETS CLEANING_GOOD                        -0.2875   0.0790  -3.6389 0.0003 -0.4424 -0.1327
# GREEN AREAS_GOOD                             -0.1156   0.0752  -1.5372 0.1243 -0.2629  0.0318
# PUBLIC LIGHTING_GOOD                         -0.6138   0.0909  -6.7537 0.0000 -0.7920 -0.4357
# ASPHALT AND STREET CONSERVATION_GOOD         -0.0391   0.0748  -0.5227 0.6012 -0.1857  0.1075
# FACADES AND BUILDING CONSERVATION_GOOD       -0.0782   0.0889  -0.8791 0.3794 -0.2525  0.0961
# CIRCULATION_GOOD                             -0.0499   0.0607  -0.8214 0.4114 -0.1689  0.0691
# BUS_GOOD                                     -0.1413   0.0944  -1.4961 0.1346 -0.3264  0.0438
# CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD -0.0997   0.0754  -1.3220 0.1862 -0.2476  0.0481
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD     0.0388   0.0789   0.4923 0.6225 -0.1158  0.1935
# MUNICIPAL MARKETS_GOOD                        0.0873   0.1047   0.8338 0.4044 -0.1179  0.2924
# Barri_transport_GOOD                         -0.8329   0.0953  -8.7434 0.0000 -1.0197 -0.6462
# Barri_transport_NORMAL                       -1.2465   0.1226 -10.1663 0.0000 -1.4868 -1.0061
# House_size_51-100 M2                         -0.4911   0.0874  -5.6197 0.0000 -0.6624 -0.3198
# House_size_< 50 M2                           -1.3307   0.1367  -9.7362 0.0000 -1.5986 -1.0628
# House_size_> 150 M2                          -0.1327   0.2000  -0.6636 0.5070 -0.5248  0.2593
# Monthly_family_income_2001-3000 EUROS        -0.7042   0.0987  -7.1345 0.0000 -0.8977 -0.5107
# Monthly_family_income_< 1000 EUROS           -0.4700   0.0685  -6.8568 0.0000 -0.6043 -0.3356
# Monthly_family_income_> 3000 EUROS           -0.4882   0.1416  -3.4484 0.0006 -0.7657 -0.2107
# Social_class_LOW                             -4.1618   0.2552 -16.3093 0.0000 -4.6619 -3.6616
# Social_class_MIDDLE-HIGH                     -4.2948   0.3114 -13.7938 0.0000 -4.9051 -3.6846
# Social_class_MIDDLE-LOW                      -3.9374   0.2430 -16.2041 0.0000 -4.4137 -3.4612
# Social_class_MIDDLE-MIDDLE                   -3.8985   0.2411 -16.1679 0.0000 -4.3711 -3.4259
# =============================================================================================

# %%
result.pvalues.sort_values(ascending=False)
# Out:
# Barri_comparison_ONE OF THE WORST                8.992543e-01
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD        6.225015e-01
# ASPHALT AND STREET CONSERVATION_GOOD             6.012104e-01
# House_size_> 150 M2                              5.069659e-01
# CIRCULATION_GOOD                                 4.114187e-01
# MUNICIPAL MARKETS_GOOD                           4.043771e-01
# FACADES AND BUILDING CONSERVATION_GOOD           3.793693e-01
# CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD     1.861743e-01
# Time_living_in_barri_MORE THAN 10 YEARS          1.794856e-01
# BUS_GOOD                                         1.346189e-01
# GREEN AREAS_GOOD                                 1.242506e-01
# Living_alone                                     7.513463e-02
# GARBAGE COLLECTION_GOOD                          6.295577e-02
# Owns_a_car                                       3.392167e-02
# Time_living_in_barri_LESS THAN 10 YEARS          2.230834e-03
# Monthly_family_income_> 3000 EUROS               5.638481e-04
# STREETS CLEANING_GOOD                            2.738318e-04
# BCN_over_barri_evolution                         1.015733e-04
# BCN_over_barri_transport                         3.287880e-05
# BCN_over_barri_satisfaction_of_living            6.104644e-06
# BCN_over_barri_future                            2.897184e-08
# House_size_51-100 M2                             1.912596e-08
# Gender                                           1.202212e-09
# PUBLIC LIGHTING_GOOD                             1.441008e-11
# Monthly_family_income_< 1000 EUROS               7.040428e-12
# Monthly_family_income_2001-3000 EUROS            9.714288e-13
# Barri_transport_GOOD                             2.261231e-18
# House_size_< 50 M2                               2.112349e-22
# Barri_transport_NORMAL                           2.804193e-24
# Barri_evolution_IT IS THE SAME                   5.776791e-27
# Barri_future_IT WILL STAY THE SAME               1.479350e-35
# Barri_satisfaction_of_living_SATISFIED           5.796183e-36
# Social_class_MIDDLE-HIGH                         2.775615e-43
# Barri_evolution_IT IS WORSE                      7.697475e-51
# Social_class_MIDDLE-MIDDLE                       8.489174e-59
# Social_class_MIDDLE-LOW                          4.717650e-59
# Social_class_LOW                                 8.476127e-60
# Barri_future_IT WILL IMPROVE                     1.712377e-62
# NOM_DISTRICTE_SARRIÀ - SANT GERVASI              1.984857e-69
# NOM_DISTRICTE_LES CORTS                          3.436484e-81
# NOM_DISTRICTE_GRÀCIA                             3.158779e-81
# NOM_DISTRICTE_HORTA - GUINARDÓ                   7.489064e-99
# NOM_DISTRICTE_SANT ANDREU                       4.496222e-101
# NOM_DISTRICTE_NOU BARRIS                        2.054985e-116
# NOM_DISTRICTE_SANTS - MONTJUÏC                  1.946491e-123
# NOM_DISTRICTE_SANT MARTÍ                        1.537998e-148
# NOM_DISTRICTE_EIXAMPLE                          3.145818e-162
# Barri_comparison_ONE OF THE BEST                2.568947e-217
# const                                           5.092759e-244
# dtype: float64

# %%
logit_roc_auc = roc_auc_score(y_resampled, result.predict(x_resampled))
fpr, tpr, thresholds = roc_curve(y_resampled, result.predict(x_resampled))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
# NIE POPRAWIŁAM PONIŻSZEGO FEATURE SELECTION

# %%
for i in ['MUNICIPAL POLICE_GOOD', 'CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD', 'BCN_over_barri_future', 
          'Gender', 'Barri_transport_GOOD']:
    del x_resampled[i]

# %%
logit_model = sm.Logit(y_resampled,x_resampled)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.433186
#          Iterations 7
#                                       Results: Logit
# ==========================================================================================
# Model:                  Logit                                Pseudo R-squared:   0.375
# Dependent Variable:     Would_not_stay_in_the_neighborhood   AIC:                6975.6630
# Date:                   2021-04-16 07:55                     BIC:                7282.8238
# No. Observations:       7950                                 Log-Likelihood:     -3443.8
# Df Model:               43                                   LL-Null:            -5510.5
# Df Residuals:           7906                                 LLR p-value:        0.0000
# Converged:              1.0000                               Scale:              1.0000
# No. Iterations:         7.0000
# ------------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------------------------------
# Owns_a_car                                 0.4377   0.0715   6.1246 0.0000  0.2977  0.5778
# Living_alone                               0.1621   0.0797   2.0332 0.0420  0.0058  0.3184
# BCN_over_barri_evolution                  -0.7235   0.1210  -5.9792 0.0000 -0.9607 -0.4864
# BCN_over_barri_satisfaction_of_living      0.7900   0.1476   5.3512 0.0000  0.5007  1.0794
# BCN_over_barri_transport                   0.4155   0.1096   3.7926 0.0001  0.2008  0.6302
# NOM_DISTRICTE_EIXAMPLE                    -2.5268   0.1167 -21.6430 0.0000 -2.7556 -2.2980
# NOM_DISTRICTE_GRÀCIA                      -1.8988   0.1445 -13.1378 0.0000 -2.1820 -1.6155
# NOM_DISTRICTE_HORTA - GUINARDÓ            -2.1700   0.1164 -18.6406 0.0000 -2.3982 -1.9419
# NOM_DISTRICTE_LES CORTS                   -3.7852   0.2628 -14.4029 0.0000 -4.3003 -3.2701
# NOM_DISTRICTE_NOU BARRIS                  -2.0443   0.1085 -18.8432 0.0000 -2.2570 -1.8317
# NOM_DISTRICTE_SANT ANDREU                 -2.1756   0.1270 -17.1292 0.0000 -2.4246 -1.9267
# NOM_DISTRICTE_SANT MARTÍ                  -2.4273   0.1168 -20.7773 0.0000 -2.6563 -2.1983
# NOM_DISTRICTE_SANTS - MONTJUÏC            -2.1241   0.1149 -18.4827 0.0000 -2.3493 -1.8988
# NOM_DISTRICTE_SARRIÀ - SANT GERVASI       -2.8744   0.2163 -13.2907 0.0000 -3.2983 -2.4505
# Time_living_in_barri_LESS THAN 10 YEARS    0.9452   0.1579   5.9852 0.0000  0.6356  1.2547
# Time_living_in_barri_MORE THAN 10 YEARS    0.5474   0.0834   6.5638 0.0000  0.3839  0.7108
# Barri_evolution_IT IS THE SAME            -0.3341   0.0849  -3.9332 0.0001 -0.5006 -0.1676
# Barri_evolution_IT IS WORSE               -0.5222   0.0998  -5.2351 0.0000 -0.7177 -0.3267
# Barri_future_IT WILL IMPROVE              -0.7155   0.0888  -8.0570 0.0000 -0.8895 -0.5414
# Barri_future_IT WILL STAY THE SAME        -0.7802   0.1084  -7.1986 0.0000 -0.9927 -0.5678
# Barri_satisfaction_of_living_SATISFIED    -0.3265   0.1054  -3.0988 0.0019 -0.5331 -0.1200
# Barri_comparison_ONE OF THE BEST          -2.0074   0.0719 -27.9153 0.0000 -2.1483 -1.8665
# Barri_comparison_ONE OF THE WORST          0.5516   0.1448   3.8100 0.0001  0.2678  0.8354
# GARBAGE COLLECTION_GOOD                    1.3315   0.1233  10.8000 0.0000  1.0899  1.5732
# STREETS CLEANING_GOOD                     -0.2279   0.0851  -2.6792 0.0074 -0.3947 -0.0612
# GREEN AREAS_GOOD                          -0.1877   0.0817  -2.2981 0.0216 -0.3478 -0.0276
# PUBLIC LIGHTING_GOOD                       0.3380   0.0991   3.4115 0.0006  0.1438  0.5322
# ASPHALT AND STREET CONSERVATION_GOOD       0.1838   0.0808   2.2757 0.0229  0.0255  0.3420
# FACADES AND BUILDING CONSERVATION_GOOD     0.5896   0.0955   6.1730 0.0000  0.4024  0.7768
# CIRCULATION_GOOD                          -0.2359   0.0700  -3.3690 0.0008 -0.3732 -0.0987
# BUS_GOOD                                   0.3368   0.0965   3.4901 0.0005  0.1477  0.5259
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD -0.3279   0.0733  -4.4711 0.0000 -0.4716 -0.1841
# MUNICIPAL MARKETS_GOOD                     1.2401   0.1117  11.0972 0.0000  1.0211  1.4591
# Barri_transport_NORMAL                    -0.3321   0.1370  -2.4232 0.0154 -0.6007 -0.0635
# House_size_51-100 M2                       0.4201   0.0902   4.6569 0.0000  0.2433  0.5969
# House_size_< 50 M2                        -0.3846   0.1457  -2.6394 0.0083 -0.6701 -0.0990
# House_size_> 150 M2                        0.5078   0.2238   2.2688 0.0233  0.0691  0.9465
# Monthly_family_income_2001-3000 EUROS     -0.6453   0.1056  -6.1099 0.0000 -0.8523 -0.4383
# Monthly_family_income_< 1000 EUROS        -0.4616   0.0799  -5.7790 0.0000 -0.6181 -0.3050
# Monthly_family_income_> 3000 EUROS        -0.4333   0.1526  -2.8399 0.0045 -0.7323 -0.1343
# Social_class_LOW                          -0.7000   0.1421  -4.9271 0.0000 -0.9784 -0.4215
# Social_class_MIDDLE-HIGH                  -1.0789   0.2654  -4.0647 0.0000 -1.5992 -0.5587
# Social_class_MIDDLE-LOW                   -0.5899   0.1160  -5.0847 0.0000 -0.8173 -0.3625
# Social_class_MIDDLE-MIDDLE                -0.4443   0.1157  -3.8389 0.0001 -0.6712 -0.2175
# ==========================================================================================

# %%
result.pvalues.sort_values(ascending=False)
# Out:
# Living_alone                                  4.203236e-02
# House_size_> 150 M2                           2.328316e-02
# ASPHALT AND STREET CONSERVATION_GOOD          2.286665e-02
# GREEN AREAS_GOOD                              2.155480e-02
# Barri_transport_NORMAL                        1.538595e-02
# House_size_< 50 M2                            8.304233e-03
# STREETS CLEANING_GOOD                         7.380443e-03
# Monthly_family_income_> 3000 EUROS            4.512150e-03
# Barri_satisfaction_of_living_SATISFIED        1.943124e-03
# CIRCULATION_GOOD                              7.542893e-04
# PUBLIC LIGHTING_GOOD                          6.461190e-04
# BUS_GOOD                                      4.827889e-04
# BCN_over_barri_transport                      1.491051e-04
# Barri_comparison_ONE OF THE WORST             1.389451e-04
# Social_class_MIDDLE-MIDDLE                    1.235845e-04
# Barri_evolution_IT IS THE SAME                8.382358e-05
# Social_class_MIDDLE-HIGH                      4.810323e-05
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD     7.781547e-06
# House_size_51-100 M2                          3.209536e-06
# Social_class_LOW                              8.343966e-07
# Social_class_MIDDLE-LOW                       3.681919e-07
# Barri_evolution_IT IS WORSE                   1.649246e-07
# BCN_over_barri_satisfaction_of_living         8.736503e-08
# Monthly_family_income_< 1000 EUROS            7.515780e-09
# BCN_over_barri_evolution                      2.242007e-09
# Time_living_in_barri_LESS THAN 10 YEARS       2.160846e-09
# Monthly_family_income_2001-3000 EUROS         9.966696e-10
# Owns_a_car                                    9.089991e-10
# FACADES AND BUILDING CONSERVATION_GOOD        6.699477e-10
# Time_living_in_barri_MORE THAN 10 YEARS       5.246614e-11
# Barri_future_IT WILL STAY THE SAME            6.083124e-13
# Barri_future_IT WILL IMPROVE                  7.816456e-16
# GARBAGE COLLECTION_GOOD                       3.441773e-27
# MUNICIPAL MARKETS_GOOD                        1.293737e-28
# NOM_DISTRICTE_GRÀCIA                          2.000300e-39
# NOM_DISTRICTE_SARRIÀ - SANT GERVASI           2.619488e-40
# NOM_DISTRICTE_LES CORTS                       4.964586e-47
# NOM_DISTRICTE_SANT ANDREU                     8.988759e-66
# NOM_DISTRICTE_SANTS - MONTJUÏC                2.843869e-76
# NOM_DISTRICTE_HORTA - GUINARDÓ                1.505977e-77
# NOM_DISTRICTE_NOU BARRIS                      3.341432e-79
# NOM_DISTRICTE_SANT MARTÍ                      6.944598e-96
# NOM_DISTRICTE_EIXAMPLE                       7.080816e-104
# Barri_comparison_ONE OF THE BEST             1.738347e-171
# dtype: float64

# %%
print(result.get_margeff().summary())
# Out:
#                 Logit Marginal Effects
# =====================================================
# Dep. Variable:     Would_not_stay_in_the_neighborhood
# Method:                                          dydx
# At:                                           overall
# =============================================================================================================
#                                                dy/dx    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Owns_a_car                                    0.0612      0.010      6.176      0.000       0.042       0.081
# Living_alone                                  0.0227      0.011      2.035      0.042       0.001       0.045
# BCN_over_barri_evolution                     -0.1012      0.017     -6.025      0.000      -0.134      -0.068
# BCN_over_barri_satisfaction_of_living         0.1105      0.021      5.383      0.000       0.070       0.151
# BCN_over_barri_transport                      0.0581      0.015      3.805      0.000       0.028       0.088
# NOM_DISTRICTE_EIXAMPLE                       -0.3534      0.015    -24.235      0.000      -0.382      -0.325
# NOM_DISTRICTE_GRÀCIA                         -0.2656      0.019    -13.675      0.000      -0.304      -0.228
# NOM_DISTRICTE_HORTA - GUINARDÓ               -0.3035      0.015    -20.213      0.000      -0.333      -0.274
# NOM_DISTRICTE_LES CORTS                      -0.5295      0.035    -14.989      0.000      -0.599      -0.460
# NOM_DISTRICTE_NOU BARRIS                     -0.2860      0.014    -20.470      0.000      -0.313      -0.259
# NOM_DISTRICTE_SANT ANDREU                    -0.3043      0.017    -18.328      0.000      -0.337      -0.272
# NOM_DISTRICTE_SANT MARTÍ                     -0.3395      0.015    -23.043      0.000      -0.368      -0.311
# NOM_DISTRICTE_SANTS - MONTJUÏC               -0.2971      0.015    -19.966      0.000      -0.326      -0.268
# NOM_DISTRICTE_SARRIÀ - SANT GERVASI          -0.4021      0.029    -13.784      0.000      -0.459      -0.345
# Time_living_in_barri_LESS THAN 10 YEARS       0.1322      0.022      6.032      0.000       0.089       0.175
# Time_living_in_barri_MORE THAN 10 YEARS       0.0766      0.012      6.627      0.000       0.054       0.099
# Barri_evolution_IT IS THE SAME               -0.0467      0.012     -3.947      0.000      -0.070      -0.024
# Barri_evolution_IT IS WORSE                  -0.0730      0.014     -5.269      0.000      -0.100      -0.046
# Barri_future_IT WILL IMPROVE                 -0.1001      0.012     -8.177      0.000      -0.124      -0.076
# Barri_future_IT WILL STAY THE SAME           -0.1091      0.015     -7.284      0.000      -0.139      -0.080
# Barri_satisfaction_of_living_SATISFIED       -0.0457      0.015     -3.106      0.002      -0.075      -0.017
# Barri_comparison_ONE OF THE BEST             -0.2808      0.008    -34.507      0.000      -0.297      -0.265
# Barri_comparison_ONE OF THE WORST             0.0772      0.020      3.821      0.000       0.038       0.117
# GARBAGE COLLECTION_GOOD                       0.1862      0.017     11.085      0.000       0.153       0.219
# STREETS CLEANING_GOOD                        -0.0319      0.012     -2.683      0.007      -0.055      -0.009
# GREEN AREAS_GOOD                             -0.0263      0.011     -2.300      0.021      -0.049      -0.004
# PUBLIC LIGHTING_GOOD                          0.0473      0.014      3.420      0.001       0.020       0.074
# ASPHALT AND STREET CONSERVATION_GOOD          0.0257      0.011      2.278      0.023       0.004       0.048
# FACADES AND BUILDING CONSERVATION_GOOD        0.0825      0.013      6.225      0.000       0.057       0.108
# CIRCULATION_GOOD                             -0.0330      0.010     -3.377      0.001      -0.052      -0.014
# BUS_GOOD                                      0.0471      0.013      3.500      0.000       0.021       0.073
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD    -0.0459      0.010     -4.490      0.000      -0.066      -0.026
# MUNICIPAL MARKETS_GOOD                        0.1735      0.015     11.410      0.000       0.144       0.203
# Barri_transport_NORMAL                       -0.0465      0.019     -2.426      0.015      -0.084      -0.009
# House_size_51-100 M2                          0.0588      0.013      4.678      0.000       0.034       0.083
# House_size_< 50 M2                           -0.0538      0.020     -2.643      0.008      -0.094      -0.014
# House_size_> 150 M2                           0.0710      0.031      2.271      0.023       0.010       0.132
# Monthly_family_income_2001-3000 EUROS        -0.0903      0.015     -6.160      0.000      -0.119      -0.062
# Monthly_family_income_< 1000 EUROS           -0.0646      0.011     -5.823      0.000      -0.086      -0.043
# Monthly_family_income_> 3000 EUROS           -0.0606      0.021     -2.845      0.004      -0.102      -0.019
# Social_class_LOW                             -0.0979      0.020     -4.953      0.000      -0.137      -0.059
# Social_class_MIDDLE-HIGH                     -0.1509      0.037     -4.078      0.000      -0.223      -0.078
# Social_class_MIDDLE-LOW                      -0.0825      0.016     -5.113      0.000      -0.114      -0.051
# Social_class_MIDDLE-MIDDLE                   -0.0621      0.016     -3.852      0.000      -0.094      -0.031
# =============================================================================================================

# %%
result.pred_table()
# Out:
# array([[3159.,  816.],
#        [ 812., 3163.]])

# %%
logit_roc_auc = roc_auc_score(y_resampled, result.predict(x_resampled))
fpr, tpr, thresholds = roc_curve(y_resampled, result.predict(x_resampled))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
