# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Predictors of elderly citizens willingness to stay in the neighbourhood
# # Logistic regression

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import r2_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from scipy import stats

# %%
data = pd.read_pickle("survey_transformed.pkl")

# %%
data.head()
# Out:
#     ANY  Stay_in_the_same_neighborhood  Gender  \
# 0  2011                              1       1
# 1  2011                              1       1
# 2  2011                              1       1
# 3  2011                              1       1
# 4  2011                              0       0
#
#                 Time_living_in_BCN Time_living_in_barri  BCN_if_has_improved  \
# 0               MORE THAN 10 YEARS   MORE THAN 10 YEARS                   -1
# 1  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                   -1
# 2  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                    0
# 3               MORE THAN 10 YEARS   LESS THAN 10 YEARS                   -1
# 4  I HAVE ALWAYS LIVED IN THE CITY   MORE THAN 10 YEARS                    0
#
#    BCN_if_will_improve  BCN_satisfaction_of_living  BCN_city_management  \
# 0                   -1                           3                    1
# 1                   -1                           4                    1
# 2                    1                           4                   -1
# 3                    0                           4                    1
# 4                    0                           4                   -1
#
#    GARBAGE COLLECTION  ...  Compare_if_has_improved  Compare_if_will_improve  \
# 0                   1  ...                    Equal                    Equal
# 1                  -1  ...           Barri over BCN           Barri over BCN
# 2                   1  ...           BCN over Barri           BCN over Barri
# 3                   1  ...                    Equal           BCN over Barri
# 4                  -1  ...                    Equal                    Equal
#
#    Compare_satisfaction_of_living  Compare_city_management  Compare_transport  \
# 0                  BCN over Barri                    Equal              Equal
# 1                           Equal                    Equal     Barri over BCN
# 2                           Equal           Barri over BCN              Equal
# 3                           Equal                    Equal              Equal
# 4                  BCN over Barri           Barri over BCN     Barri over BCN
#
#    Barri_over_BCN_if_has_improved  Barri_over_BCN_if_will_improve  \
# 0                               0                               0
# 1                               1                               1
# 2                               0                               0
# 3                               0                               0
# 4                               0                               0
#
#    Barri_over_BCN_satisfaction_of_living  Barri_over_BCN_city_management  \
# 0                                      0                               0
# 1                                      0                               0
# 2                                      0                               1
# 3                                      0                               0
# 4                                      0                               1
#
#    Barri_over_BCN_transport
# 0                         0
# 1                         1
# 2                         0
# 3                         0
# 4                         1
#
# [5 rows x 53 columns]

# %%
data.shape
# Out:
# (13742, 53)

# %%
for i in data.columns:
    if data[i].isnull().sum() > 1 :
        print(i, data[i].isnull().sum())
# Out:
# Means_of_transport 2

# %%
data = data.dropna()

# %%
data_train = data.query('ANY < 2019')
data_test = data.query('ANY == 2019')

# %%
print("Train dataset shape:", data_train.shape, " Test dataset shape:", data_test.shape)
# Out:
# Train dataset shape: (12258, 53)  Test dataset shape: (1482, 53)

# %%
independent = data.columns.tolist()
for i in ['ANY', 'Stay_in_the_same_neighborhood']:
    independent.remove(i)

# %%
dependent = 'Stay_in_the_same_neighborhood'

# %%
independent
# Out:
# ['Gender',
#  'Time_living_in_BCN',
#  'Time_living_in_barri',
#  'BCN_if_has_improved',
#  'BCN_if_will_improve',
#  'BCN_satisfaction_of_living',
#  'BCN_city_management',
#  'GARBAGE COLLECTION',
#  'STREETS CLEANING',
#  'NOISE',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'URBANISM',
#  'ASPHALT AND STREET CONSERVATION',
#  'FACADES AND BUILDING CONSERVATION',
#  'CIRCULATION',
#  'PARKING',
#  'MUNICIPAL POLICE',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'SPORTS FACILITIES',
#  'CITIZEN INFORMATION AND ATTENTION SERVICES',
#  'SOCIAL SERVICES CENTERS',
#  'CULTURAL ACTIVITIES',
#  'POPULAR FESTIVALS',
#  'MUNICIPAL MARKETS',
#  'PUBLIC LIBRARIES',
#  'Means_of_transport',
#  'BCN_transport',
#  'Barri_transport',
#  'Barri_if_has_improved',
#  'Barri_if_will_improve',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'Barri_city_management',
#  'Owns_a_car',
#  'House_M2',
#  'Social_class',
#  'Voted',
#  'Born_in_BCN',
#  'Living_alone',
#  'Compare_if_has_improved',
#  'Compare_if_will_improve',
#  'Compare_satisfaction_of_living',
#  'Compare_city_management',
#  'Compare_transport',
#  'Barri_over_BCN_if_has_improved',
#  'Barri_over_BCN_if_will_improve',
#  'Barri_over_BCN_satisfaction_of_living',
#  'Barri_over_BCN_city_management',
#  'Barri_over_BCN_transport']

# %%
for i in ['BCN_if_has_improved', 'BCN_if_will_improve', 'BCN_satisfaction_of_living', 'BCN_city_management', 
          'BCN_transport', 'Barri_transport','Barri_if_has_improved', 'Barri_if_will_improve',
          'Barri_satisfaction_of_living', 'Barri_city_management', 'Compare_if_has_improved',
          'Compare_if_will_improve', 'Compare_satisfaction_of_living', 'Compare_city_management', 'Compare_transport',]:
    independent.remove(i)

# %%
x = data_train[independent]
y = data_train[dependent]

# %%
x = pd.get_dummies(x, drop_first = True)

# %%
# Training dataset is highly unbalanced
data_train.groupby(['Stay_in_the_same_neighborhood']).size()
# Out:
# Stay_in_the_same_neighborhood
# 0    2826
# 1    9432
# dtype: int64

# %%
os = SMOTE(random_state=0)
columns = x.columns
os_data_x, os_data_y=os.fit_sample(x, y)
os_data_x = pd.DataFrame(data=os_data_x, columns=columns )
os_data_y= pd.DataFrame(data=os_data_y, columns=['Stay_in_the_same_neighborhood'])

# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_x))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==0]))
print("Number of subscription",len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==1]))
print("Proportion of no subscription data in oversampled data is ",
      len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==0])/len(os_data_x))
print("Proportion of subscription data in oversampled data is ",
      len(os_data_y[os_data_y['Stay_in_the_same_neighborhood']==1])/len(os_data_x))
# Out:
# length of oversampled data is  18864
# Number of no subscription in oversampled data 9432
# Number of subscription 9432
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
logit_model = sm.Logit(os_data_y,os_data_x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.553832
#          Iterations 6
#                                       Results: Logit
# ===========================================================================================
# Model:                   Logit                             Pseudo R-squared:     0.201
# Dependent Variable:      Stay_in_the_same_neighborhood     AIC:                  20990.9745
# Date:                    2021-03-24 23:31                  BIC:                  21367.5350
# No. Observations:        18864                             Log-Likelihood:       -10447.
# Df Model:                47                                LL-Null:              -13076.
# Df Residuals:            18816                             LLR p-value:          0.0000
# Converged:               1.0000                            Scale:                1.0000
# No. Iterations:          6.0000
# -------------------------------------------------------------------------------------------
#                                             Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -------------------------------------------------------------------------------------------
# Gender                                      0.2647   0.0355   7.4462 0.0000  0.1950  0.3344
# GARBAGE COLLECTION                         -0.5064   0.0412 -12.2960 0.0000 -0.5871 -0.4257
# STREETS CLEANING                            0.0247   0.0258   0.9554 0.3394 -0.0259  0.0753
# NOISE                                       0.2226   0.0196  11.3656 0.0000  0.1842  0.2610
# GREEN AREAS                                -0.0233   0.0249  -0.9368 0.3489 -0.0722  0.0255
# PUBLIC LIGHTING                            -0.2674   0.0315  -8.4900 0.0000 -0.3292 -0.2057
# URBANISM                                    0.0983   0.0282   3.4880 0.0005  0.0431  0.1535
# ASPHALT AND STREET CONSERVATION             0.0925   0.0232   3.9889 0.0001  0.0470  0.1379
# FACADES AND BUILDING CONSERVATION          -0.1407   0.0277  -5.0809 0.0000 -0.1950 -0.0864
# CIRCULATION                                 0.0538   0.0208   2.5904 0.0096  0.0131  0.0946
# PARKING                                     0.1030   0.0216   4.7749 0.0000  0.0607  0.1453
# MUNICIPAL POLICE                            0.0447   0.0239   1.8701 0.0615 -0.0021  0.0915
# CITIZEN SECURITY IN THE CITY AS A WHOLE    -0.0224   0.0244  -0.9178 0.3587 -0.0701  0.0254
# CITIZEN SECURITY IN THE NEIGHBORHOOD        0.1242   0.0248   5.0096 0.0000  0.0756  0.1728
# SPORTS FACILITIES                           0.0320   0.0293   1.0910 0.2753 -0.0255  0.0895
# CITIZEN INFORMATION AND ATTENTION SERVICES -0.0675   0.0314  -2.1526 0.0314 -0.1290 -0.0060
# SOCIAL SERVICES CENTERS                     0.1603   0.0298   5.3746 0.0000  0.1018  0.2187
# CULTURAL ACTIVITIES                         0.0166   0.0354   0.4674 0.6402 -0.0529  0.0860
# POPULAR FESTIVALS                           0.1061   0.0314   3.3777 0.0007  0.0445  0.1676
# MUNICIPAL MARKETS                          -0.3628   0.0329 -11.0263 0.0000 -0.4273 -0.2983
# PUBLIC LIBRARIES                           -0.1297   0.0357  -3.6284 0.0003 -0.1998 -0.0596
# Barri_comparison                            1.3716   0.0336  40.8320 0.0000  1.3058  1.4374
# Owns_a_car                                  0.0595   0.0380   1.5684 0.1168 -0.0149  0.1339
# Voted                                      -0.2500   0.0422  -5.9179 0.0000 -0.3327 -0.1672
# Born_in_BCN                                -0.1936   0.0588  -3.2916 0.0010 -0.3088 -0.0783
# Living_alone                                0.3282   0.0438   7.4969 0.0000  0.2424  0.4140
# Barri_over_BCN_if_has_improved              0.2498   0.0376   6.6390 0.0000  0.1760  0.3235
# Barri_over_BCN_if_will_improve              0.4040   0.0434   9.3152 0.0000  0.3190  0.4890
# Barri_over_BCN_satisfaction_of_living       0.4007   0.0480   8.3405 0.0000  0.3066  0.4949
# Barri_over_BCN_city_management              0.4808   0.0586   8.2042 0.0000  0.3659  0.5956
# Barri_over_BCN_transport                    0.4217   0.0768   5.4916 0.0000  0.2712  0.5721
# Time_living_in_BCN_LESS THAN 10 YEARS       0.0938   0.1794   0.5228 0.6011 -0.2579  0.4455
# Time_living_in_BCN_MORE THAN 10 YEARS       0.0963   0.0607   1.5871 0.1125 -0.0226  0.2152
# Time_living_in_barri_LESS THAN 10 YEARS    -0.8685   0.1027  -8.4548 0.0000 -1.0698 -0.6671
# Time_living_in_barri_MORE THAN 10 YEARS    -0.7585   0.0500 -15.1684 0.0000 -0.8565 -0.6605
# Means_of_transport_CAR                      0.6603   0.1123   5.8809 0.0000  0.4403  0.8804
# Means_of_transport_MOTORCYCLE               0.3867   0.2263   1.7088 0.0875 -0.0568  0.8302
# Means_of_transport_OTHERS                   0.7366   0.4377   1.6829 0.0924 -0.1213  1.5945
# Means_of_transport_PUBLIC TRANSPORT         0.0015   0.0604   0.0251 0.9800 -0.1168  0.1199
# Means_of_transport_TAXI                     1.4154   0.1655   8.5508 0.0000  1.0910  1.7398
# Means_of_transport_WALKING                  0.5461   0.0771   7.0840 0.0000  0.3950  0.6972
# House_M2_51-100 M2                         -0.2495   0.0458  -5.4418 0.0000 -0.3394 -0.1596
# House_M2_< 50 M2                            0.1142   0.0879   1.2997 0.1937 -0.0580  0.2864
# House_M2_> 150 M2                           0.6167   0.1294   4.7668 0.0000  0.3631  0.8703
# Social_class_LOW                            0.9899   0.0795  12.4591 0.0000  0.8342  1.1457
# Social_class_MIDDLE-HIGH                    1.5522   0.1361  11.4035 0.0000  1.2854  1.8190
# Social_class_MIDDLE-LOW                     0.8496   0.0624  13.6255 0.0000  0.7274  0.9718
# Social_class_MIDDLE-MIDDLE                  0.9020   0.0598  15.0828 0.0000  0.7848  1.0193
# ===========================================================================================

# %%
pd.DataFrame(result.pvalues.sort_values(ascending=False))
# Out:
#                                                        0
# Means_of_transport_PUBLIC TRANSPORT         9.800009e-01
# CULTURAL ACTIVITIES                         6.402323e-01
# Time_living_in_BCN_LESS THAN 10 YEARS       6.011476e-01
# CITIZEN SECURITY IN THE CITY AS A WHOLE     3.587296e-01
# GREEN AREAS                                 3.488731e-01
# STREETS CLEANING                            3.393945e-01
# SPORTS FACILITIES                           2.752830e-01
# House_M2_< 50 M2                            1.937121e-01
# Owns_a_car                                  1.167842e-01
# Time_living_in_BCN_MORE THAN 10 YEARS       1.124827e-01
# Means_of_transport_OTHERS                   9.240170e-02
# Means_of_transport_MOTORCYCLE               8.748500e-02
# MUNICIPAL POLICE                            6.146523e-02
# CITIZEN INFORMATION AND ATTENTION SERVICES  3.135278e-02
# CIRCULATION                                 9.586309e-03
# Born_in_BCN                                 9.963176e-04
# POPULAR FESTIVALS                           7.309772e-04
# URBANISM                                    4.865854e-04
# PUBLIC LIBRARIES                            2.851335e-04
# ASPHALT AND STREET CONSERVATION             6.638831e-05
# House_M2_> 150 M2                           1.871292e-06
# PARKING                                     1.797551e-06
# CITIZEN SECURITY IN THE NEIGHBORHOOD        5.454300e-07
# FACADES AND BUILDING CONSERVATION           3.756307e-07
# SOCIAL SERVICES CENTERS                     7.673227e-08
# House_M2_51-100 M2                          5.274544e-08
# Barri_over_BCN_transport                    3.982056e-08
# Means_of_transport_CAR                      4.079944e-09
# Voted                                       3.261012e-09
# Barri_over_BCN_if_has_improved              3.157430e-11
# Means_of_transport_WALKING                  1.400318e-12
# Gender                                      9.604501e-14
# Living_alone                                6.535961e-14
# Barri_over_BCN_city_management              2.321460e-16
# Barri_over_BCN_satisfaction_of_living       7.400485e-17
# Time_living_in_barri_LESS THAN 10 YEARS     2.795255e-17
# PUBLIC LIGHTING                             2.066355e-17
# Means_of_transport_TAXI                     1.222707e-17
# Barri_over_BCN_if_will_improve              1.216892e-20
# MUNICIPAL MARKETS                           2.852116e-28
# NOISE                                       6.206426e-30
# Social_class_MIDDLE-HIGH                    4.017315e-30
# GARBAGE COLLECTION                          9.517264e-35
# Social_class_LOW                            1.246946e-35
# Social_class_MIDDLE-LOW                     2.825114e-42
# Social_class_MIDDLE-MIDDLE                  2.102939e-51
# Time_living_in_barri_MORE THAN 10 YEARS     5.724204e-52
# Barri_comparison                            0.000000e+00

# %%
features = os_data_x.columns.tolist()
for i in ['CULTURAL ACTIVITIES', 'CITIZEN SECURITY IN THE CITY AS A WHOLE',
          'GREEN AREAS', 'STREETS CLEANING', 'SPORTS FACILITIES', 'Owns_a_car']:
    features.remove(i)

# %%
os_data_x = os_data_x[features]

# %%
logit_model = sm.Logit(os_data_y,os_data_x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.554001
#          Iterations 6
#                                       Results: Logit
# ===========================================================================================
# Model:                   Logit                             Pseudo R-squared:     0.201
# Dependent Variable:      Stay_in_the_same_neighborhood     AIC:                  20985.3380
# Date:                    2021-03-24 23:31                  BIC:                  21314.8284
# No. Observations:        18864                             Log-Likelihood:       -10451.
# Df Model:                41                                LL-Null:              -13076.
# Df Residuals:            18822                             LLR p-value:          0.0000
# Converged:               1.0000                            Scale:                1.0000
# No. Iterations:          6.0000
# -------------------------------------------------------------------------------------------
#                                             Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -------------------------------------------------------------------------------------------
# Gender                                      0.2554   0.0351   7.2808 0.0000  0.1866  0.3242
# GARBAGE COLLECTION                         -0.4948   0.0394 -12.5504 0.0000 -0.5721 -0.4176
# NOISE                                       0.2208   0.0194  11.3656 0.0000  0.1827  0.2589
# PUBLIC LIGHTING                            -0.2689   0.0314  -8.5699 0.0000 -0.3304 -0.2074
# URBANISM                                    0.0966   0.0279   3.4692 0.0005  0.0420  0.1512
# ASPHALT AND STREET CONSERVATION             0.0934   0.0229   4.0826 0.0000  0.0486  0.1383
# FACADES AND BUILDING CONSERVATION          -0.1393   0.0275  -5.0617 0.0000 -0.1932 -0.0853
# CIRCULATION                                 0.0541   0.0207   2.6097 0.0091  0.0135  0.0948
# PARKING                                     0.1001   0.0215   4.6644 0.0000  0.0580  0.1421
# MUNICIPAL POLICE                            0.0434   0.0237   1.8326 0.0669 -0.0030  0.0898
# CITIZEN SECURITY IN THE NEIGHBORHOOD        0.1139   0.0205   5.5665 0.0000  0.0738  0.1540
# CITIZEN INFORMATION AND ATTENTION SERVICES -0.0619   0.0310  -1.9976 0.0458 -0.1227 -0.0012
# SOCIAL SERVICES CENTERS                     0.1612   0.0296   5.4490 0.0000  0.1032  0.2191
# POPULAR FESTIVALS                           0.1107   0.0306   3.6210 0.0003  0.0508  0.1706
# MUNICIPAL MARKETS                          -0.3606   0.0327 -11.0133 0.0000 -0.4248 -0.2964
# PUBLIC LIBRARIES                           -0.1181   0.0343  -3.4443 0.0006 -0.1853 -0.0509
# Barri_comparison                            1.3730   0.0336  40.9226 0.0000  1.3072  1.4387
# Voted                                      -0.2394   0.0419  -5.7194 0.0000 -0.3214 -0.1573
# Born_in_BCN                                -0.1885   0.0587  -3.2127 0.0013 -0.3034 -0.0735
# Living_alone                                0.3103   0.0418   7.4225 0.0000  0.2284  0.3922
# Barri_over_BCN_if_has_improved              0.2511   0.0376   6.6857 0.0000  0.1775  0.3247
# Barri_over_BCN_if_will_improve              0.4069   0.0433   9.3884 0.0000  0.3219  0.4918
# Barri_over_BCN_satisfaction_of_living       0.4021   0.0480   8.3727 0.0000  0.3079  0.4962
# Barri_over_BCN_city_management              0.4791   0.0585   8.1906 0.0000  0.3645  0.5938
# Barri_over_BCN_transport                    0.4285   0.0767   5.5857 0.0000  0.2781  0.5788
# Time_living_in_BCN_LESS THAN 10 YEARS       0.0915   0.1792   0.5106 0.6096 -0.2598  0.4428
# Time_living_in_BCN_MORE THAN 10 YEARS       0.0984   0.0606   1.6247 0.1042 -0.0203  0.2171
# Time_living_in_barri_LESS THAN 10 YEARS    -0.8647   0.1026  -8.4319 0.0000 -1.0657 -0.6637
# Time_living_in_barri_MORE THAN 10 YEARS    -0.7505   0.0498 -15.0757 0.0000 -0.8481 -0.6529
# Means_of_transport_CAR                      0.6835   0.1113   6.1424 0.0000  0.4654  0.9015
# Means_of_transport_MOTORCYCLE               0.4022   0.2257   1.7820 0.0747 -0.0402  0.8445
# Means_of_transport_OTHERS                   0.7316   0.4378   1.6711 0.0947 -0.1265  1.5896
# Means_of_transport_PUBLIC TRANSPORT         0.0078   0.0603   0.1293 0.8971 -0.1103  0.1259
# Means_of_transport_TAXI                     1.4129   0.1654   8.5410 0.0000  1.0887  1.7371
# Means_of_transport_WALKING                  0.5525   0.0769   7.1807 0.0000  0.4017  0.7033
# House_M2_51-100 M2                         -0.2493   0.0458  -5.4429 0.0000 -0.3391 -0.1595
# House_M2_< 50 M2                            0.1060   0.0877   1.2085 0.2269 -0.0659  0.2779
# House_M2_> 150 M2                           0.6245   0.1292   4.8331 0.0000  0.3713  0.8778
# Social_class_LOW                            0.9897   0.0794  12.4634 0.0000  0.8341  1.1453
# Social_class_MIDDLE-HIGH                    1.5698   0.1356  11.5772 0.0000  1.3040  1.8355
# Social_class_MIDDLE-LOW                     0.8553   0.0622  13.7516 0.0000  0.7334  0.9772
# Social_class_MIDDLE-MIDDLE                  0.9139   0.0594  15.3980 0.0000  0.7976  1.0302
# ===========================================================================================

# %%
margeff = result.get_margeff()
print(margeff.summary())
# Out:
#              Logit Marginal Effects
# ================================================
# Dep. Variable:     Stay_in_the_same_neighborhood
# Method:                                     dydx
# At:                                      overall
# ==============================================================================================================
#                                                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Gender                                         0.0478      0.007      7.316      0.000       0.035       0.061
# GARBAGE COLLECTION                            -0.0926      0.007    -12.736      0.000      -0.107      -0.078
# NOISE                                          0.0413      0.004     11.502      0.000       0.034       0.048
# PUBLIC LIGHTING                               -0.0503      0.006     -8.627      0.000      -0.062      -0.039
# URBANISM                                       0.0181      0.005      3.473      0.001       0.008       0.028
# ASPHALT AND STREET CONSERVATION                0.0175      0.004      4.089      0.000       0.009       0.026
# FACADES AND BUILDING CONSERVATION             -0.0261      0.005     -5.074      0.000      -0.036      -0.016
# CIRCULATION                                    0.0101      0.004      2.611      0.009       0.003       0.018
# PARKING                                        0.0187      0.004      4.674      0.000       0.011       0.027
# MUNICIPAL POLICE                               0.0081      0.004      1.833      0.067      -0.001       0.017
# CITIZEN SECURITY IN THE NEIGHBORHOOD           0.0213      0.004      5.582      0.000       0.014       0.029
# CITIZEN INFORMATION AND ATTENTION SERVICES    -0.0116      0.006     -1.998      0.046      -0.023      -0.000
# SOCIAL SERVICES CENTERS                        0.0302      0.006      5.464      0.000       0.019       0.041
# POPULAR FESTIVALS                              0.0207      0.006      3.625      0.000       0.010       0.032
# MUNICIPAL MARKETS                             -0.0675      0.006    -11.137      0.000      -0.079      -0.056
# PUBLIC LIBRARIES                              -0.0221      0.006     -3.448      0.001      -0.035      -0.010
# Barri_comparison                               0.2570      0.005     49.523      0.000       0.247       0.267
# Voted                                         -0.0448      0.008     -5.736      0.000      -0.060      -0.029
# Born_in_BCN                                   -0.0353      0.011     -3.216      0.001      -0.057      -0.014
# Living_alone                                   0.0581      0.008      7.460      0.000       0.043       0.073
# Barri_over_BCN_if_has_improved                 0.0470      0.007      6.713      0.000       0.033       0.061
# Barri_over_BCN_if_will_improve                 0.0762      0.008      9.465      0.000       0.060       0.092
# Barri_over_BCN_satisfaction_of_living          0.0753      0.009      8.426      0.000       0.058       0.093
# Barri_over_BCN_city_management                 0.0897      0.011      8.240      0.000       0.068       0.111
# Barri_over_BCN_transport                       0.0802      0.014      5.602      0.000       0.052       0.108
# Time_living_in_BCN_LESS THAN 10 YEARS          0.0171      0.034      0.511      0.610      -0.049       0.083
# Time_living_in_BCN_MORE THAN 10 YEARS          0.0184      0.011      1.625      0.104      -0.004       0.041
# Time_living_in_barri_LESS THAN 10 YEARS       -0.1618      0.019     -8.487      0.000      -0.199      -0.124
# Time_living_in_barri_MORE THAN 10 YEARS       -0.1405      0.009    -15.399      0.000      -0.158      -0.123
# Means_of_transport_CAR                         0.1279      0.021      6.164      0.000       0.087       0.169
# Means_of_transport_MOTORCYCLE                  0.0753      0.042      1.783      0.075      -0.007       0.158
# Means_of_transport_OTHERS                      0.1369      0.082      1.672      0.095      -0.024       0.297
# Means_of_transport_PUBLIC TRANSPORT            0.0015      0.011      0.129      0.897      -0.021       0.024
# Means_of_transport_TAXI                        0.2644      0.031      8.593      0.000       0.204       0.325
# Means_of_transport_WALKING                     0.1034      0.014      7.215      0.000       0.075       0.132
# House_M2_51-100 M2                            -0.0467      0.009     -5.458      0.000      -0.063      -0.030
# House_M2_< 50 M2                               0.0198      0.016      1.209      0.227      -0.012       0.052
# House_M2_> 150 M2                              0.1169      0.024      4.842      0.000       0.070       0.164
# Social_class_LOW                               0.1852      0.015     12.641      0.000       0.157       0.214
# Social_class_MIDDLE-HIGH                       0.2938      0.025     11.712      0.000       0.245       0.343
# Social_class_MIDDLE-LOW                        0.1601      0.011     13.987      0.000       0.138       0.183
# Social_class_MIDDLE-MIDDLE                     0.1711      0.011     15.734      0.000       0.150       0.192
# ==============================================================================================================

# %%
import seaborn as sns # just a conventional alias, don't know why
sns.set(style="white")

corr = data_train[independent].corr('spearman')

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, annot = corr.round(2), linewidths=.5, cbar_kws={"shrink": .5})

# %%
data_test = pd.get_dummies(data_test)

# %%
data_test.groupby(['Stay_in_the_same_neighborhood']).size()
# Out:
# Stay_in_the_same_neighborhood
# 0     417
# 1    1065
# dtype: int64

# %%
print("Rate if we predict 1 for whole dataset: ", data_test.groupby(['Stay_in_the_same_neighborhood']).size()[1]/(data_test.groupby(['Stay_in_the_same_neighborhood']).size()[0]+data_test.groupby(['Stay_in_the_same_neighborhood']).size()[1]))
# Out:
# Rate if we predict 1 for whole dataset:  0.7186234817813765

# %%
x_test = data_test[features]
y_test = data_test[dependent]

# %%
x_test.shape, os_data_x.shape
# Out:
# ((1482, 42), (18864, 42))

# %%
# logit_model = sm.Logit(y_test,x_test)
# result=logit_model.fit()
# print(result.summary2())

# %%
# yhat = logit_model.predict(x_test)
# prediction = list(map(y_test, yhat))
logreg = LogisticRegression(penalty='none')
logreg.fit(os_data_x,os_data_y)
y_pred=logreg.predict(x_test)
# Out:
# C:\Users\THINK\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\THINK\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
# confusion matrix 
cm = confusion_matrix(y_test, y_pred)  
print ("Confusion Matrix : \n", cm)  
  
# accuracy score of the model 
print('Test accuracy = ', accuracy_score(y_test, y_pred))

# r2 of the model 
print('R2 = ', r2_score(y_test, y_pred))
# Out:
# Confusion Matrix :
#  [[153 264]
#  [195 870]]
# Test accuracy =  0.6902834008097166
# R2 =  -0.5317053399533893

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.5919039416354241

# %%
print(classification_report(y_test, y_pred.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.37      0.40       417
#            1       0.77      0.82      0.79      1065
#
#     accuracy                           0.69      1482
#    macro avg       0.60      0.59      0.60      1482
# weighted avg       0.68      0.69      0.68      1482

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict(x_test))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
