# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Predictors of elderly citizens willingness to stay in the neighbourhood
# # Logistic regression

# %% [markdown]
# Original dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import r2_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from scipy import stats

# %%
data = pd.read_pickle("survey_transformed.pkl")

# %%
data.head()
# Out:
#      ANY NOM_DISTRICTE  Would_not_stay_in_the_neighborhood  Gender  \
# 0   2007  CIUTAT VELLA                                 0.0       0
# 5   2007  CIUTAT VELLA                                 0.0       1
# 7   2007  CIUTAT VELLA                                 1.0       0
# 9   2007  CIUTAT VELLA                                 0.0       1
# 12  2007  CIUTAT VELLA                                 0.0       1
#
#                Time_living_in_barri  Barri_evolution  \
# 0   I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED
# 5                MORE THAN 10 YEARS  IT HAS IMPROVED
# 7   I HAVE ALWAYS LIVED IN THE CITY      IT IS WORSE
# 9                MORE THAN 10 YEARS      IT IS WORSE
# 12  I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED
#
#    Barri_satisfaction_of_living                 Barri_comparison GREEN AREAS  \
# 0                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 5                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 7      I DON'T KNOW / NO ANSWER  NEITHER THE BEST, NOR THE WORST        GOOD
# 9                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 12                    SATISFIED                  ONE OF THE BEST         BAD
#
#    PUBLIC LIGHTING  ...  House_size Monthly_family_income Social_class  \
# 0             GOOD  ...   51-100 M2       1001-2000 EUROS   MIDDLE-LOW
# 5             GOOD  ...   51-100 M2          < 1000 EUROS   MIDDLE-LOW
# 7             GOOD  ...     < 50 M2       1001-2000 EUROS   MIDDLE-LOW
# 9             GOOD  ...  101-150 M2          < 1000 EUROS   MIDDLE-LOW
# 12            GOOD  ...   51-100 M2          < 1000 EUROS   MIDDLE-LOW
#
#    Living_alone    BCN_evolution BCN_satisfaction_of_living BCN_transport  \
# 0             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 5             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 7             0  IT HAS IMPROVED              NOT SATISFIED          GOOD
# 9             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 12            1  IT HAS IMPROVED                  SATISFIED          GOOD
#
#     BCN_over_barri_evolution BCN_over_barri_satisfaction_of_living  \
# 0                          0                                     0
# 5                          0                                     0
# 7                          1                                     0
# 9                          1                                     0
# 12                         0                                     0
#
#    BCN_over_barri_transport
# 0                         0
# 5                         0
# 7                         0
# 9                         1
# 12                        0
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (10915, 28)

# %%
data.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'Would_not_stay_in_the_neighborhood',
#  'Gender',
#  'Time_living_in_barri',
#  'Barri_evolution',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'ASPHALT AND STREET CONSERVATION',
#  'CIRCULATION',
#  'BUS',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'MUNICIPAL MARKETS',
#  'Barri_transport',
#  'Owns_a_car',
#  'House_size',
#  'Monthly_family_income',
#  'Social_class',
#  'Living_alone',
#  'BCN_evolution',
#  'BCN_satisfaction_of_living',
#  'BCN_transport',
#  'BCN_over_barri_evolution',
#  'BCN_over_barri_satisfaction_of_living',
#  'BCN_over_barri_transport']

# %%
x_var = data.columns.tolist()

# %%
for i in ['ANY', 'NOM_DISTRICTE', 'Would_not_stay_in_the_neighborhood',
          'BCN_evolution', 'BCN_satisfaction_of_living', 'BCN_transport']:
    x_var.remove(i)

# %%
x = data[x_var]

# %%
y = data['Would_not_stay_in_the_neighborhood']

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
x
# Out:
#        Gender  Owns_a_car  Living_alone  BCN_over_barri_evolution  \
# 0           0         0.0             0                         0
# 5           1         0.0             0                         0
# 7           0         1.0             0                         1
# 9           1         0.0             0                         1
# 12          1         0.0             1                         0
# ...       ...         ...           ...                       ...
# 19576       1         0.0             1                         1
# 19577       1         1.0             1                         0
# 19578       0         0.0             0                         0
# 19579       0         1.0             0                         0
# 19581       1         1.0             0                         0
#
#        BCN_over_barri_satisfaction_of_living  BCN_over_barri_transport  \
# 0                                          0                         0
# 5                                          0                         0
# 7                                          0                         0
# 9                                          0                         1
# 12                                         0                         0
# ...                                      ...                       ...
# 19576                                      0                         0
# 19577                                      0                         0
# 19578                                      0                         0
# 19579                                      0                         0
# 19581                                      1                         0
#
#        Time_living_in_barri_LESS THAN 10 YEARS  \
# 0                                            0
# 5                                            0
# 7                                            0
# 9                                            0
# 12                                           0
# ...                                        ...
# 19576                                        0
# 19577                                        0
# 19578                                        0
# 19579                                        0
# 19581                                        0
#
#        Time_living_in_barri_MORE THAN 10 YEARS  \
# 0                                            0
# 5                                            1
# 7                                            0
# 9                                            1
# 12                                           0
# ...                                        ...
# 19576                                        1
# 19577                                        1
# 19578                                        1
# 19579                                        1
# 19581                                        1
#
#        Barri_evolution_IT HAS IMPROVED  Barri_evolution_IT IS THE SAME  ...  \
# 0                                    1                               0  ...
# 5                                    1                               0  ...
# 7                                    0                               0  ...
# 9                                    0                               0  ...
# 12                                   1                               0  ...
# ...                                ...                             ...  ...
# 19576                                0                               1  ...
# 19577                                1                               0  ...
# 19578                                0                               1  ...
# 19579                                1                               0  ...
# 19581                                0                               0  ...
#
#        House_size_51-100 M2  House_size_< 50 M2  House_size_> 150 M2  \
# 0                         1                   0                    0
# 5                         1                   0                    0
# 7                         0                   1                    0
# 9                         0                   0                    0
# 12                        1                   0                    0
# ...                     ...                 ...                  ...
# 19576                     1                   0                    0
# 19577                     1                   0                    0
# 19578                     1                   0                    0
# 19579                     1                   0                    0
# 19581                     0                   0                    0
#
#        Monthly_family_income_2001-3000 EUROS  \
# 0                                          0
# 5                                          0
# 7                                          0
# 9                                          0
# 12                                         0
# ...                                      ...
# 19576                                      0
# 19577                                      1
# 19578                                      0
# 19579                                      1
# 19581                                      0
#
#        Monthly_family_income_< 1000 EUROS  Monthly_family_income_> 3000 EUROS  \
# 0                                       0                                   0
# 5                                       1                                   0
# 7                                       0                                   0
# 9                                       1                                   0
# 12                                      1                                   0
# ...                                   ...                                 ...
# 19576                                   1                                   0
# 19577                                   0                                   0
# 19578                                   1                                   0
# 19579                                   0                                   0
# 19581                                   0                                   0
#
#        Social_class_LOW  Social_class_MIDDLE-HIGH  Social_class_MIDDLE-LOW  \
# 0                     0                         0                        1
# 5                     0                         0                        1
# 7                     0                         0                        1
# 9                     0                         0                        1
# 12                    0                         0                        1
# ...                 ...                       ...                      ...
# 19576                 1                         0                        0
# 19577                 0                         0                        1
# 19578                 0                         0                        1
# 19579                 0                         0                        0
# 19581                 0                         0                        1
#
#        Social_class_MIDDLE-MIDDLE
# 0                               0
# 5                               0
# 7                               0
# 9                               0
# 12                              0
# ...                           ...
# 19576                           0
# 19577                           0
# 19578                           0
# 19579                           1
# 19581                           0
#
# [10915 rows x 45 columns]

# %%
# x.columns.tolist()

# %%
# for i in x.columns.tolist():
#     if i[-6:] == "ANSWER":
#         del x[i]

# %%
# for i in [#'Gender', 'Owns_a_car', 'Living_alone',
#     #'BCN_over_barri_evolution', 'BCN_over_barri_satisfaction_of_living', 'BCN_over_barri_transport',
    
#     #'Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY',
#     'Time_living_in_barri_LESS THAN 10 YEARS',
#     #'Time_living_in_barri_MORE THAN 10 YEARS',
    
#     #"Barri_evolution_I DON'T KNOW / NO ANSWER",
#     'Barri_evolution_IT HAS IMPROVED',
#     #'Barri_evolution_IT IS THE SAME',
#     #'Barri_evolution_IT IS WORSE',
    
#     #"Barri_satisfaction_of_living_I DON'T KNOW / NO ANSWER",
#     #'Barri_satisfaction_of_living_NOT SATISFIED',
#     'Barri_satisfaction_of_living_SATISFIED',
    
#     #"Barri_comparison_I DON'T KNOW / NO ANSWER",
#     #'Barri_comparison_NEITHER THE BEST, NOR THE WORST',
#     'Barri_comparison_ONE OF THE BEST',
#     #'Barri_comparison_ONE OF THE WORST',
    
#     #'House_size_101-150 M2', 'House_size_51-100 M2',
#     'House_size_< 50 M2',
#     #'House_size_> 150 M2',
    
#     #'Monthly_family_income_1001-2000 EUROS', 'Monthly_family_income_2001-3000 EUROS',
#     'Monthly_family_income_< 1000 EUROS',
#     #'Monthly_family_income_> 3000 EUROS',
    
#     #'Social_class_HIGH','Social_class_MIDDLE-HIGH','Social_class_MIDDLE-LOW','Social_class_MIDDLE-MIDDLE',
#     'Social_class_LOW']:
#     del x[i]

# %%
x = sm.add_constant(x)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.291285
#          Iterations 7
#                                                  Results: Logit
# ================================================================================================================
# Model:                        Logit                                       Pseudo R-squared:          0.167
# Dependent Variable:           Would_not_stay_in_the_neighborhood          AIC:                       6450.7460
# Date:                         2021-04-27 07:27                            BIC:                       6786.4491
# No. Observations:             10915                                       Log-Likelihood:            -3179.4
# Df Model:                     45                                          LL-Null:                   -3818.3
# Df Residuals:                 10869                                       LLR p-value:               2.8309e-238
# Converged:                    1.0000                                      Scale:                     1.0000
# No. Iterations:               7.0000
# ----------------------------------------------------------------------------------------------------------------
#                                                                   Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                                            -1.3652   0.9827 -1.3892 0.1648 -3.2913  0.5609
# Gender                                                            0.0459   0.0718  0.6399 0.5222 -0.0947  0.1866
# Owns_a_car                                                        0.1591   0.0787  2.0205 0.0433  0.0048  0.3133
# Living_alone                                                      0.1364   0.0818  1.6682 0.0953 -0.0239  0.2967
# BCN_over_barri_evolution                                         -0.1569   0.1052 -1.4916 0.1358 -0.3630  0.0492
# BCN_over_barri_satisfaction_of_living                             0.2500   0.1468  1.7033 0.0885 -0.0377  0.5377
# BCN_over_barri_transport                                          0.3021   0.1319  2.2904 0.0220  0.0436  0.5607
# Time_living_in_barri_LESS THAN 10 YEARS                           1.2811   0.1472  8.7012 0.0000  0.9926  1.5697
# Time_living_in_barri_MORE THAN 10 YEARS                           0.3301   0.1031  3.2012 0.0014  0.1280  0.5322
# Barri_evolution_IT HAS IMPROVED                                   0.1751   0.3331  0.5257 0.5991 -0.4778  0.8280
# Barri_evolution_IT IS THE SAME                                    0.1728   0.3354  0.5152 0.6064 -0.4846  0.8302
# Barri_evolution_IT IS WORSE                                       0.4384   0.3382  1.2962 0.1949 -0.2245  1.1013
# Barri_satisfaction_of_living_NOT SATISFIED                       -0.5511   0.4414 -1.2485 0.2118 -1.4163  0.3140
# Barri_satisfaction_of_living_SATISFIED                           -1.4164   0.4255 -3.3289 0.0009 -2.2503 -0.5825
# Barri_comparison_NEITHER THE BEST, NOR THE WORST                  0.1658   0.2261  0.7332 0.4634 -0.2773  0.6088
# Barri_comparison_ONE OF THE BEST                                 -1.2678   0.2319 -5.4670 0.0000 -1.7224 -0.8133
# Barri_comparison_ONE OF THE WORST                                 1.2072   0.2475  4.8776 0.0000  0.7221  1.6922
# GREEN AREAS_GOOD                                                 -0.1968   0.0892 -2.2066 0.0273 -0.3716 -0.0220
# GREEN AREAS_I DON'T KNOW / NO ANSWER                             -0.3351   0.1990 -1.6845 0.0921 -0.7251  0.0548
# PUBLIC LIGHTING_GOOD                                             -0.1956   0.1155 -1.6934 0.0904 -0.4219  0.0308
# PUBLIC LIGHTING_I DON'T KNOW / NO ANSWER                          0.0773   0.3038  0.2545 0.7991 -0.5181  0.6727
# ASPHALT AND STREET CONSERVATION_GOOD                              0.0145   0.0873  0.1667 0.8676 -0.1565  0.1856
# ASPHALT AND STREET CONSERVATION_I DON'T KNOW / NO ANSWER         -0.4945   0.3959 -1.2490 0.2117 -1.2706  0.2815
# CIRCULATION_GOOD                                                  0.0233   0.0747  0.3126 0.7546 -0.1230  0.1697
# CIRCULATION_I DON'T KNOW / NO ANSWER                             -0.0221   0.1784 -0.1238 0.9015 -0.3717  0.3275
# BUS_GOOD                                                         -0.1196   0.1138 -1.0507 0.2934 -0.3426  0.1035
# BUS_I DON'T KNOW / NO ANSWER                                     -0.4722   0.2241 -2.1072 0.0351 -0.9114 -0.0330
# CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD                      0.2610   0.0929  2.8093 0.0050  0.0789  0.4431
# CITIZEN SECURITY IN THE CITY AS A WHOLE_I DON'T KNOW / NO ANSWER  0.3779   0.1927  1.9614 0.0498  0.0003  0.7556
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD                        -0.2140   0.0943 -2.2680 0.0233 -0.3989 -0.0291
# CITIZEN SECURITY IN THE NEIGHBORHOOD_I DON'T KNOW / NO ANSWER     0.3069   0.3597  0.8532 0.3936 -0.3982  1.0120
# MUNICIPAL MARKETS_GOOD                                            0.0448   0.1277  0.3506 0.7259 -0.2055  0.2951
# MUNICIPAL MARKETS_I DON'T KNOW / NO ANSWER                       -0.1906   0.1746 -1.0914 0.2751 -0.5328  0.1517
# Barri_transport_GOOD                                             -0.0474   0.1332 -0.3558 0.7220 -0.3085  0.2137
# Barri_transport_I DON'T KNOW / NO ANSWER                         -0.0214   0.4546 -0.0471 0.9624 -0.9124  0.8696
# Barri_transport_NORMAL                                            0.0331   0.1347  0.2458 0.8058 -0.2308  0.2971
# House_size_51-100 M2                                              0.2158   0.1255  1.7189 0.0856 -0.0303  0.4619
# House_size_< 50 M2                                                0.3224   0.1650  1.9546 0.0506 -0.0009  0.6458
# House_size_> 150 M2                                               0.1556   0.2312  0.6729 0.5010 -0.2976  0.6088
# Monthly_family_income_2001-3000 EUROS                             0.1942   0.1080  1.7991 0.0720 -0.0174  0.4058
# Monthly_family_income_< 1000 EUROS                               -0.0510   0.0828 -0.6158 0.5380 -0.2133  0.1113
# Monthly_family_income_> 3000 EUROS                                0.2371   0.1550  1.5300 0.1260 -0.0666  0.5408
# Social_class_LOW                                                  0.4092   0.7633  0.5360 0.5919 -1.0869  1.9053
# Social_class_MIDDLE-HIGH                                          0.3356   0.7749  0.4331 0.6650 -1.1832  1.8543
# Social_class_MIDDLE-LOW                                           0.3672   0.7593  0.4836 0.6287 -1.1211  1.8555
# Social_class_MIDDLE-MIDDLE                                        0.2040   0.7585  0.2690 0.7879 -1.2825  1.6906
# ================================================================================================================

# %%
result.pvalues.sort_values(ascending=False)
# Out:
# Barri_transport_BAD                                     9.999505e-01
# CIRCULATION_GOOD                                        9.969179e-01
# Barri_evolution_IT IS THE SAME                          9.644962e-01
# Barri_transport_NORMAL                                  9.173563e-01
# Barri_transport_GOOD                                    9.115683e-01
# CIRCULATION_BAD                                         8.896592e-01
# Social_class_MIDDLE-HIGH                                6.882185e-01
# PUBLIC LIGHTING_BAD                                     6.120177e-01
# CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD            5.902971e-01
# Social_class_MIDDLE-LOW                                 5.885620e-01
# GREEN AREAS_GOOD                                        5.824482e-01
# Monthly_family_income_1001-2000 EUROS                   5.665344e-01
# Social_class_HIGH                                       5.290592e-01
# Gender                                                  4.835505e-01
# House_size_> 150 M2                                     4.203095e-01
# CITIZEN SECURITY IN THE NEIGHBORHOOD_BAD                3.902803e-01
# MUNICIPAL MARKETS_BAD                                   3.121284e-01
# House_size_51-100 M2                                    3.021578e-01
# PUBLIC LIGHTING_GOOD                                    2.345909e-01
# ASPHALT AND STREET CONSERVATION_BAD                     2.224980e-01
# ASPHALT AND STREET CONSERVATION_GOOD                    1.967053e-01
# BCN_over_barri_evolution                                1.463883e-01
# GREEN AREAS_BAD                                         1.374547e-01
# CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD               1.295123e-01
# BCN_over_barri_satisfaction_of_living                   1.183454e-01
# Living_alone                                            1.107610e-01
# Monthly_family_income_> 3000 EUROS                      1.051762e-01
# MUNICIPAL MARKETS_GOOD                                  1.016239e-01
# BUS_GOOD                                                7.804824e-02
# CITIZEN SECURITY IN THE CITY AS A WHOLE_BAD             6.604229e-02
# Monthly_family_income_2001-3000 EUROS                   5.340101e-02
# Social_class_MIDDLE-MIDDLE                              4.241829e-02
# House_size_101-150 M2                                   3.660604e-02
# BUS_BAD                                                 3.653955e-02
# Owns_a_car                                              3.452280e-02
# BCN_over_barri_transport                                2.049231e-02
# Barri_evolution_IT IS WORSE                             3.585164e-03
# const                                                   5.673851e-04
# Barri_satisfaction_of_living_NOT SATISFIED              1.401826e-11
# Time_living_in_barri_MORE THAN 10 YEARS                 3.195749e-16
# Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY    2.296446e-18
# Barri_comparison_NEITHER THE BEST, NOR THE WORST        1.985052e-70
# Barri_comparison_ONE OF THE WORST                       3.555123e-74
# dtype: float64

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
# NIE POPRAWIŁAM PONIŻSZEGO FEATURE SELECTION

# %%
for i in ['GARBAGE COLLECTION', 'BCN_over_barri_evolution', 'Barri_transport', 'Barri_evolution', 'Owns_a_car']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['FACADES AND BUILDING CONSERVATION', 'MUNICIPAL POLICE', 'CIRCULATION', 'Gender']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['BCN_over_barri_future', 'MUNICIPAL MARKETS', 'STREETS CLEANING', 'Monthly_family_income', 'PUBLIC LIGHTING']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['House_size', 'Living_alone', 'ASPHALT AND STREET CONSERVATION']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
print(result.get_margeff().summary())

# %%
result.pred_table()

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
