# %% [markdown]
# Aleksandra Bednarczuk

# %% [markdown]
# # Predictors of elderly citizens willingness to stay in the neighbourhood
# # Logistic regression

# %% [markdown]
# Original dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import r2_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from scipy import stats

# %%
data = pd.read_pickle("survey_transformed.pkl")

# %%
data.head()
# Out:
#      ANY NOM_DISTRICTE  Would_not_stay_in_the_neighborhood  Gender  \
# 0   2007  CIUTAT VELLA                                 0.0       0
# 5   2007  CIUTAT VELLA                                 0.0       1
# 7   2007  CIUTAT VELLA                                 1.0       0
# 9   2007  CIUTAT VELLA                                 0.0       1
# 12  2007  CIUTAT VELLA                                 0.0       1
#
#                Time_living_in_barri  Barri_evolution  \
# 0   I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED
# 5                MORE THAN 10 YEARS  IT HAS IMPROVED
# 7   I HAVE ALWAYS LIVED IN THE CITY      IT IS WORSE
# 9                MORE THAN 10 YEARS      IT IS WORSE
# 12  I HAVE ALWAYS LIVED IN THE CITY  IT HAS IMPROVED
#
#    Barri_satisfaction_of_living                 Barri_comparison GREEN AREAS  \
# 0                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 5                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 7      I DON'T KNOW / NO ANSWER  NEITHER THE BEST, NOR THE WORST        GOOD
# 9                     SATISFIED  NEITHER THE BEST, NOR THE WORST        GOOD
# 12                    SATISFIED                  ONE OF THE BEST         BAD
#
#    PUBLIC LIGHTING  ...  House_size Monthly_family_income Social_class  \
# 0             GOOD  ...   51-100 M2       1001-2000 EUROS   MIDDLE-LOW
# 5             GOOD  ...   51-100 M2          < 1000 EUROS   MIDDLE-LOW
# 7             GOOD  ...     < 50 M2       1001-2000 EUROS   MIDDLE-LOW
# 9             GOOD  ...  101-150 M2          < 1000 EUROS   MIDDLE-LOW
# 12            GOOD  ...   51-100 M2          < 1000 EUROS   MIDDLE-LOW
#
#    Living_alone    BCN_evolution BCN_satisfaction_of_living BCN_transport  \
# 0             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 5             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 7             0  IT HAS IMPROVED              NOT SATISFIED          GOOD
# 9             0  IT HAS IMPROVED                  SATISFIED          GOOD
# 12            1  IT HAS IMPROVED                  SATISFIED          GOOD
#
#     BCN_over_barri_evolution BCN_over_barri_satisfaction_of_living  \
# 0                          0                                     0
# 5                          0                                     0
# 7                          1                                     0
# 9                          1                                     0
# 12                         0                                     0
#
#    BCN_over_barri_transport
# 0                         0
# 5                         0
# 7                         0
# 9                         1
# 12                        0
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (10915, 28)

# %%
data.columns.tolist()
# Out:
# ['ANY',
#  'NOM_DISTRICTE',
#  'Would_not_stay_in_the_neighborhood',
#  'Gender',
#  'Time_living_in_barri',
#  'Barri_evolution',
#  'Barri_satisfaction_of_living',
#  'Barri_comparison',
#  'GREEN AREAS',
#  'PUBLIC LIGHTING',
#  'ASPHALT AND STREET CONSERVATION',
#  'CIRCULATION',
#  'BUS',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD',
#  'MUNICIPAL MARKETS',
#  'Barri_transport',
#  'Owns_a_car',
#  'House_size',
#  'Monthly_family_income',
#  'Social_class',
#  'Living_alone',
#  'BCN_evolution',
#  'BCN_satisfaction_of_living',
#  'BCN_transport',
#  'BCN_over_barri_evolution',
#  'BCN_over_barri_satisfaction_of_living',
#  'BCN_over_barri_transport']

# %%
x_var = data.columns.tolist()

# %%
for i in ['ANY', 'NOM_DISTRICTE', 'Would_not_stay_in_the_neighborhood',
          'BCN_evolution', 'BCN_satisfaction_of_living', 'BCN_transport']:
    x_var.remove(i)

# %%
x = data[x_var]

# %%
y = data['Would_not_stay_in_the_neighborhood']

# %%
x = pd.get_dummies(x)

# %%
x
# Out:
#        Gender  Owns_a_car  Living_alone  BCN_over_barri_evolution  \
# 0           0         0.0             0                         0
# 5           1         0.0             0                         0
# 7           0         1.0             0                         1
# 9           1         0.0             0                         1
# 12          1         0.0             1                         0
# ...       ...         ...           ...                       ...
# 19576       1         0.0             1                         1
# 19577       1         1.0             1                         0
# 19578       0         0.0             0                         0
# 19579       0         1.0             0                         0
# 19581       1         1.0             0                         0
#
#        BCN_over_barri_satisfaction_of_living  BCN_over_barri_transport  \
# 0                                          0                         0
# 5                                          0                         0
# 7                                          0                         0
# 9                                          0                         1
# 12                                         0                         0
# ...                                      ...                       ...
# 19576                                      0                         0
# 19577                                      0                         0
# 19578                                      0                         0
# 19579                                      0                         0
# 19581                                      1                         0
#
#        Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY  \
# 0                                                      1
# 5                                                      0
# 7                                                      1
# 9                                                      0
# 12                                                     1
# ...                                                  ...
# 19576                                                  0
# 19577                                                  0
# 19578                                                  0
# 19579                                                  0
# 19581                                                  0
#
#        Time_living_in_barri_LESS THAN 10 YEARS  \
# 0                                            0
# 5                                            0
# 7                                            0
# 9                                            0
# 12                                           0
# ...                                        ...
# 19576                                        0
# 19577                                        0
# 19578                                        0
# 19579                                        0
# 19581                                        0
#
#        Time_living_in_barri_MORE THAN 10 YEARS  \
# 0                                            0
# 5                                            1
# 7                                            0
# 9                                            1
# 12                                           0
# ...                                        ...
# 19576                                        1
# 19577                                        1
# 19578                                        1
# 19579                                        1
# 19581                                        1
#
#        Barri_evolution_I DON'T KNOW / NO ANSWER  ...  House_size_> 150 M2  \
# 0                                             0  ...                    0
# 5                                             0  ...                    0
# 7                                             0  ...                    0
# 9                                             0  ...                    0
# 12                                            0  ...                    0
# ...                                         ...  ...                  ...
# 19576                                         0  ...                    0
# 19577                                         0  ...                    0
# 19578                                         0  ...                    0
# 19579                                         0  ...                    0
# 19581                                         0  ...                    0
#
#        Monthly_family_income_1001-2000 EUROS  \
# 0                                          1
# 5                                          0
# 7                                          1
# 9                                          0
# 12                                         0
# ...                                      ...
# 19576                                      0
# 19577                                      0
# 19578                                      0
# 19579                                      0
# 19581                                      1
#
#        Monthly_family_income_2001-3000 EUROS  \
# 0                                          0
# 5                                          0
# 7                                          0
# 9                                          0
# 12                                         0
# ...                                      ...
# 19576                                      0
# 19577                                      1
# 19578                                      0
# 19579                                      1
# 19581                                      0
#
#        Monthly_family_income_< 1000 EUROS  Monthly_family_income_> 3000 EUROS  \
# 0                                       0                                   0
# 5                                       1                                   0
# 7                                       0                                   0
# 9                                       1                                   0
# 12                                      1                                   0
# ...                                   ...                                 ...
# 19576                                   1                                   0
# 19577                                   0                                   0
# 19578                                   1                                   0
# 19579                                   0                                   0
# 19581                                   0                                   0
#
#        Social_class_HIGH  Social_class_LOW  Social_class_MIDDLE-HIGH  \
# 0                      0                 0                         0
# 5                      0                 0                         0
# 7                      0                 0                         0
# 9                      0                 0                         0
# 12                     0                 0                         0
# ...                  ...               ...                       ...
# 19576                  0                 1                         0
# 19577                  0                 0                         0
# 19578                  0                 0                         0
# 19579                  0                 0                         0
# 19581                  0                 0                         0
#
#        Social_class_MIDDLE-LOW  Social_class_MIDDLE-MIDDLE
# 0                            1                           0
# 5                            1                           0
# 7                            1                           0
# 9                            1                           0
# 12                           1                           0
# ...                        ...                         ...
# 19576                        0                           0
# 19577                        1                           0
# 19578                        1                           0
# 19579                        0                           1
# 19581                        1                           0
#
# [10915 rows x 61 columns]

# %%
x.columns.tolist()
# Out:
# ['Gender',
#  'Owns_a_car',
#  'Living_alone',
#  'BCN_over_barri_evolution',
#  'BCN_over_barri_satisfaction_of_living',
#  'BCN_over_barri_transport',
#  'Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY',
#  'Time_living_in_barri_LESS THAN 10 YEARS',
#  'Time_living_in_barri_MORE THAN 10 YEARS',
#  "Barri_evolution_I DON'T KNOW / NO ANSWER",
#  'Barri_evolution_IT HAS IMPROVED',
#  'Barri_evolution_IT IS THE SAME',
#  'Barri_evolution_IT IS WORSE',
#  "Barri_satisfaction_of_living_I DON'T KNOW / NO ANSWER",
#  'Barri_satisfaction_of_living_NOT SATISFIED',
#  'Barri_satisfaction_of_living_SATISFIED',
#  "Barri_comparison_I DON'T KNOW / NO ANSWER",
#  'Barri_comparison_NEITHER THE BEST, NOR THE WORST',
#  'Barri_comparison_ONE OF THE BEST',
#  'Barri_comparison_ONE OF THE WORST',
#  'GREEN AREAS_BAD',
#  'GREEN AREAS_GOOD',
#  "GREEN AREAS_I DON'T KNOW / NO ANSWER",
#  'PUBLIC LIGHTING_BAD',
#  'PUBLIC LIGHTING_GOOD',
#  "PUBLIC LIGHTING_I DON'T KNOW / NO ANSWER",
#  'ASPHALT AND STREET CONSERVATION_BAD',
#  'ASPHALT AND STREET CONSERVATION_GOOD',
#  "ASPHALT AND STREET CONSERVATION_I DON'T KNOW / NO ANSWER",
#  'CIRCULATION_BAD',
#  'CIRCULATION_GOOD',
#  "CIRCULATION_I DON'T KNOW / NO ANSWER",
#  'BUS_BAD',
#  'BUS_GOOD',
#  "BUS_I DON'T KNOW / NO ANSWER",
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE_BAD',
#  'CITIZEN SECURITY IN THE CITY AS A WHOLE_GOOD',
#  "CITIZEN SECURITY IN THE CITY AS A WHOLE_I DON'T KNOW / NO ANSWER",
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD_BAD',
#  'CITIZEN SECURITY IN THE NEIGHBORHOOD_GOOD',
#  "CITIZEN SECURITY IN THE NEIGHBORHOOD_I DON'T KNOW / NO ANSWER",
#  'MUNICIPAL MARKETS_BAD',
#  'MUNICIPAL MARKETS_GOOD',
#  "MUNICIPAL MARKETS_I DON'T KNOW / NO ANSWER",
#  'Barri_transport_BAD',
#  'Barri_transport_GOOD',
#  "Barri_transport_I DON'T KNOW / NO ANSWER",
#  'Barri_transport_NORMAL',
#  'House_size_101-150 M2',
#  'House_size_51-100 M2',
#  'House_size_< 50 M2',
#  'House_size_> 150 M2',
#  'Monthly_family_income_1001-2000 EUROS',
#  'Monthly_family_income_2001-3000 EUROS',
#  'Monthly_family_income_< 1000 EUROS',
#  'Monthly_family_income_> 3000 EUROS',
#  'Social_class_HIGH',
#  'Social_class_LOW',
#  'Social_class_MIDDLE-HIGH',
#  'Social_class_MIDDLE-LOW',
#  'Social_class_MIDDLE-MIDDLE']

# %%
for i in x.columns.tolist():
    if i[-5:] == "_GOOD":
        del x[i]

# %%
for i in [#'Gender', 'Owns_a_car', 'Living_alone',
    #'BCN_over_barri_evolution', 'BCN_over_barri_satisfaction_of_living', 'BCN_over_barri_transport',
    
    #'Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY',
    'Time_living_in_barri_LESS THAN 10 YEARS',
    #'Time_living_in_barri_MORE THAN 10 YEARS',
    
    #"Barri_evolution_I DON'T KNOW / NO ANSWER",
    'Barri_evolution_IT HAS IMPROVED',
    #'Barri_evolution_IT IS THE SAME',
    #'Barri_evolution_IT IS WORSE',
    
    #"Barri_satisfaction_of_living_I DON'T KNOW / NO ANSWER",
    #'Barri_satisfaction_of_living_NOT SATISFIED',
    'Barri_satisfaction_of_living_SATISFIED',
    
    #"Barri_comparison_I DON'T KNOW / NO ANSWER",
    #'Barri_comparison_NEITHER THE BEST, NOR THE WORST',
    'Barri_comparison_ONE OF THE BEST',
    #'Barri_comparison_ONE OF THE WORST',
    
    #'House_size_101-150 M2', 'House_size_51-100 M2',
    'House_size_< 50 M2',
    #'House_size_> 150 M2',
    
    #'Monthly_family_income_1001-2000 EUROS', 'Monthly_family_income_2001-3000 EUROS',
    'Monthly_family_income_< 1000 EUROS',
    #'Monthly_family_income_> 3000 EUROS',
    
    #'Social_class_HIGH','Social_class_MIDDLE-HIGH','Social_class_MIDDLE-LOW','Social_class_MIDDLE-MIDDLE',
    'Social_class_LOW']:
    del x[i]

# %%
x = sm.add_constant(x)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.291285
#          Iterations 7
#                                                  Results: Logit
# =================================================================================================================
# Model:                         Logit                                       Pseudo R-squared:          0.167
# Dependent Variable:            Would_not_stay_in_the_neighborhood          AIC:                       6450.7460
# Date:                          2021-04-25 17:20                            BIC:                       6786.4491
# No. Observations:              10915                                       Log-Likelihood:            -3179.4
# Df Model:                      45                                          LL-Null:                   -3818.3
# Df Residuals:                  10869                                       LLR p-value:               2.8309e-238
# Converged:                     1.0000                                      Scale:                     1.0000
# No. Iterations:                7.0000
# -----------------------------------------------------------------------------------------------------------------
#                                                                   Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                                            -2.3422   0.1905 -12.2939 0.0000 -2.7156 -1.9688
# Gender                                                            0.0459   0.0718   0.6399 0.5222 -0.0947  0.1866
# Owns_a_car                                                        0.1591   0.0787   2.0205 0.0433  0.0048  0.3133
# Living_alone                                                      0.1364   0.0818   1.6682 0.0953 -0.0239  0.2967
# BCN_over_barri_evolution                                         -0.1569   0.1052  -1.4916 0.1358 -0.3630  0.0492
# BCN_over_barri_satisfaction_of_living                             0.2500   0.1468   1.7033 0.0885 -0.0377  0.5377
# BCN_over_barri_transport                                          0.3021   0.1319   2.2904 0.0220  0.0436  0.5607
# Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY             -1.2811   0.1472  -8.7012 0.0000 -1.5697 -0.9926
# Time_living_in_barri_MORE THAN 10 YEARS                          -0.9511   0.1175  -8.0928 0.0000 -1.1814 -0.7207
# Barri_evolution_I DON'T KNOW / NO ANSWER                         -0.1751   0.3331  -0.5257 0.5991 -0.8280  0.4778
# Barri_evolution_IT IS THE SAME                                   -0.0023   0.0850  -0.0270 0.9784 -0.1690  0.1644
# Barri_evolution_IT IS WORSE                                       0.2633   0.0952   2.7665 0.0057  0.0768  0.4498
# Barri_satisfaction_of_living_I DON'T KNOW / NO ANSWER             1.4164   0.4255   3.3289 0.0009  0.5825  2.2503
# Barri_satisfaction_of_living_NOT SATISFIED                        0.8653   0.1294   6.6848 0.0000  0.6116  1.1189
# Barri_comparison_I DON'T KNOW / NO ANSWER                         1.2678   0.2319   5.4670 0.0000  0.8133  1.7224
# Barri_comparison_NEITHER THE BEST, NOR THE WORST                  1.4336   0.0794  18.0634 0.0000  1.2780  1.5892
# Barri_comparison_ONE OF THE WORST                                 2.4750   0.1330  18.6077 0.0000  2.2143  2.7357
# GREEN AREAS_BAD                                                   0.1968   0.0892   2.2066 0.0273  0.0220  0.3716
# GREEN AREAS_I DON'T KNOW / NO ANSWER                             -0.1383   0.1873  -0.7384 0.4603 -0.5055  0.2288
# PUBLIC LIGHTING_BAD                                               0.1956   0.1155   1.6934 0.0904 -0.0308  0.4219
# PUBLIC LIGHTING_I DON'T KNOW / NO ANSWER                          0.2729   0.2861   0.9537 0.3402 -0.2879  0.8337
# ASPHALT AND STREET CONSERVATION_BAD                              -0.0145   0.0873  -0.1667 0.8676 -0.1856  0.1565
# ASPHALT AND STREET CONSERVATION_I DON'T KNOW / NO ANSWER         -0.5091   0.3907  -1.3028 0.1926 -1.2749  0.2568
# CIRCULATION_BAD                                                  -0.0233   0.0747  -0.3126 0.7546 -0.1697  0.1230
# CIRCULATION_I DON'T KNOW / NO ANSWER                             -0.0454   0.1742  -0.2608 0.7942 -0.3868  0.2959
# BUS_BAD                                                           0.1196   0.1138   1.0507 0.2934 -0.1035  0.3426
# BUS_I DON'T KNOW / NO ANSWER                                     -0.3526   0.2007  -1.7574 0.0788 -0.7459  0.0406
# CITIZEN SECURITY IN THE CITY AS A WHOLE_BAD                      -0.2610   0.0929  -2.8093 0.0050 -0.4431 -0.0789
# CITIZEN SECURITY IN THE CITY AS A WHOLE_I DON'T KNOW / NO ANSWER  0.1169   0.1824   0.6408 0.5216 -0.2407  0.4745
# CITIZEN SECURITY IN THE NEIGHBORHOOD_BAD                          0.2140   0.0943   2.2680 0.0233  0.0291  0.3989
# CITIZEN SECURITY IN THE NEIGHBORHOOD_I DON'T KNOW / NO ANSWER     0.5209   0.3517   1.4810 0.1386 -0.1685  1.2102
# MUNICIPAL MARKETS_BAD                                            -0.0448   0.1277  -0.3506 0.7259 -0.2951  0.2055
# MUNICIPAL MARKETS_I DON'T KNOW / NO ANSWER                       -0.2353   0.1300  -1.8106 0.0702 -0.4901  0.0194
# Barri_transport_BAD                                               0.0474   0.1332   0.3558 0.7220 -0.2137  0.3085
# Barri_transport_I DON'T KNOW / NO ANSWER                          0.0260   0.4393   0.0591 0.9529 -0.8351  0.8870
# Barri_transport_NORMAL                                            0.0805   0.1212   0.6643 0.5065 -0.1570  0.3180
# House_size_101-150 M2                                            -0.3224   0.1650  -1.9546 0.0506 -0.6458  0.0009
# House_size_51-100 M2                                             -0.1066   0.1150  -0.9274 0.3537 -0.3320  0.1187
# House_size_> 150 M2                                              -0.1669   0.2360  -0.7069 0.4796 -0.6295  0.2958
# Monthly_family_income_1001-2000 EUROS                             0.0510   0.0828   0.6158 0.5380 -0.1113  0.2133
# Monthly_family_income_2001-3000 EUROS                             0.2452   0.1225   2.0016 0.0453  0.0051  0.4853
# Monthly_family_income_> 3000 EUROS                                0.2881   0.1677   1.7178 0.0858 -0.0406  0.6168
# Social_class_HIGH                                                -0.4092   0.7633  -0.5360 0.5919 -1.9053  1.0869
# Social_class_MIDDLE-HIGH                                         -0.0736   0.2094  -0.3515 0.7252 -0.4839  0.3367
# Social_class_MIDDLE-LOW                                          -0.0420   0.1083  -0.3874 0.6984 -0.2542  0.1703
# Social_class_MIDDLE-MIDDLE                                       -0.2051   0.1106  -1.8545 0.0637 -0.4219  0.0117
# =================================================================================================================

# %%
result.pvalues.sort_values(ascending=False)
# Out:
# Barri_evolution_IT IS THE SAME                                      9.784480e-01
# Barri_transport_I DON'T KNOW / NO ANSWER                            9.528516e-01
# ASPHALT AND STREET CONSERVATION_BAD                                 8.676092e-01
# CIRCULATION_I DON'T KNOW / NO ANSWER                                7.942427e-01
# CIRCULATION_BAD                                                     7.546010e-01
# MUNICIPAL MARKETS_BAD                                               7.258898e-01
# Social_class_MIDDLE-HIGH                                            7.252011e-01
# Barri_transport_BAD                                                 7.220183e-01
# Social_class_MIDDLE-LOW                                             6.984289e-01
# Barri_evolution_I DON'T KNOW / NO ANSWER                            5.991280e-01
# Social_class_HIGH                                                   5.919460e-01
# Monthly_family_income_1001-2000 EUROS                               5.380048e-01
# Gender                                                              5.222273e-01
# CITIZEN SECURITY IN THE CITY AS A WHOLE_I DON'T KNOW / NO ANSWER    5.216491e-01
# Barri_transport_NORMAL                                              5.064879e-01
# House_size_> 150 M2                                                 4.796490e-01
# GREEN AREAS_I DON'T KNOW / NO ANSWER                                4.602766e-01
# House_size_51-100 M2                                                3.537333e-01
# PUBLIC LIGHTING_I DON'T KNOW / NO ANSWER                            3.402484e-01
# BUS_BAD                                                             2.933962e-01
# ASPHALT AND STREET CONSERVATION_I DON'T KNOW / NO ANSWER            1.926329e-01
# CITIZEN SECURITY IN THE NEIGHBORHOOD_I DON'T KNOW / NO ANSWER       1.386154e-01
# BCN_over_barri_evolution                                            1.357924e-01
# Living_alone                                                        9.528376e-02
# PUBLIC LIGHTING_BAD                                                 9.037160e-02
# BCN_over_barri_satisfaction_of_living                               8.851335e-02
# Monthly_family_income_> 3000 EUROS                                  8.583103e-02
# BUS_I DON'T KNOW / NO ANSWER                                        7.884227e-02
# MUNICIPAL MARKETS_I DON'T KNOW / NO ANSWER                          7.019936e-02
# Social_class_MIDDLE-MIDDLE                                          6.366089e-02
# House_size_101-150 M2                                               5.062911e-02
# Monthly_family_income_2001-3000 EUROS                               4.532389e-02
# Owns_a_car                                                          4.333117e-02
# GREEN AREAS_BAD                                                     2.734124e-02
# CITIZEN SECURITY IN THE NEIGHBORHOOD_BAD                            2.332804e-02
# BCN_over_barri_transport                                            2.199800e-02
# Barri_evolution_IT IS WORSE                                         5.666809e-03
# CITIZEN SECURITY IN THE CITY AS A WHOLE_BAD                         4.964970e-03
# Barri_satisfaction_of_living_I DON'T KNOW / NO ANSWER               8.717909e-04
# Barri_comparison_I DON'T KNOW / NO ANSWER                           4.576326e-08
# Barri_satisfaction_of_living_NOT SATISFIED                          2.312715e-11
# Time_living_in_barri_MORE THAN 10 YEARS                             5.832141e-16
# Time_living_in_barri_I HAVE ALWAYS LIVED IN THE CITY                3.285324e-18
# const                                                               9.765632e-35
# Barri_comparison_NEITHER THE BEST, NOR THE WORST                    6.192373e-73
# Barri_comparison_ONE OF THE WORST                                   2.781959e-77
# dtype: float64

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
# NIE POPRAWIŁAM PONIŻSZEGO FEATURE SELECTION

# %%
for i in ['GARBAGE COLLECTION', 'BCN_over_barri_evolution', 'Barri_transport', 'Barri_evolution', 'Owns_a_car']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['FACADES AND BUILDING CONSERVATION', 'MUNICIPAL POLICE', 'CIRCULATION', 'Gender']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['BCN_over_barri_future', 'MUNICIPAL MARKETS', 'STREETS CLEANING', 'Monthly_family_income', 'PUBLIC LIGHTING']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %%
for i in ['House_size', 'Living_alone', 'ASPHALT AND STREET CONSERVATION']:
    x_var.remove(i)

# %%
x = data[x_var]
x = pd.get_dummies(x, drop_first = True)

# %%
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary2())

# %%
result.pvalues.sort_values(ascending=False)

# %%
print(result.get_margeff().summary())

# %%
result.pred_table()

# %%
logit_roc_auc = roc_auc_score(y, result.predict(x))
fpr, tpr, thresholds = roc_curve(y, result.predict(x))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
